# %% [markdown]
# # Sumerian and Akkadian Word Embeddings
#
# This notebook loads Sumerian and Akkadian word embedding models and gives some hints for how to explore these models. Will someone be brave enough to try and align the two models?
#
# The data derive from the Open Richly Annotated Cuneiform Corpus ([ORACC](http://oracc.org)) created by Steve Tinney (UPenn) and dircted by Jamie Novotny (Munich), Eleanor Robson (UC London), and Niek Veldhuis (UC Berkeley).
#
# The Sumerian corpus used in this model has about 4.3 million words, the Akkadian corpus 1.5 million.

# %%
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
warnings.filterwarnings(action='ignore', category=FutureWarning, module='gensim' )
import gensim
import pickle
from sklearn.manifold import TSNE
from gensim.models.fasttext import FastText as FT_gensim
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file, save
from bokeh.models import ColumnDataSource, LabelSet, Legend, LegendItem #, HoverTool, CustomJS, , Slider
from bokeh.layouts import column
from bokeh.palettes import all_palettes
output_notebook()
# note: more recent bokeh versions require notebook 5 or JupyterLab
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2389245e-c35f-48af-a497-0b7d3b612a23">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load the Models
# There is one Akkadian model, three Sumerian models (all three use the same data, but different data representations). If your Sumerian is rusty, the lemmatized model is recommended.
# - model_cuneiform.model: the Sumerian copus in Unicode cuneiform
# - model_tl.model: the Sumerian corpus in transliteration
# - model_lemm.model: the Sumerian corpus in lemmatization

# %%
model_sux = FT_gensim.load("model/model_lemm.model")
model_akk = FT_gensim.load("model/akk_model_lemm.model")

# %% [markdown]
# # Vocabulary
# Lemmatized tokens have the form **CitationForm[GuideWord]POS**. To find possible vocabulary items you may inspect the `vocabulary`attribute.

# %%
model_sux.wv.vocab
# Out:
# {'1(barig@c)': <gensim.models.keyedvectors.Vocab at 0x10fb665f8>,
#  'še[barley]N': <gensim.models.keyedvectors.Vocab at 0x10fb66860>,
#  'ba-lul': <gensim.models.keyedvectors.Vocab at 0x10fb668d0>,
#  'nagar[carpenter]N': <gensim.models.keyedvectors.Vocab at 0x10fb66908>,
#  'niŋdu[appropriate-thing]N': <gensim.models.keyedvectors.Vocab at 0x10fb66940>,
#  'aŋ[measure]V/t': <gensim.models.keyedvectors.Vocab at 0x10fb66978>,
#  'hur-sag-še₃-mah': <gensim.models.keyedvectors.Vocab at 0x10fb669b0>,
#  'saŋ.DUN₃[recorder]N': <gensim.models.keyedvectors.Vocab at 0x10fb669e8>,
#  '2(iku@c)': <gensim.models.keyedvectors.Vocab at 0x10fb66a20>,
#  'iku[unit]N': <gensim.models.keyedvectors.Vocab at 0x10fb66a58>,
#  'har-tu-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x10fb66a90>,
#  'nukirik[gardener]N': <gensim.models.keyedvectors.Vocab at 0x10fb66ac8>,
#  'me-zi-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x10fb66b00>,
#  '1/2(iku@c)': <gensim.models.keyedvectors.Vocab at 0x10fb66b38>,
#  'ša₃-gu₂-ba': <gensim.models.keyedvectors.Vocab at 0x10fb66b70>,
#  '4(iku@c)': <gensim.models.keyedvectors.Vocab at 0x10fb66ba8>,
#  'AŠ₂-mud': <gensim.models.keyedvectors.Vocab at 0x10fb66be0>,
#  '3(iku@c)': <gensim.models.keyedvectors.Vocab at 0x10fb66c18>,
#  'dud[mound]N': <gensim.models.keyedvectors.Vocab at 0x10fb66c50>,
#  'gala[singer]N': <gensim.models.keyedvectors.Vocab at 0x10fb66c88>,
#  'a-lu-lu': <gensim.models.keyedvectors.Vocab at 0x10fb66cf8>,
#  'lugušudu[profession]N': <gensim.models.keyedvectors.Vocab at 0x10fb66d30>,
#  '1(iku@c)': <gensim.models.keyedvectors.Vocab at 0x10fb66d68>,
#  'e[house]N': <gensim.models.keyedvectors.Vocab at 0x10fb66da0>,
#  'zadim[stone-cutter]N': <gensim.models.keyedvectors.Vocab at 0x10fb66eb8>,
#  '1/4(iku@c)': <gensim.models.keyedvectors.Vocab at 0x10fb66e80>,
#  'amar-tur₃': <gensim.models.keyedvectors.Vocab at 0x103a1efd0>,
#  'dumu-šita': <gensim.models.keyedvectors.Vocab at 0x103a1ef98>,
#  'ur-dumu-zi': <gensim.models.keyedvectors.Vocab at 0x103a1ef60>,
#  'ašgab[leatherworker]N': <gensim.models.keyedvectors.Vocab at 0x103a1ef28>,
#  'u₂-KA-KA': <gensim.models.keyedvectors.Vocab at 0x103a1eef0>,
#  'AN-nu-me': <gensim.models.keyedvectors.Vocab at 0x103a1eeb8>,
#  'kuš[official]N': <gensim.models.keyedvectors.Vocab at 0x103a1ee80>,
#  'amar-ku₃': <gensim.models.keyedvectors.Vocab at 0x103a1ee48>,
#  'lum-ma': <gensim.models.keyedvectors.Vocab at 0x103a1edd8>,
#  '5(iku@c)': <gensim.models.keyedvectors.Vocab at 0x103a1eda0>,
#  '{d}sud₃-ur-sag': <gensim.models.keyedvectors.Vocab at 0x103a1ed68>,
#  '1(eše₃@c)': <gensim.models.keyedvectors.Vocab at 0x103a1ed30>,
#  'pap[relation]N': <gensim.models.keyedvectors.Vocab at 0x103a1ecf8>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x103a1ecc0>,
#  'sag-narₓ(LAK244)': <gensim.models.keyedvectors.Vocab at 0x103a1ec88>,
#  '2(u@c)': <gensim.models.keyedvectors.Vocab at 0x103a1ec18>,
#  'lal[small]V/i': <gensim.models.keyedvectors.Vocab at 0x103a1ebe0>,
#  '1(aš@c)': <gensim.models.keyedvectors.Vocab at 0x103a1eba8>,
#  'ŋuruš[male]N': <gensim.models.keyedvectors.Vocab at 0x103a1eb70>,
#  '1(u@c)': <gensim.models.keyedvectors.Vocab at 0x103a1eb00>,
#  '4(aš@c)': <gensim.models.keyedvectors.Vocab at 0x103a1eac8>,
#  'ur-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x103a1ea90>,
#  '1(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x103a1ea58>,
#  '2(aš@c)': <gensim.models.keyedvectors.Vocab at 0x103a1ea20>,
#  'munus-geštin': <gensim.models.keyedvectors.Vocab at 0x103a1e9e8>,
#  '3(aš@c)': <gensim.models.keyedvectors.Vocab at 0x103a1e9b0>,
#  'mes-lu-lu': <gensim.models.keyedvectors.Vocab at 0x103a1e978>,
#  '6(aš@c)': <gensim.models.keyedvectors.Vocab at 0x103a1e940>,
#  'adda[father]N': <gensim.models.keyedvectors.Vocab at 0x103a1e8d0>,
#  'di-utu': <gensim.models.keyedvectors.Vocab at 0x1039ef588>,
#  '5(aš@c)': <gensim.models.keyedvectors.Vocab at 0x1039ef518>,
#  'simug[smith]N': <gensim.models.keyedvectors.Vocab at 0x1039dfc50>,
#  'abgal[sage]N': <gensim.models.keyedvectors.Vocab at 0x103982ef0>,
#  '7(aš@c)': <gensim.models.keyedvectors.Vocab at 0x103dc7470>,
#  'gal-nimgir': <gensim.models.keyedvectors.Vocab at 0x103dc7320>,
#  '3(u@c)': <gensim.models.keyedvectors.Vocab at 0x103dc7630>,
#  'e₂-su₁₃-ag₂': <gensim.models.keyedvectors.Vocab at 0x103dc70b8>,
#  'nin-ur-sag': <gensim.models.keyedvectors.Vocab at 0x103dc74a8>,
#  'amar-šuba₃': <gensim.models.keyedvectors.Vocab at 0x103dc7f60>,
#  'enkud[tax-collector]N': <gensim.models.keyedvectors.Vocab at 0x103dc7eb8>,
#  'šuniŋin[total]N': <gensim.models.keyedvectors.Vocab at 0x10fb9a828>,
#  '1(gešʾu@c)': <gensim.models.keyedvectors.Vocab at 0x10fb9a860>,
#  '4(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x10fb9a898>,
#  'diš[one]NU': <gensim.models.keyedvectors.Vocab at 0x10fb9a8d0>,
#  'šeš-tur': <gensim.models.keyedvectors.Vocab at 0x10fb9a908>,
#  '7(diš)': <gensim.models.keyedvectors.Vocab at 0x10fb9a940>,
#  '1(diš)': <gensim.models.keyedvectors.Vocab at 0x10fb9a978>,
#  'bilₓ(|PAP.GEŠ.BIL|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x10fb9a9b0>,
#  'si-du₃': <gensim.models.keyedvectors.Vocab at 0x10fb9a9e8>,
#  'en-kas₄': <gensim.models.keyedvectors.Vocab at 0x10fb9aa20>,
#  '6(diš)': <gensim.models.keyedvectors.Vocab at 0x10fb9aa58>,
#  'sipad[shepherd]N': <gensim.models.keyedvectors.Vocab at 0x10fb9aa90>,
#  'giš': <gensim.models.keyedvectors.Vocab at 0x10fb9aac8>,
#  'BAD': <gensim.models.keyedvectors.Vocab at 0x10fb9ab38>,
#  'munsub[shepherd]N': <gensim.models.keyedvectors.Vocab at 0x10fb9ab70>,
#  'dubsar[scribe]N': <gensim.models.keyedvectors.Vocab at 0x10fb9aba8>,
#  'anše[equid]N': <gensim.models.keyedvectors.Vocab at 0x10fb9abe0>,
#  'a-ki-gal': <gensim.models.keyedvectors.Vocab at 0x10fb9ac18>,
#  'subur[slave]N': <gensim.models.keyedvectors.Vocab at 0x10fb9ac50>,
#  'mes-ki-na': <gensim.models.keyedvectors.Vocab at 0x10fb9ac88>,
#  'engar[farmer]N': <gensim.models.keyedvectors.Vocab at 0x10fb9acc0>,
#  'nin-gu₂-gal': <gensim.models.keyedvectors.Vocab at 0x10fb9acf8>,
#  'nagada[herdsman]N': <gensim.models.keyedvectors.Vocab at 0x10fb9ad30>,
#  'išib[priest]N': <gensim.models.keyedvectors.Vocab at 0x10fb9ad68>,
#  'abzu-mud': <gensim.models.keyedvectors.Vocab at 0x10fb9ada0>,
#  '{d}nusku₂': <gensim.models.keyedvectors.Vocab at 0x10fb9add8>,
#  'e₂-pirig-gal': <gensim.models.keyedvectors.Vocab at 0x10fb9ae10>,
#  'dilmun[important]V/i': <gensim.models.keyedvectors.Vocab at 0x10fb9ae48>,
#  'a-NI-NI': <gensim.models.keyedvectors.Vocab at 0x10fb9aeb8>,
#  '{d}nin-PA': <gensim.models.keyedvectors.Vocab at 0x10fb9aef0>,
#  'gal-ukken': <gensim.models.keyedvectors.Vocab at 0x10fb9af28>,
#  'e₂-na-lu': <gensim.models.keyedvectors.Vocab at 0x10fb9af60>,
#  '{d}nu-muš-da': <gensim.models.keyedvectors.Vocab at 0x10fb9af98>,
#  'du₁₁-ga-ni': <gensim.models.keyedvectors.Vocab at 0x10fb9afd0>,
#  'ušum-ma': <gensim.models.keyedvectors.Vocab at 0x103a25048>,
#  'kin-nir': <gensim.models.keyedvectors.Vocab at 0x103a250b8>,
#  'lugal-he₂-gal₂': <gensim.models.keyedvectors.Vocab at 0x103a250f0>,
#  'IB': <gensim.models.keyedvectors.Vocab at 0x103a25160>,
#  'nig₂-si₄': <gensim.models.keyedvectors.Vocab at 0x103a25198>,
#  'nammah[greatness]N': <gensim.models.keyedvectors.Vocab at 0x103a251d0>,
#  'e₂-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x103a25208>,
#  'AK-utu': <gensim.models.keyedvectors.Vocab at 0x103a25278>,
#  'x-x': <gensim.models.keyedvectors.Vocab at 0x103a252e8>,
#  'nubanda[overseer]N': <gensim.models.keyedvectors.Vocab at 0x103a25320>,
#  'ugula[overseer]N': <gensim.models.keyedvectors.Vocab at 0x103a25358>,
#  '{d}en-lil₂-ukken-a': <gensim.models.keyedvectors.Vocab at 0x103a25390>,
#  'sukkal[secretary]N': <gensim.models.keyedvectors.Vocab at 0x103a253c8>,
#  'guʾanše[total]N': <gensim.models.keyedvectors.Vocab at 0x103a25400>,
#  'anše-apin': <gensim.models.keyedvectors.Vocab at 0x103a25438>,
#  'u₂-dul₄': <gensim.models.keyedvectors.Vocab at 0x103a25470>,
#  'dumu[child]N': <gensim.models.keyedvectors.Vocab at 0x103a254a8>,
#  'luʾad[official]N': <gensim.models.keyedvectors.Vocab at 0x103a254e0>,
#  'ur-e₂-gal': <gensim.models.keyedvectors.Vocab at 0x103a25518>,
#  'nar[musician]N': <gensim.models.keyedvectors.Vocab at 0x103a25550>,
#  'AK': <gensim.models.keyedvectors.Vocab at 0x103a255c0>,
#  'munu[malt]N': <gensim.models.keyedvectors.Vocab at 0x103a255f8>,
#  'KA-zi-da': <gensim.models.keyedvectors.Vocab at 0x103a25630>,
#  'gal-x': <gensim.models.keyedvectors.Vocab at 0x103a256a0>,
#  'de[bring]V/t': <gensim.models.keyedvectors.Vocab at 0x103a256d8>,
#  'gub[stand]V/i': <gensim.models.keyedvectors.Vocab at 0x103a25710>,
#  'lugal-u₃-ma': <gensim.models.keyedvectors.Vocab at 0x103a25748>,
#  'inim-ma-ni-zi': <gensim.models.keyedvectors.Vocab at 0x103a25780>,
#  'lugal-nig₂': <gensim.models.keyedvectors.Vocab at 0x103a257b8>,
#  'dag[side]N': <gensim.models.keyedvectors.Vocab at 0x103a257f0>,
#  'peš[fig]N': <gensim.models.keyedvectors.Vocab at 0x103a25828>,
#  'ur-e₂-zi-da': <gensim.models.keyedvectors.Vocab at 0x103a25860>,
#  'x-na': <gensim.models.keyedvectors.Vocab at 0x103a258d0>,
#  'x-ma': <gensim.models.keyedvectors.Vocab at 0x103a25940>,
#  'a-da-DUR₂': <gensim.models.keyedvectors.Vocab at 0x103a25978>,
#  'e₂-da': <gensim.models.keyedvectors.Vocab at 0x103a259b0>,
#  'šeš-ama-na': <gensim.models.keyedvectors.Vocab at 0x103a259e8>,
#  'maškim[administrator]N': <gensim.models.keyedvectors.Vocab at 0x103a25a20>,
#  'damgargal[merchant]N': <gensim.models.keyedvectors.Vocab at 0x103a25a58>,
#  'šuba[stone]N': <gensim.models.keyedvectors.Vocab at 0x103a25a90>,
#  'KA-x-x': <gensim.models.keyedvectors.Vocab at 0x103a25b00>,
#  'urud[copper]N': <gensim.models.keyedvectors.Vocab at 0x103a25b38>,
#  'mana[unit]N': <gensim.models.keyedvectors.Vocab at 0x103a25b70>,
#  'šah[pig]N': <gensim.models.keyedvectors.Vocab at 0x103a25ba8>,
#  'ad-da-tur': <gensim.models.keyedvectors.Vocab at 0x103a25be0>,
#  '3(barig@c)': <gensim.models.keyedvectors.Vocab at 0x103a25c18>,
#  'ur-e₂-nun-gal': <gensim.models.keyedvectors.Vocab at 0x103a25c50>,
#  '2(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x103a25c88>,
#  'RI-RI': <gensim.models.keyedvectors.Vocab at 0x103a25cf8>,
#  'šuʾi[barber]N': <gensim.models.keyedvectors.Vocab at 0x103a25d30>,
#  'a₂-ag₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x103a25d68>,
#  'ad.KID[weaver]N': <gensim.models.keyedvectors.Vocab at 0x103a25da0>,
#  '1/2(diš@c)': <gensim.models.keyedvectors.Vocab at 0x103a25dd8>,
#  'en-nu-kur-še₃': <gensim.models.keyedvectors.Vocab at 0x103a25e10>,
#  '2(barig@c)': <gensim.models.keyedvectors.Vocab at 0x103a25e48>,
#  'e₂-a-nun': <gensim.models.keyedvectors.Vocab at 0x103a25e80>,
#  'lungak[brewer]N': <gensim.models.keyedvectors.Vocab at 0x103a25eb8>,
#  'KA-nun-zi': <gensim.models.keyedvectors.Vocab at 0x103a25ef0>,
#  'lidga[vessel]N': <gensim.models.keyedvectors.Vocab at 0x103a25f28>,
#  'lu[person]N': <gensim.models.keyedvectors.Vocab at 0x103a25f60>,
#  'du₁₁-ga': <gensim.models.keyedvectors.Vocab at 0x103a25f98>,
#  'NI': <gensim.models.keyedvectors.Vocab at 0x1125a4048>,
#  'DU': <gensim.models.keyedvectors.Vocab at 0x1125a40b8>,
#  '4(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x1125a40f0>,
#  '5(diš)': <gensim.models.keyedvectors.Vocab at 0x1125a4128>,
#  'ninda[bread]N': <gensim.models.keyedvectors.Vocab at 0x1125a4160>,
#  'ud[sun]N': <gensim.models.keyedvectors.Vocab at 0x1125a4198>,
#  'bad[wall]N': <gensim.models.keyedvectors.Vocab at 0x1125a41d0>,
#  'ŋi[night]N': <gensim.models.keyedvectors.Vocab at 0x1125a4208>,
#  'šeba[ration]N': <gensim.models.keyedvectors.Vocab at 0x1125a4240>,
#  'itud[moon]N': <gensim.models.keyedvectors.Vocab at 0x1125a4278>,
#  'gu[eat]V/t': <gensim.models.keyedvectors.Vocab at 0x1125a42b0>,
#  'en-il₂': <gensim.models.keyedvectors.Vocab at 0x1125a42e8>,
#  '8(aš@c)': <gensim.models.keyedvectors.Vocab at 0x1125a4320>,
#  '3(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x1125a4358>,
#  'maš[goat]N': <gensim.models.keyedvectors.Vocab at 0x1125a4390>,
#  'ur[root]N': <gensim.models.keyedvectors.Vocab at 0x1125a43c8>,
#  'šum[give]V/t': <gensim.models.keyedvectors.Vocab at 0x1125a4400>,
#  'PA': <gensim.models.keyedvectors.Vocab at 0x1125a4470>,
#  'TAG': <gensim.models.keyedvectors.Vocab at 0x1125a44e0>,
#  'kib[wheat]N': <gensim.models.keyedvectors.Vocab at 0x1125a4518>,
#  'he₂-sa₆': <gensim.models.keyedvectors.Vocab at 0x1125a4550>,
#  'šud₃': <gensim.models.keyedvectors.Vocab at 0x1125a4588>,
#  'sanga': <gensim.models.keyedvectors.Vocab at 0x1125a45f8>,
#  'HAR-tu-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x1125a4630>,
#  'zag[side]N': <gensim.models.keyedvectors.Vocab at 0x1125a4668>,
#  'gud[ox]N': <gensim.models.keyedvectors.Vocab at 0x1125a46a0>,
#  'urra[loan]N': <gensim.models.keyedvectors.Vocab at 0x1125a46d8>,
#  'egal[palace]N': <gensim.models.keyedvectors.Vocab at 0x1125a4710>,
#  'tuku[acquire]V/t': <gensim.models.keyedvectors.Vocab at 0x1125a4748>,
#  'gur[unit]N': <gensim.models.keyedvectors.Vocab at 0x1125a4780>,
#  'idu[doorkeeper]N': <gensim.models.keyedvectors.Vocab at 0x1125a47b8>,
#  'ur-dumu-nun': <gensim.models.keyedvectors.Vocab at 0x1125a47f0>,
#  'niŋir[herald]N': <gensim.models.keyedvectors.Vocab at 0x1125a4828>,
#  'ama-bur-ra': <gensim.models.keyedvectors.Vocab at 0x1125a4860>,
#  'sug[replace]V/t': <gensim.models.keyedvectors.Vocab at 0x1125a4898>,
#  'e₂-ki-ba': <gensim.models.keyedvectors.Vocab at 0x1125a48d0>,
#  'šagia[cup-bearer]N': <gensim.models.keyedvectors.Vocab at 0x1125a4908>,
#  'ša₃-ta-nu-e₃': <gensim.models.keyedvectors.Vocab at 0x1125a4940>,
#  'a-nun-{d}sud₃-da': <gensim.models.keyedvectors.Vocab at 0x1125a4978>,
#  'munumud[maltster]N': <gensim.models.keyedvectors.Vocab at 0x1125a49b0>,
#  'me-lam₂-kur-ra': <gensim.models.keyedvectors.Vocab at 0x1125a49e8>,
#  'ur-{d}tu': <gensim.models.keyedvectors.Vocab at 0x1125a4a20>,
#  'lugal-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x1125a4a58>,
#  'e₂-nu-kur-si': <gensim.models.keyedvectors.Vocab at 0x1125a4a90>,
#  'lu₂-lum-ma': <gensim.models.keyedvectors.Vocab at 0x1125a4ac8>,
#  'tul₂-sag-du₁₀': <gensim.models.keyedvectors.Vocab at 0x1125a4b00>,
#  'ugula-sukkal': <gensim.models.keyedvectors.Vocab at 0x1125a4b38>,
#  'šeš[brother]N': <gensim.models.keyedvectors.Vocab at 0x1125a4b70>,
#  'ur-nigin₃-si': <gensim.models.keyedvectors.Vocab at 0x1125a4ba8>,
#  'utu-ur-sag': <gensim.models.keyedvectors.Vocab at 0x1125a4be0>,
#  'unug{ki}': <gensim.models.keyedvectors.Vocab at 0x1125a4c18>,
#  'nin[lady]N': <gensim.models.keyedvectors.Vocab at 0x1125a4c50>,
#  'pa₄-nu-la₂': <gensim.models.keyedvectors.Vocab at 0x1125a4c88>,
#  'UR-UR': <gensim.models.keyedvectors.Vocab at 0x1125a4cf8>,
#  'e₂-nu-si': <gensim.models.keyedvectors.Vocab at 0x1125a4d30>,
#  'gurmah[unit]N': <gensim.models.keyedvectors.Vocab at 0x1125a4d68>,
#  'ur-{d}nu-muš-da': <gensim.models.keyedvectors.Vocab at 0x1125a4da0>,
#  'lal[syrup]N': <gensim.models.keyedvectors.Vocab at 0x1125a4dd8>,
#  'abzu-ki-du₁₀': <gensim.models.keyedvectors.Vocab at 0x1125a4e10>,
#  'bara₂-ki-ba': <gensim.models.keyedvectors.Vocab at 0x1125a4e48>,
#  'ur-utu': <gensim.models.keyedvectors.Vocab at 0x1125a4eb8>,
#  '1/2(aš@c)': <gensim.models.keyedvectors.Vocab at 0x1125a4ef0>,
#  'AK-{d}NE': <gensim.models.keyedvectors.Vocab at 0x1125a4f28>,
#  'uru[flood]N': <gensim.models.keyedvectors.Vocab at 0x1125a4f60>,
#  '{d}sud₃-anzu': <gensim.models.keyedvectors.Vocab at 0x1125a4f98>,
#  'NI-NI': <gensim.models.keyedvectors.Vocab at 0x1125ba048>,
#  'maš-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x1125ba080>,
#  'sikil[pure]V/i': <gensim.models.keyedvectors.Vocab at 0x1125ba0b8>,
#  'munus-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x1125ba0f0>,
#  'SAL.UŠ[sheath]N': <gensim.models.keyedvectors.Vocab at 0x1125ba128>,
#  'mes-pa₃': <gensim.models.keyedvectors.Vocab at 0x1125ba160>,
#  'ba-dag': <gensim.models.keyedvectors.Vocab at 0x1125ba1d0>,
#  'a-geštin': <gensim.models.keyedvectors.Vocab at 0x1125ba208>,
#  'damgar[merchant]N': <gensim.models.keyedvectors.Vocab at 0x1125ba240>,
#  'AN-sag-tuku': <gensim.models.keyedvectors.Vocab at 0x1125ba278>,
#  'amar-AN': <gensim.models.keyedvectors.Vocab at 0x1125ba2e8>,
#  'adab{ki}': <gensim.models.keyedvectors.Vocab at 0x1125ba320>,
#  'nibru{ki}': <gensim.models.keyedvectors.Vocab at 0x1125ba358>,
#  'umma{ki}': <gensim.models.keyedvectors.Vocab at 0x1125ba390>,
#  'azu[doctor]N': <gensim.models.keyedvectors.Vocab at 0x1125ba3c8>,
#  'a-si₄': <gensim.models.keyedvectors.Vocab at 0x1125ba400>,
#  'geš-DUL₃': <gensim.models.keyedvectors.Vocab at 0x1125ba438>,
#  'ar₃-du₂-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x1125ba470>,
#  'gi₄-za₇': <gensim.models.keyedvectors.Vocab at 0x1125ba4a8>,
#  'edin-si': <gensim.models.keyedvectors.Vocab at 0x1125ba518>,
#  'ur-{d}gu₂-la₂': <gensim.models.keyedvectors.Vocab at 0x1125ba550>,
#  'KA-lugal-da-zi': <gensim.models.keyedvectors.Vocab at 0x1125ba588>,
#  'dingir-nu-me': <gensim.models.keyedvectors.Vocab at 0x1125ba5c0>,
#  'diŋir[deity]N': <gensim.models.keyedvectors.Vocab at 0x1125ba5f8>,
#  'dumu-nun-šita': <gensim.models.keyedvectors.Vocab at 0x1125ba630>,
#  'ba-ba': <gensim.models.keyedvectors.Vocab at 0x1125ba6a0>,
#  'x-zi-x': <gensim.models.keyedvectors.Vocab at 0x1125ba710>,
#  'KA-zi': <gensim.models.keyedvectors.Vocab at 0x1125ba780>,
#  'e₂-sahar-ta-e₃': <gensim.models.keyedvectors.Vocab at 0x1125ba7b8>,
#  'šu[hand]N': <gensim.models.keyedvectors.Vocab at 0x1125ba7f0>,
#  'ar₃-du₂': <gensim.models.keyedvectors.Vocab at 0x1125ba828>,
#  'šag[heart]N': <gensim.models.keyedvectors.Vocab at 0x1125ba860>,
#  'dingir-ur-sag': <gensim.models.keyedvectors.Vocab at 0x1125ba898>,
#  'i₃-li₂-a': <gensim.models.keyedvectors.Vocab at 0x1125ba8d0>,
#  'nam-mah₂': <gensim.models.keyedvectors.Vocab at 0x1125ba908>,
#  'ursaŋ[hero]N': <gensim.models.keyedvectors.Vocab at 0x1125ba940>,
#  'KISAL': <gensim.models.keyedvectors.Vocab at 0x1125ba9b0>,
#  'niŋ[thing]N': <gensim.models.keyedvectors.Vocab at 0x1125ba9e8>,
#  'umma[old-woman]N': <gensim.models.keyedvectors.Vocab at 0x1125baa20>,
#  '{d}sud₃-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x1125baa58>,
#  '4(u@c)': <gensim.models.keyedvectors.Vocab at 0x1125baac8>,
#  '1(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x1125bab00>,
#  'lul[false]V/i': <gensim.models.keyedvectors.Vocab at 0x1125bab38>,
#  'lu-lu': <gensim.models.keyedvectors.Vocab at 0x1125baba8>,
#  'eden-si': <gensim.models.keyedvectors.Vocab at 0x1125bac18>,
#  'nimgir-mete-na': <gensim.models.keyedvectors.Vocab at 0x1125bac50>,
#  'sanga-GAR': <gensim.models.keyedvectors.Vocab at 0x1125bac88>,
#  'e₂-ušum-gal': <gensim.models.keyedvectors.Vocab at 0x1125bacc0>,
#  'e₂-hur-sag': <gensim.models.keyedvectors.Vocab at 0x1125bacf8>,
#  'nam-mah-{d}sud₃-da': <gensim.models.keyedvectors.Vocab at 0x1125bad30>,
#  'amar-abzu': <gensim.models.keyedvectors.Vocab at 0x1125bad68>,
#  'a-du₆-la': <gensim.models.keyedvectors.Vocab at 0x1125bada0>,
#  'KU-sag': <gensim.models.keyedvectors.Vocab at 0x1125bae10>,
#  'AK-du₆': <gensim.models.keyedvectors.Vocab at 0x1125bae48>,
#  'ama-ig-gal': <gensim.models.keyedvectors.Vocab at 0x1125bae80>,
#  'al₆-la': <gensim.models.keyedvectors.Vocab at 0x1125baeb8>,
#  'šul-la': <gensim.models.keyedvectors.Vocab at 0x1125baef0>,
#  'pa₄-ur-sag': <gensim.models.keyedvectors.Vocab at 0x1125baf28>,
#  'za-ra': <gensim.models.keyedvectors.Vocab at 0x1125baf98>,
#  'gissu-še₃': <gensim.models.keyedvectors.Vocab at 0x1125bafd0>,
#  'lu₂-pa₃': <gensim.models.keyedvectors.Vocab at 0x112b36048>,
#  'ensi₂-GAR-gal': <gensim.models.keyedvectors.Vocab at 0x112b36080>,
#  'AŠ': <gensim.models.keyedvectors.Vocab at 0x112b360b8>,
#  'ur-lugal-DU': <gensim.models.keyedvectors.Vocab at 0x112b360f0>,
#  'gal-kinda₂': <gensim.models.keyedvectors.Vocab at 0x112b36128>,
#  'muhaldim[cook]N': <gensim.models.keyedvectors.Vocab at 0x112b36160>,
#  'SUR-gu-nun': <gensim.models.keyedvectors.Vocab at 0x112b36198>,
#  '{d}gibil₆': <gensim.models.keyedvectors.Vocab at 0x112b361d0>,
#  'gal-unken': <gensim.models.keyedvectors.Vocab at 0x112b36208>,
#  'kur[different]V/i': <gensim.models.keyedvectors.Vocab at 0x112b36240>,
#  'pa-e₃': <gensim.models.keyedvectors.Vocab at 0x112b36278>,
#  'x-ra': <gensim.models.keyedvectors.Vocab at 0x112b362e8>,
#  'enku{ku₆}': <gensim.models.keyedvectors.Vocab at 0x112b36320>,
#  'lumagur[boatman]N': <gensim.models.keyedvectors.Vocab at 0x112b36358>,
#  'dubsarmah[official]N': <gensim.models.keyedvectors.Vocab at 0x112b36390>,
#  '3(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x112b363c8>,
#  'ur-dumu-zi-da': <gensim.models.keyedvectors.Vocab at 0x112b36400>,
#  'lu₂-bara₂-si': <gensim.models.keyedvectors.Vocab at 0x112b36438>,
#  'mah[great]V/i': <gensim.models.keyedvectors.Vocab at 0x112b36470>,
#  'maškim-gi₄': <gensim.models.keyedvectors.Vocab at 0x112b364a8>,
#  'gu-ni-DU': <gensim.models.keyedvectors.Vocab at 0x112b364e0>,
#  'ugulaʾek[overseer]N': <gensim.models.keyedvectors.Vocab at 0x112b36518>,
#  'nargal[musician]N': <gensim.models.keyedvectors.Vocab at 0x112b36550>,
#  'AB': <gensim.models.keyedvectors.Vocab at 0x112b365c0>,
#  '{d}en-lil₂': <gensim.models.keyedvectors.Vocab at 0x112b365f8>,
#  'šugi[senior]N': <gensim.models.keyedvectors.Vocab at 0x112b36630>,
#  'lu₂-e₂-zi': <gensim.models.keyedvectors.Vocab at 0x112b36668>,
#  'lugal-ezem': <gensim.models.keyedvectors.Vocab at 0x112b366a0>,
#  'e₂-UD-nu-dib': <gensim.models.keyedvectors.Vocab at 0x112b366d8>,
#  'sa-HAR': <gensim.models.keyedvectors.Vocab at 0x112b36748>,
#  'dar[split]V/t': <gensim.models.keyedvectors.Vocab at 0x112b36780>,
#  'e₂-ki-gal-la': <gensim.models.keyedvectors.Vocab at 0x112b367b8>,
#  'AK-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x112b367f0>,
#  'ekur[prison]N': <gensim.models.keyedvectors.Vocab at 0x112b36828>,
#  'AN': <gensim.models.keyedvectors.Vocab at 0x112b36898>,
#  'zi₃@t': <gensim.models.keyedvectors.Vocab at 0x112b368d0>,
#  'ba[animal]N': <gensim.models.keyedvectors.Vocab at 0x112b36908>,
#  '6(barig@c)': <gensim.models.keyedvectors.Vocab at 0x112b36940>,
#  'sila[unit]N': <gensim.models.keyedvectors.Vocab at 0x112b36978>,
#  'teŋ[approach]V/i': <gensim.models.keyedvectors.Vocab at 0x112b369b0>,
#  'utu-di-ku₅': <gensim.models.keyedvectors.Vocab at 0x112b369e8>,
#  'amar-e₂-gibil': <gensim.models.keyedvectors.Vocab at 0x112b36a20>,
#  'mušlah[charmer]N': <gensim.models.keyedvectors.Vocab at 0x112b36a58>,
#  'amar-{d}iškur': <gensim.models.keyedvectors.Vocab at 0x112b36a90>,
#  'ur-tul₂-sag': <gensim.models.keyedvectors.Vocab at 0x112b36ac8>,
#  'pa-bilₓ(|GIŠ.PAP.NE|)-ga': <gensim.models.keyedvectors.Vocab at 0x112b36b00>,
#  'me-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x112b36b38>,
#  'e₂-u₂': <gensim.models.keyedvectors.Vocab at 0x112b36b70>,
#  'u₄-kur-ra': <gensim.models.keyedvectors.Vocab at 0x112b36ba8>,
#  'amar-{d}tu': <gensim.models.keyedvectors.Vocab at 0x112b36be0>,
#  'mes-nu-še₃': <gensim.models.keyedvectors.Vocab at 0x112b36c18>,
#  '{d}sud₃-da-zi': <gensim.models.keyedvectors.Vocab at 0x112b36c50>,
#  'addirₓ(|LAK589.A.SI|)': <gensim.models.keyedvectors.Vocab at 0x112b36c88>,
#  '{d}en-lil₂-unken-a': <gensim.models.keyedvectors.Vocab at 0x112b36cc0>,
#  'šita-KAL': <gensim.models.keyedvectors.Vocab at 0x112b36cf8>,
#  'a-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x112b36d30>,
#  'a-NI': <gensim.models.keyedvectors.Vocab at 0x112b36da0>,
#  'ur-{d}en-ki': <gensim.models.keyedvectors.Vocab at 0x112b36dd8>,
#  'e₂-du₆': <gensim.models.keyedvectors.Vocab at 0x112b36e10>,
#  'ki-ni-du₁₀': <gensim.models.keyedvectors.Vocab at 0x112b36e48>,
#  'bilₓ(|GIŠ.PAP.NE|)-kalam-du₁₀': <gensim.models.keyedvectors.Vocab at 0x112b36e80>,
#  'e₂-{d}anzu': <gensim.models.keyedvectors.Vocab at 0x112b36eb8>,
#  'utu-ki-gal': <gensim.models.keyedvectors.Vocab at 0x112b36ef0>,
#  'UŠ': <gensim.models.keyedvectors.Vocab at 0x112b36f28>,
#  'en-nam-zu₅-še₃': <gensim.models.keyedvectors.Vocab at 0x112b36f60>,
#  'e₂-na-lu-lu': <gensim.models.keyedvectors.Vocab at 0x112b36f98>,
#  'lu₂-{giš}BULUG₃': <gensim.models.keyedvectors.Vocab at 0x112b36fd0>,
#  'e₂-nun-KA': <gensim.models.keyedvectors.Vocab at 0x112b5c048>,
#  'mes-u₄-ba': <gensim.models.keyedvectors.Vocab at 0x112b5c080>,
#  'zig[rise]V/t': <gensim.models.keyedvectors.Vocab at 0x112b5c0b8>,
#  'kur-ra-a₂-gal₂': <gensim.models.keyedvectors.Vocab at 0x112b5c0f0>,
#  'ni₂-zu₅-kur-še₃': <gensim.models.keyedvectors.Vocab at 0x112b5c128>,
#  'a-hu-ti': <gensim.models.keyedvectors.Vocab at 0x112b5c198>,
#  'pa₄-{d}anzu': <gensim.models.keyedvectors.Vocab at 0x112b5c1d0>,
#  'šita-kalam': <gensim.models.keyedvectors.Vocab at 0x112b5c208>,
#  'ur-{d}en-lil₂': <gensim.models.keyedvectors.Vocab at 0x112b5c240>,
#  'ludag[official]N': <gensim.models.keyedvectors.Vocab at 0x112b5c278>,
#  'e₂-{d}nanna': <gensim.models.keyedvectors.Vocab at 0x112b5c2b0>,
#  'KA-ni-zi': <gensim.models.keyedvectors.Vocab at 0x112b5c2e8>,
#  'ba-za₇': <gensim.models.keyedvectors.Vocab at 0x112b5c320>,
#  'aya[father]N': <gensim.models.keyedvectors.Vocab at 0x112b5c358>,
#  'dub-hul-tar': <gensim.models.keyedvectors.Vocab at 0x112b5c390>,
#  'mes-ni₃-lul-le': <gensim.models.keyedvectors.Vocab at 0x112b5c3c8>,
#  'udu[sheep]N': <gensim.models.keyedvectors.Vocab at 0x112b5c400>,
#  'lugal-zi-kalam': <gensim.models.keyedvectors.Vocab at 0x112b5c438>,
#  'UR': <gensim.models.keyedvectors.Vocab at 0x112b5c4a8>,
#  'nig₂-pa₃-da': <gensim.models.keyedvectors.Vocab at 0x112b5c4e0>,
#  'uzud[goat]N': <gensim.models.keyedvectors.Vocab at 0x112b5c518>,
#  'aktum[garment]N': <gensim.models.keyedvectors.Vocab at 0x112b5c550>,
#  'tug[textile]N': <gensim.models.keyedvectors.Vocab at 0x112b5c588>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x112b5c5c0>,
#  'ur-{d}nin-mu₂': <gensim.models.keyedvectors.Vocab at 0x112b5c5f8>,
#  'sa[pay-for]V/t': <gensim.models.keyedvectors.Vocab at 0x112b5c630>,
#  'lugal-x-x': <gensim.models.keyedvectors.Vocab at 0x112b5c668>,
#  'ki-inim': <gensim.models.keyedvectors.Vocab at 0x112b5c6d8>,
#  'ara₃': <gensim.models.keyedvectors.Vocab at 0x112b5c710>,
#  'me-an-ne₂-si': <gensim.models.keyedvectors.Vocab at 0x112b5c748>,
#  'zabar[bronze]N': <gensim.models.keyedvectors.Vocab at 0x112b5c780>,
#  'gamgam[fish]N': <gensim.models.keyedvectors.Vocab at 0x112b5c7b8>,
#  'ak[do]V/t': <gensim.models.keyedvectors.Vocab at 0x112b5c7f0>,
#  'KA-ki-bi-še₃': <gensim.models.keyedvectors.Vocab at 0x112b5c828>,
#  'nig₂-hu-bu₇{bu}': <gensim.models.keyedvectors.Vocab at 0x112b5c860>,
#  'ki-ni': <gensim.models.keyedvectors.Vocab at 0x112b5c8d0>,
#  'kun-du₆': <gensim.models.keyedvectors.Vocab at 0x112b5c908>,
#  'šukud[fisherman]N': <gensim.models.keyedvectors.Vocab at 0x112b5c940>,
#  '2/4(aš@c)': <gensim.models.keyedvectors.Vocab at 0x112b5c978>,
#  'x-si': <gensim.models.keyedvectors.Vocab at 0x112b5c9e8>,
#  'gukkal[sheep]N': <gensim.models.keyedvectors.Vocab at 0x112b5ca20>,
#  'en-x-x': <gensim.models.keyedvectors.Vocab at 0x112b5ca90>,
#  'giŋ[unit]N': <gensim.models.keyedvectors.Vocab at 0x112b5cac8>,
#  'sar[garden]N': <gensim.models.keyedvectors.Vocab at 0x112b5cb00>,
#  'niŋdirig[extra]N': <gensim.models.keyedvectors.Vocab at 0x112b5cb38>,
#  'du[build]V/t': <gensim.models.keyedvectors.Vocab at 0x112b5cb70>,
#  'niŋba[gift]N': <gensim.models.keyedvectors.Vocab at 0x112b5cba8>,
#  'siki[hair]N': <gensim.models.keyedvectors.Vocab at 0x112b5cbe0>,
#  'gug[cake]N': <gensim.models.keyedvectors.Vocab at 0x112b5cc18>,
#  'kur[unit]N': <gensim.models.keyedvectors.Vocab at 0x112b5cc50>,
#  'tu₇(|HI×AŠ@c|)': <gensim.models.keyedvectors.Vocab at 0x112b5cc88>,
#  '|LAGAB×(HA.A)|': <gensim.models.keyedvectors.Vocab at 0x112b5ccc0>,
#  'i[oil]N': <gensim.models.keyedvectors.Vocab at 0x112b5cd30>,
#  'nin-a-zu': <gensim.models.keyedvectors.Vocab at 0x112b5cd68>,
#  'il[raise]V/t': <gensim.models.keyedvectors.Vocab at 0x112b5cda0>,
#  'tu[soup]N': <gensim.models.keyedvectors.Vocab at 0x112b5cdd8>,
#  'e₂-ur₂-bi-du₁₀': <gensim.models.keyedvectors.Vocab at 0x112b5ce10>,
#  'giri₃-ni-ba-dab₅': <gensim.models.keyedvectors.Vocab at 0x112b5ce48>,
#  'RI-ti': <gensim.models.keyedvectors.Vocab at 0x112b5ceb8>,
#  'kigu[~land]N': <gensim.models.keyedvectors.Vocab at 0x112b5cef0>,
#  'ur-abzu': <gensim.models.keyedvectors.Vocab at 0x112b5cf60>,
#  'ki-ni-mu-zu': <gensim.models.keyedvectors.Vocab at 0x112b5cf98>,
#  'me-an-ne₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x112b5cfd0>,
#  'ur-{d}inanna': <gensim.models.keyedvectors.Vocab at 0x10f6f2048>,
#  'ummia[expert]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2080>,
#  'ŋar[place]V/t': <gensim.models.keyedvectors.Vocab at 0x10f6f20b8>,
#  'da-da': <gensim.models.keyedvectors.Vocab at 0x10f6f2128>,
#  'sila[street]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2160>,
#  'gan-ezem': <gensim.models.keyedvectors.Vocab at 0x10f6f2198>,
#  'gallagal[policeman]N': <gensim.models.keyedvectors.Vocab at 0x10f6f21d0>,
#  'bala[turn]V/t': <gensim.models.keyedvectors.Vocab at 0x10f6f2208>,
#  'AK-nab': <gensim.models.keyedvectors.Vocab at 0x10f6f2278>,
#  'ŠEŠ-KI-na': <gensim.models.keyedvectors.Vocab at 0x10f6f22b0>,
#  'e₂-ezem-du₁₀': <gensim.models.keyedvectors.Vocab at 0x10f6f22e8>,
#  'nin-sun₂-zi': <gensim.models.keyedvectors.Vocab at 0x10f6f2320>,
#  'GUR₈': <gensim.models.keyedvectors.Vocab at 0x10f6f2358>,
#  'mes-e₂-zi-da': <gensim.models.keyedvectors.Vocab at 0x10f6f2390>,
#  'amar-KID-NUN': <gensim.models.keyedvectors.Vocab at 0x10f6f23c8>,
#  'šeš-pa₃': <gensim.models.keyedvectors.Vocab at 0x10f6f2400>,
#  'en-guruš-zi': <gensim.models.keyedvectors.Vocab at 0x10f6f2438>,
#  'gugal[inspector]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2470>,
#  'luma[boatman]N': <gensim.models.keyedvectors.Vocab at 0x10f6f24a8>,
#  '{an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x10f6f24e0>,
#  'ur₂-x': <gensim.models.keyedvectors.Vocab at 0x10f6f2518>,
#  'e₂-sahar': <gensim.models.keyedvectors.Vocab at 0x10f6f2550>,
#  'ta': <gensim.models.keyedvectors.Vocab at 0x10f6f25c0>,
#  '{d}sud₃-anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x10f6f25f8>,
#  'utu-nu-me': <gensim.models.keyedvectors.Vocab at 0x10f6f2630>,
#  'x-NI': <gensim.models.keyedvectors.Vocab at 0x10f6f26a0>,
#  'tugdu[felter]N': <gensim.models.keyedvectors.Vocab at 0x10f6f26d8>,
#  'pa-bilₓ(|PAP.GEŠ.BIL|)-ga': <gensim.models.keyedvectors.Vocab at 0x10f6f2710>,
#  'za₇-gin₃': <gensim.models.keyedvectors.Vocab at 0x10f6f2748>,
#  'gu[pulse]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2780>,
#  'gal-dam-gar₃': <gensim.models.keyedvectors.Vocab at 0x10f6f27b8>,
#  '{d}PA': <gensim.models.keyedvectors.Vocab at 0x10f6f2828>,
#  'saŋ[head]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2860>,
#  'us[side]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2898>,
#  'saŋdu[beam]N': <gensim.models.keyedvectors.Vocab at 0x10f6f28d0>,
#  'dalla[ring]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2908>,
#  'su₆-mu₂': <gensim.models.keyedvectors.Vocab at 0x10f6f2940>,
#  'ba[allot]V/t': <gensim.models.keyedvectors.Vocab at 0x10f6f2978>,
#  'atu[doorkeeper?]N': <gensim.models.keyedvectors.Vocab at 0x10f6f29b0>,
#  'mun[salt]V/i': <gensim.models.keyedvectors.Vocab at 0x10f6f29e8>,
#  'ur[pluck]V/t': <gensim.models.keyedvectors.Vocab at 0x10f6f2a20>,
#  'dam[spouse]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2a58>,
#  'be₆-li₂-li₂': <gensim.models.keyedvectors.Vocab at 0x10f6f2a90>,
#  'geme[worker]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2ac8>,
#  '{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x10f6f2b00>,
#  'ša₃-zu': <gensim.models.keyedvectors.Vocab at 0x10f6f2b38>,
#  'kinud[bedroom]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2b70>,
#  'ur-{d}nin-PA': <gensim.models.keyedvectors.Vocab at 0x10f6f2ba8>,
#  'na-na': <gensim.models.keyedvectors.Vocab at 0x10f6f2c18>,
#  '1(aš@v)': <gensim.models.keyedvectors.Vocab at 0x10f6f2c50>,
#  'x-x-x': <gensim.models.keyedvectors.Vocab at 0x10f6f2cc0>,
#  'allub[crab]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2cf8>,
#  'pa': <gensim.models.keyedvectors.Vocab at 0x10f6f2d68>,
#  'ezem[festival]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2da0>,
#  'bahar₂': <gensim.models.keyedvectors.Vocab at 0x10f6f2dd8>,
#  'ma': <gensim.models.keyedvectors.Vocab at 0x10f6f2e48>,
#  'ki[place]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2e80>,
#  'niŋsi[provisions]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2eb8>,
#  'kuš[skin]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2ef0>,
#  'si[horn]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2f28>,
#  'kur[mountain]N': <gensim.models.keyedvectors.Vocab at 0x10f6f2f60>,
#  'maš-da₅': <gensim.models.keyedvectors.Vocab at 0x10f6f2f98>,
#  'zir[break]V/t': <gensim.models.keyedvectors.Vocab at 0x10f6f2fd0>,
#  'aš-ni': <gensim.models.keyedvectors.Vocab at 0x10f7de048>,
#  'e₂-la-lumₓ(LAK218)': <gensim.models.keyedvectors.Vocab at 0x10f7de080>,
#  'amar-IMMAL': <gensim.models.keyedvectors.Vocab at 0x10f7de0b8>,
#  'nag-su': <gensim.models.keyedvectors.Vocab at 0x10f7de128>,
#  'AN-ur₂-še₃': <gensim.models.keyedvectors.Vocab at 0x10f7de160>,
#  'azlag₄': <gensim.models.keyedvectors.Vocab at 0x10f7de198>,
#  'za₃-ta': <gensim.models.keyedvectors.Vocab at 0x10f7de1d0>,
#  'lugal-ki-tuš-du₁₀': <gensim.models.keyedvectors.Vocab at 0x10f7de208>,
#  'lugal-dumu-zi': <gensim.models.keyedvectors.Vocab at 0x10f7de240>,
#  'aša₅': <gensim.models.keyedvectors.Vocab at 0x10f7de278>,
#  'al₆-lu-lu': <gensim.models.keyedvectors.Vocab at 0x10f7de2b0>,
#  '5(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x10f7de2e8>,
#  '5(diš@t)': <gensim.models.keyedvectors.Vocab at 0x10f7de320>,
#  'šidim[builder]N': <gensim.models.keyedvectors.Vocab at 0x10f7de358>,
#  'lugal-ki-gal-la': <gensim.models.keyedvectors.Vocab at 0x10f7de390>,
#  'ama-x': <gensim.models.keyedvectors.Vocab at 0x10f7de400>,
#  'ga-x': <gensim.models.keyedvectors.Vocab at 0x10f7de470>,
#  '7(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x10f7de4a8>,
#  'sag-nin-tuku': <gensim.models.keyedvectors.Vocab at 0x10f7de4e0>,
#  'nin-ama-na': <gensim.models.keyedvectors.Vocab at 0x10f7de518>,
#  'geš-kin': <gensim.models.keyedvectors.Vocab at 0x10f7de550>,
#  'lugal[king]N': <gensim.models.keyedvectors.Vocab at 0x10f7de588>,
#  'šešbanda[relation]N': <gensim.models.keyedvectors.Vocab at 0x10f7de5c0>,
#  '2(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x10f7de5f8>,
#  'lugal-bara₂-si': <gensim.models.keyedvectors.Vocab at 0x10f7de630>,
#  '5(u@c)': <gensim.models.keyedvectors.Vocab at 0x10f7de6a0>,
#  'e₂-zi-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x10f7de6d8>,
#  'UD': <gensim.models.keyedvectors.Vocab at 0x10f7de748>,
#  'x-du₁₀': <gensim.models.keyedvectors.Vocab at 0x10f7de780>,
#  '6(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x10f7de7b8>,
#  'kuli[unit]N': <gensim.models.keyedvectors.Vocab at 0x10f7de7f0>,
#  'gišgal-si': <gensim.models.keyedvectors.Vocab at 0x10f7de828>,
#  '2(gešʾu@c)': <gensim.models.keyedvectors.Vocab at 0x10f7de860>,
#  'si-|NU×U|': <gensim.models.keyedvectors.Vocab at 0x10f7de898>,
#  'ensi₂-GAR': <gensim.models.keyedvectors.Vocab at 0x10f7de8d0>,
#  'en[priest]N': <gensim.models.keyedvectors.Vocab at 0x10f7de908>,
#  'kinda[barber]N': <gensim.models.keyedvectors.Vocab at 0x10f7de940>,
#  'niŋara[groats]N': <gensim.models.keyedvectors.Vocab at 0x10f7de978>,
#  '{d}en-lil₂-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x10f7de9b0>,
#  'lu₂-na-nam': <gensim.models.keyedvectors.Vocab at 0x10f7de9e8>,
#  'pa₄-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x10f7dea20>,
#  'sag-TAR': <gensim.models.keyedvectors.Vocab at 0x10f7dea90>,
#  '{d}suen': <gensim.models.keyedvectors.Vocab at 0x10f7deb00>,
#  'e₂-x': <gensim.models.keyedvectors.Vocab at 0x10f7deb38>,
#  'lugal-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x10f7deb70>,
#  'lugal-ki-dur₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x10f7deba8>,
#  'amar[young]N': <gensim.models.keyedvectors.Vocab at 0x10f7debe0>,
#  '{d}ŠEŠ-KI-na': <gensim.models.keyedvectors.Vocab at 0x10f7dec18>,
#  'a-x-x': <gensim.models.keyedvectors.Vocab at 0x10f7dec88>,
#  'AN-URUDU-si': <gensim.models.keyedvectors.Vocab at 0x10f7decc0>,
#  'du[go]V/t': <gensim.models.keyedvectors.Vocab at 0x10f7decf8>,
#  'e₂-kur-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x10f7ded30>,
#  '{d}sud₃-nu-me': <gensim.models.keyedvectors.Vocab at 0x10f7ded68>,
#  'ab-ba-ni': <gensim.models.keyedvectors.Vocab at 0x10f7deda0>,
#  'amar-KID-nun': <gensim.models.keyedvectors.Vocab at 0x10f7dedd8>,
#  'sila[lamb]N': <gensim.models.keyedvectors.Vocab at 0x10f7dee10>,
#  'nita[male]N': <gensim.models.keyedvectors.Vocab at 0x10f7dee48>,
#  'LAK020[goat]N': <gensim.models.keyedvectors.Vocab at 0x10f7dee80>,
#  'u[ewe]N': <gensim.models.keyedvectors.Vocab at 0x10f7deef0>,
#  'utu-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x10f7def28>,
#  'tur[small]V/i': <gensim.models.keyedvectors.Vocab at 0x10f7def60>,
#  'AN-AK': <gensim.models.keyedvectors.Vocab at 0x10f7defd0>,
#  'ur-{d}dumu-zi': <gensim.models.keyedvectors.Vocab at 0x10f8e0048>,
#  '|SUR.GU|': <gensim.models.keyedvectors.Vocab at 0x10f8e0080>,
#  'nin-da-mah-di': <gensim.models.keyedvectors.Vocab at 0x10f8e00b8>,
#  'ur-{d}nin-pirig': <gensim.models.keyedvectors.Vocab at 0x10f8e00f0>,
#  'igi-ildu₃-še₃@90': <gensim.models.keyedvectors.Vocab at 0x10f8e0128>,
#  'lugal-si-sa₂': <gensim.models.keyedvectors.Vocab at 0x10f8e0160>,
#  'ab-ba-tur': <gensim.models.keyedvectors.Vocab at 0x10f8e0198>,
#  'ku₃-la₂': <gensim.models.keyedvectors.Vocab at 0x10f8e01d0>,
#  'lugal-šeš': <gensim.models.keyedvectors.Vocab at 0x10f8e0208>,
#  'lugal-an-dul₃': <gensim.models.keyedvectors.Vocab at 0x10f8e0240>,
#  'dingir-a-zu': <gensim.models.keyedvectors.Vocab at 0x10f8e0278>,
#  'lugal-e₂-ni-še₃': <gensim.models.keyedvectors.Vocab at 0x10f8e02b0>,
#  'ša₃-nu-gal₂': <gensim.models.keyedvectors.Vocab at 0x10f8e02e8>,
#  'e₂-šeš': <gensim.models.keyedvectors.Vocab at 0x10f8e0320>,
#  'lugal-sa₆-ga': <gensim.models.keyedvectors.Vocab at 0x10f8e0358>,
#  'gal[big]V/i': <gensim.models.keyedvectors.Vocab at 0x10f8e0390>,
#  '2(gešmin@c)': <gensim.models.keyedvectors.Vocab at 0x10f8e03c8>,
#  'baza[dwarf]N': <gensim.models.keyedvectors.Vocab at 0x10f8e0400>,
#  'la[hang]V/t': <gensim.models.keyedvectors.Vocab at 0x10f8e0438>,
#  'ur-x-x': <gensim.models.keyedvectors.Vocab at 0x10f8e04a8>,
#  'mu-kur-ta': <gensim.models.keyedvectors.Vocab at 0x10f8e04e0>,
#  'an-dab₆-si': <gensim.models.keyedvectors.Vocab at 0x10f8e0518>,
#  'x-nam': <gensim.models.keyedvectors.Vocab at 0x10f8e0588>,
#  'me-mah-nu-sa₂': <gensim.models.keyedvectors.Vocab at 0x10f8e05c0>,
#  'dub[tablet]N': <gensim.models.keyedvectors.Vocab at 0x10f8e05f8>,
#  'dili[single]V/i': <gensim.models.keyedvectors.Vocab at 0x10f8e0630>,
#  '3(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x10f8e0668>,
#  'magur[barge]N': <gensim.models.keyedvectors.Vocab at 0x10f8e06a0>,
#  'RU[~architecture]N': <gensim.models.keyedvectors.Vocab at 0x10f8e06d8>,
#  'ŋeškiŋti[workshop]N': <gensim.models.keyedvectors.Vocab at 0x10f8e0710>,
#  'zagšu[brand]N': <gensim.models.keyedvectors.Vocab at 0x10f8e0748>,
#  'lah[bring]V/t': <gensim.models.keyedvectors.Vocab at 0x10f8e0780>,
#  'iri[city]N': <gensim.models.keyedvectors.Vocab at 0x10f8e07b8>,
#  'ur-{d}eš-peš': <gensim.models.keyedvectors.Vocab at 0x10f8e07f0>,
#  '9(aš@c)': <gensim.models.keyedvectors.Vocab at 0x10f8e0828>,
#  'nita-tur': <gensim.models.keyedvectors.Vocab at 0x10f8e0860>,
#  '4(barig@c)': <gensim.models.keyedvectors.Vocab at 0x10f8e0898>,
#  'lam-ma': <gensim.models.keyedvectors.Vocab at 0x10f8e0908>,
#  'ašgar[kid]N': <gensim.models.keyedvectors.Vocab at 0x10f8e0940>,
#  'ibadu[garment]N': <gensim.models.keyedvectors.Vocab at 0x10f8e0978>,
#  '|GA₂×(HA.A)|': <gensim.models.keyedvectors.Vocab at 0x10f8e09b0>,
#  'ur-{d}nin-unu': <gensim.models.keyedvectors.Vocab at 0x10f8e09e8>,
#  'a-har-ši': <gensim.models.keyedvectors.Vocab at 0x10f8e0a20>,
#  'da-du-lul': <gensim.models.keyedvectors.Vocab at 0x10f8e0a58>,
#  'engar-us₂': <gensim.models.keyedvectors.Vocab at 0x10f8e0a90>,
#  'inim-{d}sud₃-da-zi': <gensim.models.keyedvectors.Vocab at 0x10f8e0ac8>,
#  'šeš-ama(LAK769)-na': <gensim.models.keyedvectors.Vocab at 0x10f8e0b00>,
#  'inim-ni-zi': <gensim.models.keyedvectors.Vocab at 0x10f8e0b38>,
#  'usan₃-du₃': <gensim.models.keyedvectors.Vocab at 0x10f8e0b70>,
#  'lu₂-x': <gensim.models.keyedvectors.Vocab at 0x10f8e0ba8>,
#  'me₃': <gensim.models.keyedvectors.Vocab at 0x10f8e0be0>,
#  'niŋgu[food]N': <gensim.models.keyedvectors.Vocab at 0x10f8e0c18>,
#  'gi₄-za': <gensim.models.keyedvectors.Vocab at 0x10f8e0c50>,
#  'amar-{d}šuba₃': <gensim.models.keyedvectors.Vocab at 0x10f8e0c88>,
#  'ki-nir': <gensim.models.keyedvectors.Vocab at 0x10f8e0cf8>,
#  'amar-{d}PA': <gensim.models.keyedvectors.Vocab at 0x10f8e0d30>,
#  'šul[youth]V/i': <gensim.models.keyedvectors.Vocab at 0x10f8e0d68>,
#  'a-du₇': <gensim.models.keyedvectors.Vocab at 0x10f8e0da0>,
#  'ur-NI': <gensim.models.keyedvectors.Vocab at 0x10f8e0e10>,
#  'a-NE-nu': <gensim.models.keyedvectors.Vocab at 0x10f8e0e80>,
#  'KA-lugal-zi-da': <gensim.models.keyedvectors.Vocab at 0x10f8e0eb8>,
#  'en-abzu-ta-mud': <gensim.models.keyedvectors.Vocab at 0x10f8e0ef0>,
#  'sangaₓ(|ŠID.NIG₂|)': <gensim.models.keyedvectors.Vocab at 0x10f8e0f28>,
#  'ensikgal[governor]N': <gensim.models.keyedvectors.Vocab at 0x10f8e0f60>,
#  'a-du₆': <gensim.models.keyedvectors.Vocab at 0x10f8e0f98>,
#  'lu₂-HAR': <gensim.models.keyedvectors.Vocab at 0x10f8e0fd0>,
#  '{d}ad-ašgi₂{gi₄}-ur-sag': <gensim.models.keyedvectors.Vocab at 0x10fab6048>,
#  'a-nun-pa₃': <gensim.models.keyedvectors.Vocab at 0x10fab6080>,
#  'lu₂-lal₃': <gensim.models.keyedvectors.Vocab at 0x10fab60b8>,
#  'MI': <gensim.models.keyedvectors.Vocab at 0x10fab6128>,
#  'e₂-du₇-du₇': <gensim.models.keyedvectors.Vocab at 0x10fab6160>,
#  'nig₂-gal₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x10fab6198>,
#  'AK-dingir': <gensim.models.keyedvectors.Vocab at 0x10fab61d0>,
#  'ašgabgal[leatherworker]N': <gensim.models.keyedvectors.Vocab at 0x10fab6208>,
#  'dabin[semolina]N': <gensim.models.keyedvectors.Vocab at 0x10fab6240>,
#  'bur-nun-si': <gensim.models.keyedvectors.Vocab at 0x10fab6278>,
#  'babbar[white]V/i': <gensim.models.keyedvectors.Vocab at 0x10fab62b0>,
#  'nida': <gensim.models.keyedvectors.Vocab at 0x10fab6320>,
#  'aslum[sheep]N': <gensim.models.keyedvectors.Vocab at 0x10fab6358>,
#  'AK-AN': <gensim.models.keyedvectors.Vocab at 0x10fab63c8>,
#  'mar[wagon]N': <gensim.models.keyedvectors.Vocab at 0x10fab6400>,
#  'šir-ezen': <gensim.models.keyedvectors.Vocab at 0x10fab6438>,
#  'ur-e₂': <gensim.models.keyedvectors.Vocab at 0x10fab6470>,
#  'ur-{d}TAG-nun': <gensim.models.keyedvectors.Vocab at 0x10fab64a8>,
#  'ga-ri': <gensim.models.keyedvectors.Vocab at 0x10fab6518>,
#  'lu₂-geme₂-zi': <gensim.models.keyedvectors.Vocab at 0x10fab6550>,
#  'LAK343': <gensim.models.keyedvectors.Vocab at 0x10fab65c0>,
#  'en-MU-du₁₀': <gensim.models.keyedvectors.Vocab at 0x10fab65f8>,
#  'ur-{d}lamma': <gensim.models.keyedvectors.Vocab at 0x10fab6630>,
#  'zum-da': <gensim.models.keyedvectors.Vocab at 0x10fab66a0>,
#  'ur-{d}{še₃}šer₇-da': <gensim.models.keyedvectors.Vocab at 0x10fab66d8>,
#  'gissu-bi': <gensim.models.keyedvectors.Vocab at 0x10fab6710>,
#  'a-nun-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x10fab6748>,
#  'lu₂-ninda₂': <gensim.models.keyedvectors.Vocab at 0x10fab6780>,
#  'galla[policeman]N': <gensim.models.keyedvectors.Vocab at 0x10fab67b8>,
#  'ša₃-TAR': <gensim.models.keyedvectors.Vocab at 0x10fab67f0>,
#  'gal-sagi': <gensim.models.keyedvectors.Vocab at 0x10fab6828>,
#  'bilₓ(|GIŠ.PAP.NE|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x10fab6860>,
#  'šenumun[seed]N': <gensim.models.keyedvectors.Vocab at 0x10fab6898>,
#  'kalam-du₁₀': <gensim.models.keyedvectors.Vocab at 0x10fab68d0>,
#  'kur-a₂-gal₂': <gensim.models.keyedvectors.Vocab at 0x10fab6908>,
#  'a-RI-ti': <gensim.models.keyedvectors.Vocab at 0x10fab6978>,
#  '2(burʾu@c)': <gensim.models.keyedvectors.Vocab at 0x10fab69b0>,
#  '2(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x10fab69e8>,
#  'gu₂-u₂': <gensim.models.keyedvectors.Vocab at 0x10fab6a20>,
#  'urtur[puppy]N': <gensim.models.keyedvectors.Vocab at 0x10fab6a58>,
#  'e₂-zi': <gensim.models.keyedvectors.Vocab at 0x10fab6a90>,
#  'mes-ki-erim₂': <gensim.models.keyedvectors.Vocab at 0x10fab6ac8>,
#  'x-ki': <gensim.models.keyedvectors.Vocab at 0x10fab6b38>,
#  'amar-{d}nam-nir': <gensim.models.keyedvectors.Vocab at 0x10fab6b70>,
#  'ni₂-kur-ra': <gensim.models.keyedvectors.Vocab at 0x10fab6ba8>,
#  'kiŋ[work]N': <gensim.models.keyedvectors.Vocab at 0x10fab6be0>,
#  'tur[stall]N': <gensim.models.keyedvectors.Vocab at 0x10fab6c18>,
#  'NA': <gensim.models.keyedvectors.Vocab at 0x10fab6c88>,
#  'anna[metal]N': <gensim.models.keyedvectors.Vocab at 0x10fab6cc0>,
#  'unken-a': <gensim.models.keyedvectors.Vocab at 0x10fab6d30>,
#  'ur-kin-nir': <gensim.models.keyedvectors.Vocab at 0x10fab6d68>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x10fab6da0>,
#  'ur-sipa': <gensim.models.keyedvectors.Vocab at 0x10fab6e10>,
#  'ba-zi': <gensim.models.keyedvectors.Vocab at 0x10fab6e80>,
#  'AN-x': <gensim.models.keyedvectors.Vocab at 0x10fab6ef0>,
#  'susig[flayer]N': <gensim.models.keyedvectors.Vocab at 0x10fab6f28>,
#  'a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x10fab6f60>,
#  'lugal-šembi₃': <gensim.models.keyedvectors.Vocab at 0x10fab6f98>,
#  'ur-nin': <gensim.models.keyedvectors.Vocab at 0x10fae5048>,
#  '1(diš@t)': <gensim.models.keyedvectors.Vocab at 0x10fae5080>,
#  'e₂-gissu-du₁₀': <gensim.models.keyedvectors.Vocab at 0x10fae50b8>,
#  'am[bull]N': <gensim.models.keyedvectors.Vocab at 0x10fae50f0>,
#  'ša₁₃-dub': <gensim.models.keyedvectors.Vocab at 0x10fae5128>,
#  'KA-x': <gensim.models.keyedvectors.Vocab at 0x10fae5198>,
#  'mes-nig₂-lul-le': <gensim.models.keyedvectors.Vocab at 0x10fae51d0>,
#  'šubur-x': <gensim.models.keyedvectors.Vocab at 0x10fae5208>,
#  'gudu₄': <gensim.models.keyedvectors.Vocab at 0x10fae5240>,
#  'ŋeš[tree]N': <gensim.models.keyedvectors.Vocab at 0x10fae5278>,
#  'DU-x': <gensim.models.keyedvectors.Vocab at 0x10fae52e8>,
#  'dul[cover]V/t': <gensim.models.keyedvectors.Vocab at 0x10fae5320>,
#  'balaₓ(LAK020)': <gensim.models.keyedvectors.Vocab at 0x10fae5358>,
#  '1/4(aš@c)': <gensim.models.keyedvectors.Vocab at 0x10fae5390>,
#  'DI': <gensim.models.keyedvectors.Vocab at 0x10fae5400>,
#  'tah[add]V/t': <gensim.models.keyedvectors.Vocab at 0x10fae5438>,
#  'en-kalam-du₁₀': <gensim.models.keyedvectors.Vocab at 0x10fae5470>,
#  'en-abzu-mud': <gensim.models.keyedvectors.Vocab at 0x10fae54a8>,
#  'pa₄-zi': <gensim.models.keyedvectors.Vocab at 0x10fae54e0>,
#  'dur-narₓ(LAK244)': <gensim.models.keyedvectors.Vocab at 0x10fae5518>,
#  'munus-{d}anzu': <gensim.models.keyedvectors.Vocab at 0x10fae5550>,
#  'UŠ-x': <gensim.models.keyedvectors.Vocab at 0x10fae5588>,
#  'a-ru': <gensim.models.keyedvectors.Vocab at 0x10fae55f8>,
#  'nin-bad₃': <gensim.models.keyedvectors.Vocab at 0x10fae5630>,
#  'pa₄-NAM₂': <gensim.models.keyedvectors.Vocab at 0x10fae5668>,
#  'ur-{d}aš₈-gi₄': <gensim.models.keyedvectors.Vocab at 0x10fae56a0>,
#  'gal-zadim': <gensim.models.keyedvectors.Vocab at 0x10fae56d8>,
#  'lagaš{ki}': <gensim.models.keyedvectors.Vocab at 0x10fae5710>,
#  'x-ur-sag': <gensim.models.keyedvectors.Vocab at 0x10fae5748>,
#  'iš-lul-il': <gensim.models.keyedvectors.Vocab at 0x10fae5780>,
#  'AN-ur-sag': <gensim.models.keyedvectors.Vocab at 0x10fae57b8>,
#  'ur-PA': <gensim.models.keyedvectors.Vocab at 0x10fae5828>,
#  'nin-unken-a': <gensim.models.keyedvectors.Vocab at 0x10fae5860>,
#  'ur-sag-zi': <gensim.models.keyedvectors.Vocab at 0x10fae5898>,
#  'zid[flour]N': <gensim.models.keyedvectors.Vocab at 0x10fae58d0>,
#  'magid[boat-tower]N': <gensim.models.keyedvectors.Vocab at 0x10fae5908>,
#  'ma[ship]N': <gensim.models.keyedvectors.Vocab at 0x10fae5940>,
#  'a-hu-ti{ki}': <gensim.models.keyedvectors.Vocab at 0x10fae5978>,
#  'sum': <gensim.models.keyedvectors.Vocab at 0x10fae59e8>,
#  'ti[arrow]N': <gensim.models.keyedvectors.Vocab at 0x10fae5a20>,
#  'dug[pot]N': <gensim.models.keyedvectors.Vocab at 0x10fae5a58>,
#  'ga[milk]N': <gensim.models.keyedvectors.Vocab at 0x10fae5a90>,
#  'eš[rope]N': <gensim.models.keyedvectors.Vocab at 0x10fae5ac8>,
#  'gisal': <gensim.models.keyedvectors.Vocab at 0x10fae5b38>,
#  'ŋešgu[stock]N': <gensim.models.keyedvectors.Vocab at 0x10fae5b70>,
#  'KAL': <gensim.models.keyedvectors.Vocab at 0x10fae5be0>,
#  'anur[horizon]N': <gensim.models.keyedvectors.Vocab at 0x10fae5c18>,
#  'emuhaldim[kitchen]N': <gensim.models.keyedvectors.Vocab at 0x10fae5c50>,
#  'n(aš@c)': <gensim.models.keyedvectors.Vocab at 0x10fae5c88>,
#  'lugal-uri₃': <gensim.models.keyedvectors.Vocab at 0x10fae5cc0>,
#  'šeš-lu₂': <gensim.models.keyedvectors.Vocab at 0x10fae5cf8>,
#  'ŋanun[storehouse]N': <gensim.models.keyedvectors.Vocab at 0x10fae5d30>,
#  'pa₄-{+an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x10fae5d68>,
#  'agrig[steward]N': <gensim.models.keyedvectors.Vocab at 0x10fae5da0>,
#  'a-ru₁₂-da': <gensim.models.keyedvectors.Vocab at 0x10fae5dd8>,
#  'kug[metal]N': <gensim.models.keyedvectors.Vocab at 0x10fae5e10>,
#  'HAR-tu': <gensim.models.keyedvectors.Vocab at 0x10fae5e80>,
# ...
#  '|DUMU×NUN|-šita': <gensim.models.keyedvectors.Vocab at 0x11254f908>,
#  'bilₓ(|GEŠ.PAP.BIL|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x11254f940>,
#  'kir[lamb]N': <gensim.models.keyedvectors.Vocab at 0x11254f978>,
#  'sila₄-tur': <gensim.models.keyedvectors.Vocab at 0x11254f9b0>,
#  'ur-{d}nin-kur': <gensim.models.keyedvectors.Vocab at 0x11254f9e8>,
#  'gibil[new]V/i': <gensim.models.keyedvectors.Vocab at 0x11254fa20>,
#  'kaš[beer]N': <gensim.models.keyedvectors.Vocab at 0x11254fa58>,
#  'de[pour]V/t': <gensim.models.keyedvectors.Vocab at 0x11254fa90>,
#  'luh[clean]V/t': <gensim.models.keyedvectors.Vocab at 0x11254fac8>,
#  'me-gal₂': <gensim.models.keyedvectors.Vocab at 0x11254fb00>,
#  '5(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x11254fb38>,
#  '|LAGAB×HA|-A': <gensim.models.keyedvectors.Vocab at 0x11254fb70>,
#  'sag-dingir-tuku': <gensim.models.keyedvectors.Vocab at 0x11254fba8>,
#  'mu-ni-uri₃': <gensim.models.keyedvectors.Vocab at 0x11254fbe0>,
#  'lugal-utu': <gensim.models.keyedvectors.Vocab at 0x11254fc18>,
#  'utu-mu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x11254fc50>,
#  'lugal-me-gal-gal': <gensim.models.keyedvectors.Vocab at 0x11254fc88>,
#  'lugal-zi-ša₃-gal₂': <gensim.models.keyedvectors.Vocab at 0x11254fcc0>,
#  'amar-kuara': <gensim.models.keyedvectors.Vocab at 0x11254fcf8>,
#  'eš₂-gar': <gensim.models.keyedvectors.Vocab at 0x11254fd30>,
#  'e₂-DU': <gensim.models.keyedvectors.Vocab at 0x11254fd68>,
#  'ŋeštin[vine]N': <gensim.models.keyedvectors.Vocab at 0x11254fda0>,
#  'ur-x': <gensim.models.keyedvectors.Vocab at 0x11254fe10>,
#  'x-x-x-x': <gensim.models.keyedvectors.Vocab at 0x11254fe80>,
#  'URUDU': <gensim.models.keyedvectors.Vocab at 0x11254fef0>,
#  'PAP': <gensim.models.keyedvectors.Vocab at 0x11254ff60>,
#  '|HI×AŠ@c|': <gensim.models.keyedvectors.Vocab at 0x11254ff98>,
#  'ama-bara₂-ge': <gensim.models.keyedvectors.Vocab at 0x11254ffd0>,
#  'lu₂-sa₁₀-gu₇': <gensim.models.keyedvectors.Vocab at 0x1125fc048>,
#  'ur-šubur': <gensim.models.keyedvectors.Vocab at 0x1125fc080>,
#  'eš₃-ta-mud': <gensim.models.keyedvectors.Vocab at 0x1125fc0b8>,
#  'lukiʾinimak[witness]N': <gensim.models.keyedvectors.Vocab at 0x1125fc0f0>,
#  'lugal-inim-zi-da': <gensim.models.keyedvectors.Vocab at 0x1125fc128>,
#  'hašhur[apple]N': <gensim.models.keyedvectors.Vocab at 0x1125fc160>,
#  'niŋduʾa[string]N': <gensim.models.keyedvectors.Vocab at 0x1125fc198>,
#  'kisur[locus]N': <gensim.models.keyedvectors.Vocab at 0x1125fc1d0>,
#  'ama-a-si': <gensim.models.keyedvectors.Vocab at 0x1125fc208>,
#  'TUN₃': <gensim.models.keyedvectors.Vocab at 0x1125fc240>,
#  'PI[unit]N': <gensim.models.keyedvectors.Vocab at 0x1125fc278>,
#  'niŋla[clothing]N': <gensim.models.keyedvectors.Vocab at 0x1125fc2b0>,
#  '|GA₂×HA|': <gensim.models.keyedvectors.Vocab at 0x1125fc2e8>,
#  'sag-AN-tuku': <gensim.models.keyedvectors.Vocab at 0x1125fc320>,
#  'e₂-du-du': <gensim.models.keyedvectors.Vocab at 0x1125fc358>,
#  'e₂-abzu': <gensim.models.keyedvectors.Vocab at 0x1125fc390>,
#  'ur-{d}nin-unug': <gensim.models.keyedvectors.Vocab at 0x1125fc3c8>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x1125fc438>,
#  'sa₆-ga': <gensim.models.keyedvectors.Vocab at 0x1125fc470>,
#  'hulu[ruination]N': <gensim.models.keyedvectors.Vocab at 0x1125fc4a8>,
#  'DUR₂': <gensim.models.keyedvectors.Vocab at 0x1125fc4e0>,
#  'unu[dwelling]N': <gensim.models.keyedvectors.Vocab at 0x1125fc518>,
#  '4(diš)': <gensim.models.keyedvectors.Vocab at 0x1125fc550>,
#  'utu-šita': <gensim.models.keyedvectors.Vocab at 0x1125fc588>,
#  '{d}nin-mar': <gensim.models.keyedvectors.Vocab at 0x1125fc5c0>,
#  '6(u)': <gensim.models.keyedvectors.Vocab at 0x1125fc630>,
#  'ninda[seed-funnel]N': <gensim.models.keyedvectors.Vocab at 0x1125fc668>,
#  '1(u)': <gensim.models.keyedvectors.Vocab at 0x1125fc6d8>,
#  'nagargal[carpenter]N': <gensim.models.keyedvectors.Vocab at 0x1125fc710>,
#  '3(u)': <gensim.models.keyedvectors.Vocab at 0x1125fc780>,
#  '2(u)': <gensim.models.keyedvectors.Vocab at 0x1125fc7f0>,
#  '1(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x1125fc828>,
#  'ku₃-luh-ha': <gensim.models.keyedvectors.Vocab at 0x1125fc860>,
#  '1/3(diš@c)': <gensim.models.keyedvectors.Vocab at 0x1125fc898>,
#  '|GA₂×HA|-A': <gensim.models.keyedvectors.Vocab at 0x1125fc8d0>,
#  'šaŋan[flask]N': <gensim.models.keyedvectors.Vocab at 0x1125fc908>,
#  'ur-sukkal-{d}saman₃': <gensim.models.keyedvectors.Vocab at 0x1125fc940>,
#  'kas': <gensim.models.keyedvectors.Vocab at 0x1125fc9b0>,
#  'amar-{d}sag-ku₅': <gensim.models.keyedvectors.Vocab at 0x1125fc9e8>,
#  'ed[ascend]V/i': <gensim.models.keyedvectors.Vocab at 0x1125fca20>,
#  'sag-a-ra₂-ba-šum₂': <gensim.models.keyedvectors.Vocab at 0x1125fca58>,
#  'ba-da': <gensim.models.keyedvectors.Vocab at 0x1125fcac8>,
#  'nig₂-du₈-du₈': <gensim.models.keyedvectors.Vocab at 0x1125fcb00>,
#  'za₃-mu': <gensim.models.keyedvectors.Vocab at 0x1125fcb38>,
#  'lugal-uš-suₓ(MUŠ)': <gensim.models.keyedvectors.Vocab at 0x1125fcb70>,
#  'gu-sur-NUN': <gensim.models.keyedvectors.Vocab at 0x1125fcba8>,
#  'ur-nusku₂': <gensim.models.keyedvectors.Vocab at 0x1125fcbe0>,
#  'dingir-nu-dam': <gensim.models.keyedvectors.Vocab at 0x1125fcc18>,
#  'ri[impose]V/t': <gensim.models.keyedvectors.Vocab at 0x1125fcc50>,
#  'kiʾerim[enemy-territory]N': <gensim.models.keyedvectors.Vocab at 0x1125fcc88>,
#  'bara₂-x': <gensim.models.keyedvectors.Vocab at 0x1125fccc0>,
#  'ka-tar-zi': <gensim.models.keyedvectors.Vocab at 0x1125fccf8>,
#  'šeš-geštin': <gensim.models.keyedvectors.Vocab at 0x1125fcd30>,
#  'gal-kiri₆': <gensim.models.keyedvectors.Vocab at 0x1125fcd68>,
#  'e₂-ki-du₁₀-ga': <gensim.models.keyedvectors.Vocab at 0x1125fcda0>,
#  'u₂-tuku': <gensim.models.keyedvectors.Vocab at 0x1125fcdd8>,
#  'en-kur-nu-hun': <gensim.models.keyedvectors.Vocab at 0x1125fce10>,
#  'az-za': <gensim.models.keyedvectors.Vocab at 0x1125fce80>,
#  '{geš}geštu-la-bi': <gensim.models.keyedvectors.Vocab at 0x1125fceb8>,
#  'lu₂-gu₄': <gensim.models.keyedvectors.Vocab at 0x1125fcef0>,
#  'sag-nin-da': <gensim.models.keyedvectors.Vocab at 0x1125fcf28>,
#  'KA-ni': <gensim.models.keyedvectors.Vocab at 0x1125fcf98>,
#  'a-zu₅-zu₅': <gensim.models.keyedvectors.Vocab at 0x1125fcfd0>,
#  'en-nagar-ša₃': <gensim.models.keyedvectors.Vocab at 0x112787048>,
#  'šita[prayer]N': <gensim.models.keyedvectors.Vocab at 0x112787080>,
#  'e₂-gissu-bi-du₁₀': <gensim.models.keyedvectors.Vocab at 0x1127870b8>,
#  'lu₂-geme₂-zi-da': <gensim.models.keyedvectors.Vocab at 0x1127870f0>,
#  'ar₃-du₃-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x112787128>,
#  '2(aš@c@90)': <gensim.models.keyedvectors.Vocab at 0x112787160>,
#  'ur-ab-u₂': <gensim.models.keyedvectors.Vocab at 0x112787198>,
#  '1(aš@c@90)': <gensim.models.keyedvectors.Vocab at 0x1127871d0>,
#  '2(eše₃@c)': <gensim.models.keyedvectors.Vocab at 0x112787208>,
#  'šeš-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x112787240>,
#  'DI-utu': <gensim.models.keyedvectors.Vocab at 0x1127872b0>,
#  'amar-x': <gensim.models.keyedvectors.Vocab at 0x112787320>,
#  'x-su': <gensim.models.keyedvectors.Vocab at 0x112787390>,
#  'lugal-x-x-x': <gensim.models.keyedvectors.Vocab at 0x1127873c8>,
#  '6(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x112787400>,
#  '5(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x112787438>,
#  'gamurₓ(LAK490)': <gensim.models.keyedvectors.Vocab at 0x112787470>,
#  'kam₄': <gensim.models.keyedvectors.Vocab at 0x1127874a8>,
#  'tag': <gensim.models.keyedvectors.Vocab at 0x112787518>,
#  'unud[cowherd]N': <gensim.models.keyedvectors.Vocab at 0x112787550>,
#  'sig₁₅': <gensim.models.keyedvectors.Vocab at 0x112787588>,
#  'KA': <gensim.models.keyedvectors.Vocab at 0x1127875f8>,
#  'GAR[former]AJ': <gensim.models.keyedvectors.Vocab at 0x112787630>,
#  'x-zi': <gensim.models.keyedvectors.Vocab at 0x1127876a0>,
#  'munus-en-kalam': <gensim.models.keyedvectors.Vocab at 0x1127876d8>,
#  'min[two]NU': <gensim.models.keyedvectors.Vocab at 0x112787710>,
#  'nesaŋ[offering]N': <gensim.models.keyedvectors.Vocab at 0x112787748>,
#  'ma-ma': <gensim.models.keyedvectors.Vocab at 0x1127877b8>,
#  'nu': <gensim.models.keyedvectors.Vocab at 0x112787828>,
#  'PA-PA': <gensim.models.keyedvectors.Vocab at 0x112787898>,
#  '4(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x1127878d0>,
#  '{ninda}nindaₓ(DU)': <gensim.models.keyedvectors.Vocab at 0x112787908>,
#  '7(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x112787940>,
#  'nam[fate]N': <gensim.models.keyedvectors.Vocab at 0x112787978>,
#  'TUR': <gensim.models.keyedvectors.Vocab at 0x1127879e8>,
#  'kalam[land]N': <gensim.models.keyedvectors.Vocab at 0x112787a20>,
#  'lugididak[musician]N': <gensim.models.keyedvectors.Vocab at 0x112787a58>,
#  'ur-{d}gibil₆': <gensim.models.keyedvectors.Vocab at 0x112787a90>,
#  'x-mu': <gensim.models.keyedvectors.Vocab at 0x112787b00>,
#  'nin-mu': <gensim.models.keyedvectors.Vocab at 0x112787b70>,
#  'x-PA': <gensim.models.keyedvectors.Vocab at 0x112787be0>,
#  'nin-a-zu₅': <gensim.models.keyedvectors.Vocab at 0x112787c18>,
#  'e₂-UD-gin₇-e₃': <gensim.models.keyedvectors.Vocab at 0x112787c50>,
#  'nin-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x112787c88>,
#  'a-ul₄-gal': <gensim.models.keyedvectors.Vocab at 0x112787cc0>,
#  'lu₂-su₁₃': <gensim.models.keyedvectors.Vocab at 0x112787cf8>,
#  'lu₂-si₄': <gensim.models.keyedvectors.Vocab at 0x112787d30>,
#  'lugal-engar-zi': <gensim.models.keyedvectors.Vocab at 0x112787d68>,
#  'lugal-ezen': <gensim.models.keyedvectors.Vocab at 0x112787da0>,
#  '{d}x': <gensim.models.keyedvectors.Vocab at 0x112787e10>,
#  'lammar[deity]N': <gensim.models.keyedvectors.Vocab at 0x112787e48>,
#  '{d}tu': <gensim.models.keyedvectors.Vocab at 0x112787eb8>,
#  '{d}nin-x': <gensim.models.keyedvectors.Vocab at 0x112787ef0>,
#  '{d}nin-ki-da': <gensim.models.keyedvectors.Vocab at 0x112787f28>,
#  '{d}nin-mug': <gensim.models.keyedvectors.Vocab at 0x112787f60>,
#  '{d}nin-pirig': <gensim.models.keyedvectors.Vocab at 0x112787f98>,
#  'ZI': <gensim.models.keyedvectors.Vocab at 0x1128b8048>,
#  'ŠE₃': <gensim.models.keyedvectors.Vocab at 0x1128b8080>,
#  'ki-mu-gi₄': <gensim.models.keyedvectors.Vocab at 0x1128b80b8>,
#  'al₆-lum': <gensim.models.keyedvectors.Vocab at 0x1128b80f0>,
#  'AK-{d}tu': <gensim.models.keyedvectors.Vocab at 0x1128b8128>,
#  'sipa-anše': <gensim.models.keyedvectors.Vocab at 0x1128b8160>,
#  'ša₃-iri': <gensim.models.keyedvectors.Vocab at 0x1128b8198>,
#  'munus-u₄-ba': <gensim.models.keyedvectors.Vocab at 0x1128b81d0>,
#  'e₂-šud₃-du₁₀': <gensim.models.keyedvectors.Vocab at 0x1128b8208>,
#  'e₂-geme₂': <gensim.models.keyedvectors.Vocab at 0x1128b8240>,
#  'x-nun': <gensim.models.keyedvectors.Vocab at 0x1128b82b0>,
#  'nu-nu': <gensim.models.keyedvectors.Vocab at 0x1128b8320>,
#  'šukur[ration]N': <gensim.models.keyedvectors.Vocab at 0x1128b8358>,
#  'KU-KU': <gensim.models.keyedvectors.Vocab at 0x1128b83c8>,
#  'sag-narₓ(X)': <gensim.models.keyedvectors.Vocab at 0x1128b8400>,
#  'KA-nun-ki-ba': <gensim.models.keyedvectors.Vocab at 0x1128b8438>,
#  'e₂-nam': <gensim.models.keyedvectors.Vocab at 0x1128b8470>,
#  'a-en-da': <gensim.models.keyedvectors.Vocab at 0x1128b84e0>,
#  'maš-x': <gensim.models.keyedvectors.Vocab at 0x1128b8518>,
#  'sag-ku₅': <gensim.models.keyedvectors.Vocab at 0x1128b8550>,
#  'ur-{d}nanše': <gensim.models.keyedvectors.Vocab at 0x1128b8588>,
#  'sim[sieve]V/t': <gensim.models.keyedvectors.Vocab at 0x1128b85c0>,
#  'igi-su₄': <gensim.models.keyedvectors.Vocab at 0x1128b85f8>,
#  'alim[bison]N': <gensim.models.keyedvectors.Vocab at 0x1128b8630>,
#  'x-x-da': <gensim.models.keyedvectors.Vocab at 0x1128b86a0>,
#  'imria[clan]N': <gensim.models.keyedvectors.Vocab at 0x1128b86d8>,
#  'urur[functionary]N': <gensim.models.keyedvectors.Vocab at 0x1128b8710>,
#  'ŋiri[dagger]N': <gensim.models.keyedvectors.Vocab at 0x1128b8748>,
#  '2(diš)': <gensim.models.keyedvectors.Vocab at 0x1128b8780>,
#  'ša₃-ba': <gensim.models.keyedvectors.Vocab at 0x1128b87b8>,
#  'ur-{d}nin-urta': <gensim.models.keyedvectors.Vocab at 0x1128b87f0>,
#  'limum[thousand]NU': <gensim.models.keyedvectors.Vocab at 0x1128b8828>,
#  'mi-at': <gensim.models.keyedvectors.Vocab at 0x1128b8898>,
#  'munus[woman]N': <gensim.models.keyedvectors.Vocab at 0x1128b88d0>,
#  'e₂-{d}x': <gensim.models.keyedvectors.Vocab at 0x1128b8908>,
#  'eʾara[mill]N': <gensim.models.keyedvectors.Vocab at 0x1128b8940>,
#  'ukken-a': <gensim.models.keyedvectors.Vocab at 0x1128b89b0>,
#  'x-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x1128b89e8>,
#  'bilₓ(|GIŠ.PAP.BIL|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x1128b8a20>,
#  'x-AN-x': <gensim.models.keyedvectors.Vocab at 0x1128b8a90>,
#  'lugal-da-zi': <gensim.models.keyedvectors.Vocab at 0x1128b8ac8>,
#  'gal-muhaldim': <gensim.models.keyedvectors.Vocab at 0x1128b8b00>,
#  'gal-LI-LI': <gensim.models.keyedvectors.Vocab at 0x1128b8b38>,
#  'bilₓ(|GIŠ.PAP.BIL|)-la': <gensim.models.keyedvectors.Vocab at 0x1128b8b70>,
#  'ensiₓ(|PA.TE.SI.NIG₂|)-gal': <gensim.models.keyedvectors.Vocab at 0x1128b8ba8>,
#  'nin-ukken-a': <gensim.models.keyedvectors.Vocab at 0x1128b8be0>,
#  'e₂-SAHAR-ta-e₃': <gensim.models.keyedvectors.Vocab at 0x1128b8c18>,
#  'pa₄-ul₄-gal': <gensim.models.keyedvectors.Vocab at 0x1128b8c50>,
#  '{d}buranunaₓ(|KIB@g.NUN|)-ur-sag': <gensim.models.keyedvectors.Vocab at 0x1128b8c88>,
#  'AB-BAR-TAB': <gensim.models.keyedvectors.Vocab at 0x1128b8cc0>,
#  'eriš-dingir': <gensim.models.keyedvectors.Vocab at 0x1128b8cf8>,
#  'ulu₃-di': <gensim.models.keyedvectors.Vocab at 0x1128b8d30>,
#  'mu[year]N': <gensim.models.keyedvectors.Vocab at 0x1128b8d68>,
#  'libir[old]V/i': <gensim.models.keyedvectors.Vocab at 0x1128b8da0>,
#  '3(diš@t)': <gensim.models.keyedvectors.Vocab at 0x1128b8dd8>,
#  '4(diš@t)': <gensim.models.keyedvectors.Vocab at 0x1128b8e10>,
#  'x-x-DI': <gensim.models.keyedvectors.Vocab at 0x1128b8e80>,
#  'elam': <gensim.models.keyedvectors.Vocab at 0x1128b8ef0>,
#  'lu₂-ma₂-x': <gensim.models.keyedvectors.Vocab at 0x1128b8f28>,
#  '5(aš)': <gensim.models.keyedvectors.Vocab at 0x1128b8f60>,
#  'ma₂-gal-gal': <gensim.models.keyedvectors.Vocab at 0x1128b8f98>,
#  '|MI+ZA₇|': <gensim.models.keyedvectors.Vocab at 0x1128b8fd0>,
#  'ama-bara₂-si': <gensim.models.keyedvectors.Vocab at 0x112932048>,
#  'na-U₂-U₂': <gensim.models.keyedvectors.Vocab at 0x112932080>,
#  'e₂-an-da-mu₂': <gensim.models.keyedvectors.Vocab at 0x1129320b8>,
#  'e₂-{+an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x1129320f0>,
#  'dumu-{+an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x112932128>,
#  'lu₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x112932160>,
#  'nig₂-lugud₂-da': <gensim.models.keyedvectors.Vocab at 0x112932198>,
#  'a-da-tuš': <gensim.models.keyedvectors.Vocab at 0x1129321d0>,
#  'gir₄-bil': <gensim.models.keyedvectors.Vocab at 0x112932208>,
#  'e₂-al₆-la': <gensim.models.keyedvectors.Vocab at 0x112932240>,
#  'nam-ša₃-ta': <gensim.models.keyedvectors.Vocab at 0x112932278>,
#  'NU': <gensim.models.keyedvectors.Vocab at 0x1129322e8>,
#  'gu[cord]N': <gensim.models.keyedvectors.Vocab at 0x112932320>,
#  'šubur-tur': <gensim.models.keyedvectors.Vocab at 0x112932358>,
#  'gada[flax]N': <gensim.models.keyedvectors.Vocab at 0x112932390>,
#  'UD-UD': <gensim.models.keyedvectors.Vocab at 0x112932400>,
#  'GAL': <gensim.models.keyedvectors.Vocab at 0x112932470>,
#  'mu-x': <gensim.models.keyedvectors.Vocab at 0x1129324e0>,
#  'ŠUBUR': <gensim.models.keyedvectors.Vocab at 0x112932518>,
#  'ME': <gensim.models.keyedvectors.Vocab at 0x112932588>,
#  'nanna{na}': <gensim.models.keyedvectors.Vocab at 0x1129325c0>,
#  'uš[die]V/i': <gensim.models.keyedvectors.Vocab at 0x1129325f8>,
#  'x-x-ni': <gensim.models.keyedvectors.Vocab at 0x112932668>,
#  'mud[tube]N': <gensim.models.keyedvectors.Vocab at 0x1129326a0>,
#  'ua[provisioner]N': <gensim.models.keyedvectors.Vocab at 0x1129326d8>,
#  'ekas[road-house]N': <gensim.models.keyedvectors.Vocab at 0x112932710>,
#  'kun-kun': <gensim.models.keyedvectors.Vocab at 0x112932780>,
#  'amar-giri₁₆': <gensim.models.keyedvectors.Vocab at 0x1129327b8>,
#  'na-x-x': <gensim.models.keyedvectors.Vocab at 0x112932828>,
#  'x-ki-x': <gensim.models.keyedvectors.Vocab at 0x112932898>,
#  'za[bead]N': <gensim.models.keyedvectors.Vocab at 0x1129328d0>,
#  'balaŋdi[lamentation-singer]N': <gensim.models.keyedvectors.Vocab at 0x112932908>,
#  ...}

# %% [markdown]
# # Similar words

# %%
model_akk.wv.most_similar("šarru[king]N", topn = 2), model_sux.wv.most_similar("lugal[king]N", topn=2)
# Out:
# ([('bēlu[lord]N', 0.9549878835678101), ('ana[to]PRP', 0.9517405033111572)],
#  [('ki[place]N', 0.9306299090385437), ('kalam[land]N', 0.9235943555831909)])

# %% [markdown]
# # Out of Vocabulary Words
# This is fasttext ... You may also use OOV words such as partial matches.

# %%
model_akk.wv.most_similar("palace", topn = 2), model_sux.wv.most_similar("[tiger]N", topn=2)
# Out:
# ([('Ekallu-eššetu[New-Palace-palace-in-Aššur]ON', 0.7083826065063477),
#   ('egalturrû[little-palace]N', 0.6874814033508301)],
#  [('uršub[tiger]N', 0.6488356590270996),
#   ('uršubkuda[wild-animal]N', 0.5293694138526917)])

# %% [markdown]
# # Kings and Queens
# Hmmmm

# %%
model_akk.wv.most_similar(positive=["šarru[king]N", "sinništu[woman]N"], negative = ["zikaru[male]N"])
# Out:
# [('ana[to]PRP', 0.8608435988426208),
#  ('bēlu[lord]N', 0.8355154991149902),
#  ('ša[of]DET', 0.8317270874977112),
#  ('ša[that]REL', 0.8234253525733948),
#  ('ardu[slave]N', 0.8218632936477661),
#  ('ina[in]PRP', 0.8146044611930847),
#  ('māru[son]N', 0.80776047706604),
#  ('abu[father]N', 0.8045012950897217),
#  ('ēkallu[palace]N', 0.8006858825683594),
#  ('muhhu[skull]N', 0.7995380163192749)]

# %% [markdown]
# # Oxen and Sheep
# More culturally appropriate, perhaps.

# %%
model_sux.wv.most_similar(positive=["gud[oxen]N", "sila[lamb]N"], negative= ["amar[calf]N"])
# Out:
# [('mašgal[goat]N', 0.9077289700508118),
#  ('ašgar[kid]N', 0.9058449268341064),
#  ('u[ewe]N', 0.8994815349578857),
#  ('udu[sheep]N', 0.8990205526351929),
#  ('maš[goat]N', 0.8890479207038879),
#  ('nua[~animal]N', 0.8813501596450806),
#  ('niga[fattened]V/i', 0.8751996159553528),
#  ('gukkal[sheep]N', 0.8608914017677307),
#  ('aslum[sheep]N', 0.8605831265449524),
#  ('mašda[gazelle]N', 0.8534128069877625)]

# %% [markdown]
# # Some Bokeh Fun

# %%
def tsne_bokeh(model, word_d, words, fontsize="12pt"):

    labels = []
    tokens = []
    categories = []
    legend = []
    
    for word in word_d:
        tokens.append(model.wv[word])
        labels.append(word)
        categories.append(word_d[word])
        if word_d[word] == 5: 
            legend.append("mixed")
        else: 
            legend.append(words[word_d[word]])
    
    color_d = {0: "black", 1: "red", 2: "green", 3: "yellow", 4: "brown", 5: "blue"}
    colors = [color_d[category] for category in categories]
    
    tsne = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    tsne_embedding = tsne.fit_transform(tokens)
    tsne_embedding = pd.DataFrame(tsne_embedding, columns=['x','y'])
    tsne_embedding["color"] = colors
    tsne_embedding["labels"] = labels
    tsne_embedding["legend"] = legend

    source = ColumnDataSource(
        data=dict(
        x = tsne_embedding.x,
        y = tsne_embedding.y,
        colors = tsne_embedding.color,
        labels=tsne_embedding.labels,
        legend = tsne_embedding.legend
        )
    )

    l = LabelSet(x='x', y='y', text='labels', level='glyph',
              x_offset=5, y_offset=5, source=source, render_mode='canvas', 
             text_font_size=fontsize, text_font="CuneiformComposite")

    plot_tsne = figure(plot_width=900, plot_height=900) #, tools=tools_tsne, title='Papers')
    plot_tsne.circle('x', 'y', size=7, fill_color='colors', 
                  line_alpha=0, line_width=0.01, source=source, legend="legend")
    plot_tsne.add_layout(l)
    return plot_tsne

# %%
def word_categories(model, words, topn=10):
    """word_categories takes an iterable with one or more words from the vocabulary of model.
    For each word a dictionary of similar words (with the target word) is construed.
    The value of each word is numerical (integer) and indicates the category to which it belongs.
    The function returns a dictionary."""
    word_d = {}
    for idx, word in enumerate(words):
        w = model.wv.most_similar(word, topn=topn)
        w = [m[0] for m in w]
        w.append(word)
        for item in w:
            if item in word_d:
                word_d[item] = 5
            else:
                word_d[item] = idx
    return word_d

# %%
vegetables_perfumes = ["šimgig[tree]N", "hiz[vegetable]N"]
words_d = word_categories(model_sux, vegetables_perfumes, 10)
p2 = tsne_bokeh(model_sux, words_d, vegetables_perfumes, "20pt")
show(p2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-1294572711a7> in <module>()
#       1 vegetables_perfumes = ["šimgig[tree]N", "hiz[vegetable]N"]
#       2 words_d = word_categories(model_sux, vegetables_perfumes, 10)
# ----> 3 p2 = tsne_bokeh(model_sux, words_d, vegetables_perfumes, "20pt")
#       4 show(p2)
#
# <ipython-input-12-6d5f10d74835> in tsne_bokeh(model, word_d, words, fontsize)
#      19
#      20     tsne = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
# ---> 21     tsne_embedding = tsne.fit_transform(tokens)
#      22     tsne_embedding = pd.DataFrame(tsne_embedding, columns=['x','y'])
#      23     tsne_embedding["color"] = colors
#
# /Users/veldhuis/anaconda/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     882             Embedding of the training data in low-dimensional space.
#     883         """
# --> 884         embedding = self._fit(X)
#     885         self.embedding_ = embedding
#     886         return self.embedding_
#
# /Users/veldhuis/anaconda/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     787                           X_embedded=X_embedded,
#     788                           neighbors=neighbors_nn,
# --> 789                           skip_num_points=skip_num_points)
#     790
#     791     def _tsne(self, P, degrees_of_freedom, n_samples, random_state,
#
# /Users/veldhuis/anaconda/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, random_state, X_embedded, neighbors, skip_num_points)
#     840
#     841         params, kl_divergence, it = _gradient_descent(obj_func, params,
# --> 842                                                       **opt_args)
#     843         opt_args['n_iter'] = 100
#     844         opt_args['momentum'] = 0.8
#
# /Users/veldhuis/anaconda/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _gradient_descent(objective, p0, it, n_iter, objective_error, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, min_error_diff, verbose, args, kwargs)
#     386     for i in range(it, n_iter):
#     387         new_error, grad = objective(p, *args, **kwargs)
# --> 388         grad_norm = linalg.norm(grad)
#     389
#     390         inc = update * grad >= 0.0
#
# /Users/veldhuis/anaconda/lib/python3.6/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims)
#     127     """
#     128     # Differs from numpy only in non-finite handling and the use of blas.
# --> 129     a = np.asarray_chkfinite(a)
#     130
#     131     # Only use optimized norms if axis and keepdims are not specified.
#
# /Users/veldhuis/anaconda/lib/python3.6/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#    1213     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#    1214         raise ValueError(
# -> 1215             "array must not contain infs or NaNs")
#    1216     return a
#    1217
#
# ValueError: array must not contain infs or NaNs

# %%
words_d
# Out:
# {'GAM.GAM[~aromatics]N': 0,
#  'HI.a[vegetable]N': 1,
#  'abušu[plant]N': 1,
#  'ad[bush]N': 0,
#  'andahšum[plant]N': 1,
#  'arganum[conifer]N': 0,
#  'azugna[vegetable]N': 1,
#  'babbarhi[plant]N': 1,
#  'buluh[tree]N': 0,
#  'damšelum[plant]N': 0,
#  'dimgi[plant]N': 1,
#  'emeʾurgirak[plant]N': 1,
#  'enmur[resin]N': 0,
#  'eren[cedar]N': 0,
#  'eš[tree]N': 0,
#  'gakkul[heart]N': 1,
#  'gamamtum[vegetable]N': 1,
#  'gamun[cumin]N': 5,
#  'ganazi[plant]N': 1,
#  'ganše[plant]N': 1,
#  'garaš[leek]N': 1,
#  'garašsaŋ[leek]N': 1,
#  'gi-NI[resin]N': 0,
#  'girinum[plant]N': 0,
#  'gudkuru[resin]N': 0,
#  'gurun[fruit]N': 1,
#  'hazanum[plant]N': 1,
#  'hašur[tree]N': 0,
#  'hiz[vegetable]N': 1,
#  'hizurbara[vegetable]N': 1,
#  'hurium[plant]N': 1,
#  'ihenunak[oil]N': 0,
#  'imkugsig[earth]N': 0,
#  'iškur[plant]N': 1,
#  'iʾirnun[oil]N': 0,
#  'kukuru[resin]N': 0,
#  'kurgirina[plant]N': 1,
#  'ku₃-bi': 0,
#  'lal[syrup]N': 0,
#  'li[juniper]N': 0,
#  'ligidba[plant]N': 0,
#  'ligtum[selection]N': 0,
#  'marguzum[bush]N': 0,
#  'naŋasiʾe[plant]N': 0,
#  'niŋnagar[plant]N': 1,
#  'numun[seed]N': 1,
#  'pa-li': 0,
#  'sikil[plant]N': 1,
#  'sullim[spice]N': 1,
#  'sullimšuguba[spice]N': 1,
#  'u[plant]N': 1,
#  'ulu[plant]N': 1,
#  'uŋeš[plant]N': 1,
#  'zabalum[juniper]N': 0,
#  'zahadin[vegetable]N': 1,
#  'zahhu[tree]N': 0,
#  'zahili[plant]N': 1,
#  'ŋeštin[vine]N': 1,
#  'šeli[aromatics]N': 0,
#  'šelu[coriander]N': 5,
#  'šembulug[resin]N': 0,
#  'šim-su-DI-ir-nun[resin]N': 0,
#  'šim[aromatics]N': 0,
#  'šimbirida[plant]N': 1,
#  'šimgamgama[aromatics]N': 0,
#  'šimgig[tree]N': 0,
#  'šimim[resin]N': 0,
#  'šumgaz[vegetable]N': 1,
#  'šumsikil[vegetable]N': 1,
#  'šurmen[cypress]N': 0}
