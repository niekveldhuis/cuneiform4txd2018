# %% [markdown]
# # Sumerian and Akkadian Word Embeddings
# By Niek Veldhuis, Department of Near Eastern Studies, UC Berkeley
#
# This notebook loads Sumerian and Akkadian word embedding models and gives some hints for how to explore these models. Will someone be brave enough to try and align the two models?
#
# The data derive from the Open Richly Annotated Cuneiform Corpus ([ORACC](http://oracc.org)) created by Steve Tinney (UPenn) and dircted by Jamie Novotny (Munich), Eleanor Robson (UC London), and Niek Veldhuis (UC Berkeley).
#
# The Sumerian texts used in this model date between 2,500 BCE and 0; the corpus is dominated by a group of about 70,000 administartive texts from around 2,050 BCE dealing with animals, grain, labor, precious objects, etc. The entire corpus used here has about about 4.3 million words. The Akkadian corpus ranges from ca. 2,000 BCE to 0 and consists primarily of library texts, royal inscriptions, royal correspondence and royal administartion, for a total of some 1.5 million words. Sumerian was spoken in the deep South of present day Iraq in the third millennium - afterwards it became a language of scholarship and religion. Akkadian was spoken in Babylonia and Assyria - roughly the same cultural area where Sumerian was at home.
#
# ![A Sumerian - Akkadian Bilingual Dictionary](https://cdli.ucla.edu/dl/tn_photo/P342645.jpg)
# A Sumerian - Akkadian dictionary, Museum number MS 3178. Click [here](https://cdli.ucla.edu/dl/photo/P342645.jpg) for a larger picture and [here](http://oracc.org/dcclt/signlists/P342645) for a full edition and translation of the text.
#
# ## Licensing
# The data in the models derives from [ORACC](http://oracc.org) and has been acquired formatted and processed by Niek Veldhuis, UC Berkeley, November 2018. You are free to use the models (CC0 or Public Domain), but it is appreciated if you provide a link to [ORACC](http://oracc.org) as the source of the data.
#
# ## Prerequisites
# The code below requires a relatively recent version of Gensim - one that includes a FastText implementation.

# %%
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim') # this is only relevant in Windows.
warnings.filterwarnings(action='ignore', category=FutureWarning, module='gensim' ) # warning will disappear in a future version of Gensim
from gensim.models.fasttext import FastText as FT_gensim
import pickle

# %% [markdown]
# # Load the Models

# %%
model_sux = FT_gensim.load("model/model_lemm.model")
model_akk = FT_gensim.load("model/akk_model_lemm.model")

# %% [markdown]
# # Vocabulary
# Lemmatized tokens have the form **CitationForm[GuideWord]POS** (for instance lugal[king]N). Tokens that are not lemmatized (names, broken words, unknown words) are given in transliteration (for instance ab-ba-sa₆-ga). To find possible vocabulary items you may inspect the `vocabulary` attribute.

# %%
model_sux.wv.vocab
# Out:
# {'1(barig@c)': <gensim.models.keyedvectors.Vocab at 0x4fb36d8>,
#  'še[barley]N': <gensim.models.keyedvectors.Vocab at 0x4fb37f0>,
#  'ba-lul': <gensim.models.keyedvectors.Vocab at 0x4fb3898>,
#  'nagar[carpenter]N': <gensim.models.keyedvectors.Vocab at 0x4fb30b8>,
#  'niŋdu[appropriate-thing]N': <gensim.models.keyedvectors.Vocab at 0x4fb3b38>,
#  'aŋ[measure]V/t': <gensim.models.keyedvectors.Vocab at 0x897da20>,
#  'hur-sag-še₃-mah': <gensim.models.keyedvectors.Vocab at 0x8ae37f0>,
#  'saŋ.DUN₃[recorder]N': <gensim.models.keyedvectors.Vocab at 0x8ae3b38>,
#  '2(iku@c)': <gensim.models.keyedvectors.Vocab at 0x8b56ef0>,
#  'iku[unit]N': <gensim.models.keyedvectors.Vocab at 0x8b84b38>,
#  'har-tu-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x8b84b70>,
#  'nukirik[gardener]N': <gensim.models.keyedvectors.Vocab at 0x8b84ba8>,
#  'me-zi-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x8b84be0>,
#  '1/2(iku@c)': <gensim.models.keyedvectors.Vocab at 0x8b84c18>,
#  'ša₃-gu₂-ba': <gensim.models.keyedvectors.Vocab at 0x8b84c50>,
#  '4(iku@c)': <gensim.models.keyedvectors.Vocab at 0x8b84c88>,
#  'AŠ₂-mud': <gensim.models.keyedvectors.Vocab at 0x8b84cc0>,
#  '3(iku@c)': <gensim.models.keyedvectors.Vocab at 0x8b84cf8>,
#  'dud[mound]N': <gensim.models.keyedvectors.Vocab at 0x8b84d30>,
#  'gala[singer]N': <gensim.models.keyedvectors.Vocab at 0x8b84d68>,
#  'a-lu-lu': <gensim.models.keyedvectors.Vocab at 0x8b84dd8>,
#  'lugušudu[profession]N': <gensim.models.keyedvectors.Vocab at 0x8b84e10>,
#  '1(iku@c)': <gensim.models.keyedvectors.Vocab at 0x8b84e48>,
#  'e[house]N': <gensim.models.keyedvectors.Vocab at 0x8b84e80>,
#  'zadim[stone-cutter]N': <gensim.models.keyedvectors.Vocab at 0x8b84eb8>,
#  '1/4(iku@c)': <gensim.models.keyedvectors.Vocab at 0x8b84ef0>,
#  'amar-tur₃': <gensim.models.keyedvectors.Vocab at 0x8b84f28>,
#  'dumu-šita': <gensim.models.keyedvectors.Vocab at 0x8b84f60>,
#  'ur-dumu-zi': <gensim.models.keyedvectors.Vocab at 0x8b84f98>,
#  'ašgab[leatherworker]N': <gensim.models.keyedvectors.Vocab at 0x8b84fd0>,
#  'u₂-KA-KA': <gensim.models.keyedvectors.Vocab at 0x8b98048>,
#  'AN-nu-me': <gensim.models.keyedvectors.Vocab at 0x8b98080>,
#  'kuš[official]N': <gensim.models.keyedvectors.Vocab at 0x8b980b8>,
#  'amar-ku₃': <gensim.models.keyedvectors.Vocab at 0x8b980f0>,
#  'lum-ma': <gensim.models.keyedvectors.Vocab at 0x8b98160>,
#  '5(iku@c)': <gensim.models.keyedvectors.Vocab at 0x8b98198>,
#  '{d}sud₃-ur-sag': <gensim.models.keyedvectors.Vocab at 0x8b981d0>,
#  '1(eše₃@c)': <gensim.models.keyedvectors.Vocab at 0x8b98208>,
#  'pap[relation]N': <gensim.models.keyedvectors.Vocab at 0x8b98240>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x8b98278>,
#  'sag-narₓ(LAK244)': <gensim.models.keyedvectors.Vocab at 0x8b982b0>,
#  '2(u@c)': <gensim.models.keyedvectors.Vocab at 0x8b98320>,
#  'lal[small]V/i': <gensim.models.keyedvectors.Vocab at 0x8b98358>,
#  '1(aš@c)': <gensim.models.keyedvectors.Vocab at 0x8b98390>,
#  'ŋuruš[male]N': <gensim.models.keyedvectors.Vocab at 0x8b983c8>,
#  '1(u@c)': <gensim.models.keyedvectors.Vocab at 0x8b98438>,
#  '4(aš@c)': <gensim.models.keyedvectors.Vocab at 0x8b98470>,
#  'ur-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x8b984a8>,
#  '1(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x8b984e0>,
#  '2(aš@c)': <gensim.models.keyedvectors.Vocab at 0x8b98518>,
#  'munus-geštin': <gensim.models.keyedvectors.Vocab at 0x4fb3780>,
#  '3(aš@c)': <gensim.models.keyedvectors.Vocab at 0x4fb34e0>,
#  'mes-lu-lu': <gensim.models.keyedvectors.Vocab at 0x8b98550>,
#  '6(aš@c)': <gensim.models.keyedvectors.Vocab at 0x8b98588>,
#  'adda[father]N': <gensim.models.keyedvectors.Vocab at 0x8b985c0>,
#  'di-utu': <gensim.models.keyedvectors.Vocab at 0x8b98630>,
#  '5(aš@c)': <gensim.models.keyedvectors.Vocab at 0x8b98668>,
#  'simug[smith]N': <gensim.models.keyedvectors.Vocab at 0x8b986a0>,
#  'abgal[sage]N': <gensim.models.keyedvectors.Vocab at 0x8b986d8>,
#  '7(aš@c)': <gensim.models.keyedvectors.Vocab at 0x8b98710>,
#  'gal-nimgir': <gensim.models.keyedvectors.Vocab at 0x8b98748>,
#  '3(u@c)': <gensim.models.keyedvectors.Vocab at 0x8b987b8>,
#  'e₂-su₁₃-ag₂': <gensim.models.keyedvectors.Vocab at 0x8b987f0>,
#  'nin-ur-sag': <gensim.models.keyedvectors.Vocab at 0x8b98828>,
#  'amar-šuba₃': <gensim.models.keyedvectors.Vocab at 0x8b98860>,
#  'enkud[tax-collector]N': <gensim.models.keyedvectors.Vocab at 0x8b98898>,
#  'šuniŋin[total]N': <gensim.models.keyedvectors.Vocab at 0x8b988d0>,
#  '1(gešʾu@c)': <gensim.models.keyedvectors.Vocab at 0x8b98908>,
#  '4(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x8b98940>,
#  'diš[one]NU': <gensim.models.keyedvectors.Vocab at 0x8b98978>,
#  'šeš-tur': <gensim.models.keyedvectors.Vocab at 0x8b989b0>,
#  '7(diš)': <gensim.models.keyedvectors.Vocab at 0x8b989e8>,
#  '1(diš)': <gensim.models.keyedvectors.Vocab at 0x8b98a20>,
#  'bilₓ(|PAP.GEŠ.BIL|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x8b98a58>,
#  'si-du₃': <gensim.models.keyedvectors.Vocab at 0x8b98a90>,
#  'en-kas₄': <gensim.models.keyedvectors.Vocab at 0x8b98ac8>,
#  '6(diš)': <gensim.models.keyedvectors.Vocab at 0x8b98b00>,
#  'sipad[shepherd]N': <gensim.models.keyedvectors.Vocab at 0x8b98b38>,
#  'giš': <gensim.models.keyedvectors.Vocab at 0x8b98b70>,
#  'BAD': <gensim.models.keyedvectors.Vocab at 0x8b98be0>,
#  'munsub[shepherd]N': <gensim.models.keyedvectors.Vocab at 0x8b98c18>,
#  'dubsar[scribe]N': <gensim.models.keyedvectors.Vocab at 0x8b98c50>,
#  'anše[equid]N': <gensim.models.keyedvectors.Vocab at 0x8b98c88>,
#  'a-ki-gal': <gensim.models.keyedvectors.Vocab at 0x8b98cc0>,
#  'subur[slave]N': <gensim.models.keyedvectors.Vocab at 0x8b98cf8>,
#  'mes-ki-na': <gensim.models.keyedvectors.Vocab at 0x8b98d30>,
#  'engar[farmer]N': <gensim.models.keyedvectors.Vocab at 0x8b98d68>,
#  'nin-gu₂-gal': <gensim.models.keyedvectors.Vocab at 0x8b98da0>,
#  'nagada[herdsman]N': <gensim.models.keyedvectors.Vocab at 0x8b98dd8>,
#  'išib[priest]N': <gensim.models.keyedvectors.Vocab at 0x8b98e10>,
#  'abzu-mud': <gensim.models.keyedvectors.Vocab at 0x8b98e48>,
#  '{d}nusku₂': <gensim.models.keyedvectors.Vocab at 0x8b98e80>,
#  'e₂-pirig-gal': <gensim.models.keyedvectors.Vocab at 0x8b98eb8>,
#  'dilmun[important]V/i': <gensim.models.keyedvectors.Vocab at 0x8b98ef0>,
#  'a-NI-NI': <gensim.models.keyedvectors.Vocab at 0x8b98f60>,
#  '{d}nin-PA': <gensim.models.keyedvectors.Vocab at 0x8b98f98>,
#  'gal-ukken': <gensim.models.keyedvectors.Vocab at 0x8b98fd0>,
#  'e₂-na-lu': <gensim.models.keyedvectors.Vocab at 0x8b9f048>,
#  '{d}nu-muš-da': <gensim.models.keyedvectors.Vocab at 0x8b9f080>,
#  'du₁₁-ga-ni': <gensim.models.keyedvectors.Vocab at 0x8b9f0b8>,
#  'ušum-ma': <gensim.models.keyedvectors.Vocab at 0x8b9f0f0>,
#  'kin-nir': <gensim.models.keyedvectors.Vocab at 0x8b9f160>,
#  'lugal-he₂-gal₂': <gensim.models.keyedvectors.Vocab at 0x8b9f198>,
#  'IB': <gensim.models.keyedvectors.Vocab at 0x8b9f208>,
#  'nig₂-si₄': <gensim.models.keyedvectors.Vocab at 0x8b9f240>,
#  'nammah[greatness]N': <gensim.models.keyedvectors.Vocab at 0x8b9f278>,
#  'e₂-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x8b9f2b0>,
#  'AK-utu': <gensim.models.keyedvectors.Vocab at 0x8b9f320>,
#  'x-x': <gensim.models.keyedvectors.Vocab at 0x8b9f390>,
#  'nubanda[overseer]N': <gensim.models.keyedvectors.Vocab at 0x8b9f3c8>,
#  'ugula[overseer]N': <gensim.models.keyedvectors.Vocab at 0x8b9f400>,
#  '{d}en-lil₂-ukken-a': <gensim.models.keyedvectors.Vocab at 0x8b9f438>,
#  'sukkal[secretary]N': <gensim.models.keyedvectors.Vocab at 0x8b9f470>,
#  'guʾanše[total]N': <gensim.models.keyedvectors.Vocab at 0x8b9f4a8>,
#  'anše-apin': <gensim.models.keyedvectors.Vocab at 0x8b9f4e0>,
#  'u₂-dul₄': <gensim.models.keyedvectors.Vocab at 0x8b9f518>,
#  'dumu[child]N': <gensim.models.keyedvectors.Vocab at 0x8b9f550>,
#  'luʾad[official]N': <gensim.models.keyedvectors.Vocab at 0x8b9f588>,
#  'ur-e₂-gal': <gensim.models.keyedvectors.Vocab at 0x8b9f5c0>,
#  'nar[musician]N': <gensim.models.keyedvectors.Vocab at 0x8b9f5f8>,
#  'AK': <gensim.models.keyedvectors.Vocab at 0x8b9f668>,
#  'munu[malt]N': <gensim.models.keyedvectors.Vocab at 0x8b9f6a0>,
#  'KA-zi-da': <gensim.models.keyedvectors.Vocab at 0x8b9f6d8>,
#  'gal-x': <gensim.models.keyedvectors.Vocab at 0x8b9f748>,
#  'de[bring]V/t': <gensim.models.keyedvectors.Vocab at 0x8b9f780>,
#  'gub[stand]V/i': <gensim.models.keyedvectors.Vocab at 0x8b9f7b8>,
#  'lugal-u₃-ma': <gensim.models.keyedvectors.Vocab at 0x8b9f7f0>,
#  'inim-ma-ni-zi': <gensim.models.keyedvectors.Vocab at 0x8b9f828>,
#  'lugal-nig₂': <gensim.models.keyedvectors.Vocab at 0x8b9f860>,
#  'dag[side]N': <gensim.models.keyedvectors.Vocab at 0x8b9f898>,
#  'peš[fig]N': <gensim.models.keyedvectors.Vocab at 0x8b9f8d0>,
#  'ur-e₂-zi-da': <gensim.models.keyedvectors.Vocab at 0x8b9f908>,
#  'x-na': <gensim.models.keyedvectors.Vocab at 0x8b9f978>,
#  'x-ma': <gensim.models.keyedvectors.Vocab at 0x8b9f9e8>,
#  'a-da-DUR₂': <gensim.models.keyedvectors.Vocab at 0x8b9fa20>,
#  'e₂-da': <gensim.models.keyedvectors.Vocab at 0x8b9fa58>,
#  'šeš-ama-na': <gensim.models.keyedvectors.Vocab at 0x8b9fa90>,
#  'maškim[administrator]N': <gensim.models.keyedvectors.Vocab at 0x8b9fac8>,
#  'damgargal[merchant]N': <gensim.models.keyedvectors.Vocab at 0x8b9fb00>,
#  'šuba[stone]N': <gensim.models.keyedvectors.Vocab at 0x8b9fb38>,
#  'KA-x-x': <gensim.models.keyedvectors.Vocab at 0x8b9fba8>,
#  'urud[copper]N': <gensim.models.keyedvectors.Vocab at 0x8b9fbe0>,
#  'mana[unit]N': <gensim.models.keyedvectors.Vocab at 0x8b9fc18>,
#  'šah[pig]N': <gensim.models.keyedvectors.Vocab at 0x8b9fc50>,
#  'ad-da-tur': <gensim.models.keyedvectors.Vocab at 0x8b9fc88>,
#  '3(barig@c)': <gensim.models.keyedvectors.Vocab at 0x8b9fcc0>,
#  'ur-e₂-nun-gal': <gensim.models.keyedvectors.Vocab at 0x8b9fcf8>,
#  '2(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x8b9fd30>,
#  'RI-RI': <gensim.models.keyedvectors.Vocab at 0x8b9fda0>,
#  'šuʾi[barber]N': <gensim.models.keyedvectors.Vocab at 0x8b9fdd8>,
#  'a₂-ag₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x8b9fe10>,
#  'ad.KID[weaver]N': <gensim.models.keyedvectors.Vocab at 0x8b9fe48>,
#  '1/2(diš@c)': <gensim.models.keyedvectors.Vocab at 0x8b9fe80>,
#  'en-nu-kur-še₃': <gensim.models.keyedvectors.Vocab at 0x8b9feb8>,
#  '2(barig@c)': <gensim.models.keyedvectors.Vocab at 0x8b9fef0>,
#  'e₂-a-nun': <gensim.models.keyedvectors.Vocab at 0x8b9ff28>,
#  'lungak[brewer]N': <gensim.models.keyedvectors.Vocab at 0x8b9ff60>,
#  'KA-nun-zi': <gensim.models.keyedvectors.Vocab at 0x8b9ff98>,
#  'lidga[vessel]N': <gensim.models.keyedvectors.Vocab at 0x8b9ffd0>,
#  'lu[person]N': <gensim.models.keyedvectors.Vocab at 0x93d9048>,
#  'du₁₁-ga': <gensim.models.keyedvectors.Vocab at 0x93d9080>,
#  'NI': <gensim.models.keyedvectors.Vocab at 0x93d90f0>,
#  'DU': <gensim.models.keyedvectors.Vocab at 0x93d9160>,
#  '4(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x93d9198>,
#  '5(diš)': <gensim.models.keyedvectors.Vocab at 0x93d91d0>,
#  'ninda[bread]N': <gensim.models.keyedvectors.Vocab at 0x93d9208>,
#  'ud[sun]N': <gensim.models.keyedvectors.Vocab at 0x93d9240>,
#  'bad[wall]N': <gensim.models.keyedvectors.Vocab at 0x93d9278>,
#  'ŋi[night]N': <gensim.models.keyedvectors.Vocab at 0x93d92b0>,
#  'šeba[ration]N': <gensim.models.keyedvectors.Vocab at 0x93d92e8>,
#  'itud[moon]N': <gensim.models.keyedvectors.Vocab at 0x93d9320>,
#  'gu[eat]V/t': <gensim.models.keyedvectors.Vocab at 0x93d9358>,
#  'en-il₂': <gensim.models.keyedvectors.Vocab at 0x93d9390>,
#  '8(aš@c)': <gensim.models.keyedvectors.Vocab at 0x93d93c8>,
#  '3(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x93d9400>,
#  'maš[goat]N': <gensim.models.keyedvectors.Vocab at 0x93d9438>,
#  'ur[root]N': <gensim.models.keyedvectors.Vocab at 0x93d9470>,
#  'šum[give]V/t': <gensim.models.keyedvectors.Vocab at 0x93d94a8>,
#  'PA': <gensim.models.keyedvectors.Vocab at 0x93d9518>,
#  'TAG': <gensim.models.keyedvectors.Vocab at 0x93d9588>,
#  'kib[wheat]N': <gensim.models.keyedvectors.Vocab at 0x93d95c0>,
#  'he₂-sa₆': <gensim.models.keyedvectors.Vocab at 0x93d95f8>,
#  'šud₃': <gensim.models.keyedvectors.Vocab at 0x93d9630>,
#  'sanga': <gensim.models.keyedvectors.Vocab at 0x93d96a0>,
#  'HAR-tu-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x93d96d8>,
#  'zag[side]N': <gensim.models.keyedvectors.Vocab at 0x93d9710>,
#  'gud[ox]N': <gensim.models.keyedvectors.Vocab at 0x93d9748>,
#  'urra[loan]N': <gensim.models.keyedvectors.Vocab at 0x93d9780>,
#  'egal[palace]N': <gensim.models.keyedvectors.Vocab at 0x93d97b8>,
#  'tuku[acquire]V/t': <gensim.models.keyedvectors.Vocab at 0x93d97f0>,
#  'gur[unit]N': <gensim.models.keyedvectors.Vocab at 0x93d9828>,
#  'idu[doorkeeper]N': <gensim.models.keyedvectors.Vocab at 0x93d9860>,
#  'ur-dumu-nun': <gensim.models.keyedvectors.Vocab at 0x93d9898>,
#  'niŋir[herald]N': <gensim.models.keyedvectors.Vocab at 0x93d98d0>,
#  'ama-bur-ra': <gensim.models.keyedvectors.Vocab at 0x93d9908>,
#  'sug[replace]V/t': <gensim.models.keyedvectors.Vocab at 0x93d9940>,
#  'e₂-ki-ba': <gensim.models.keyedvectors.Vocab at 0x93d9978>,
#  'šagia[cup-bearer]N': <gensim.models.keyedvectors.Vocab at 0x93d99b0>,
#  'ša₃-ta-nu-e₃': <gensim.models.keyedvectors.Vocab at 0x93d99e8>,
#  'a-nun-{d}sud₃-da': <gensim.models.keyedvectors.Vocab at 0x93d9a20>,
#  'munumud[maltster]N': <gensim.models.keyedvectors.Vocab at 0x93d9a58>,
#  'me-lam₂-kur-ra': <gensim.models.keyedvectors.Vocab at 0x93d9a90>,
#  'ur-{d}tu': <gensim.models.keyedvectors.Vocab at 0x93d9ac8>,
#  'lugal-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x93d9b00>,
#  'e₂-nu-kur-si': <gensim.models.keyedvectors.Vocab at 0x93d9b38>,
#  'lu₂-lum-ma': <gensim.models.keyedvectors.Vocab at 0x93d9b70>,
#  'tul₂-sag-du₁₀': <gensim.models.keyedvectors.Vocab at 0x93d9ba8>,
#  'ugula-sukkal': <gensim.models.keyedvectors.Vocab at 0x93d9be0>,
#  'šeš[brother]N': <gensim.models.keyedvectors.Vocab at 0x93d9c18>,
#  'ur-nigin₃-si': <gensim.models.keyedvectors.Vocab at 0x93d9c50>,
#  'utu-ur-sag': <gensim.models.keyedvectors.Vocab at 0x93d9c88>,
#  'unug{ki}': <gensim.models.keyedvectors.Vocab at 0x93d9cc0>,
#  'nin[lady]N': <gensim.models.keyedvectors.Vocab at 0x93d9cf8>,
#  'pa₄-nu-la₂': <gensim.models.keyedvectors.Vocab at 0x93d9d30>,
#  'UR-UR': <gensim.models.keyedvectors.Vocab at 0x93d9da0>,
#  'e₂-nu-si': <gensim.models.keyedvectors.Vocab at 0x93d9dd8>,
#  'gurmah[unit]N': <gensim.models.keyedvectors.Vocab at 0x93d9e10>,
#  'ur-{d}nu-muš-da': <gensim.models.keyedvectors.Vocab at 0x93d9e48>,
#  'lal[syrup]N': <gensim.models.keyedvectors.Vocab at 0x93d9e80>,
#  'abzu-ki-du₁₀': <gensim.models.keyedvectors.Vocab at 0x93d9eb8>,
#  'bara₂-ki-ba': <gensim.models.keyedvectors.Vocab at 0x93d9ef0>,
#  'ur-utu': <gensim.models.keyedvectors.Vocab at 0x93d9f60>,
#  '1/2(aš@c)': <gensim.models.keyedvectors.Vocab at 0x93d9f98>,
#  'AK-{d}NE': <gensim.models.keyedvectors.Vocab at 0x93d9fd0>,
#  'uru[flood]N': <gensim.models.keyedvectors.Vocab at 0x93e3048>,
#  '{d}sud₃-anzu': <gensim.models.keyedvectors.Vocab at 0x93e3080>,
#  'NI-NI': <gensim.models.keyedvectors.Vocab at 0x93e30f0>,
#  'maš-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x93e3128>,
#  'sikil[pure]V/i': <gensim.models.keyedvectors.Vocab at 0x93e3160>,
#  'munus-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x93e3198>,
#  'SAL.UŠ[sheath]N': <gensim.models.keyedvectors.Vocab at 0x93e31d0>,
#  'mes-pa₃': <gensim.models.keyedvectors.Vocab at 0x93e3208>,
#  'ba-dag': <gensim.models.keyedvectors.Vocab at 0x93e3278>,
#  'a-geštin': <gensim.models.keyedvectors.Vocab at 0x93e32b0>,
#  'damgar[merchant]N': <gensim.models.keyedvectors.Vocab at 0x93e32e8>,
#  'AN-sag-tuku': <gensim.models.keyedvectors.Vocab at 0x93e3320>,
#  'amar-AN': <gensim.models.keyedvectors.Vocab at 0x93e3390>,
#  'adab{ki}': <gensim.models.keyedvectors.Vocab at 0x93e33c8>,
#  'nibru{ki}': <gensim.models.keyedvectors.Vocab at 0x93e3400>,
#  'umma{ki}': <gensim.models.keyedvectors.Vocab at 0x93e3438>,
#  'azu[doctor]N': <gensim.models.keyedvectors.Vocab at 0x93e3470>,
#  'a-si₄': <gensim.models.keyedvectors.Vocab at 0x93e34a8>,
#  'geš-DUL₃': <gensim.models.keyedvectors.Vocab at 0x93e34e0>,
#  'ar₃-du₂-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x93e3518>,
#  'gi₄-za₇': <gensim.models.keyedvectors.Vocab at 0x93e3550>,
#  'edin-si': <gensim.models.keyedvectors.Vocab at 0x93e35c0>,
#  'ur-{d}gu₂-la₂': <gensim.models.keyedvectors.Vocab at 0x93e35f8>,
#  'KA-lugal-da-zi': <gensim.models.keyedvectors.Vocab at 0x93e3630>,
#  'dingir-nu-me': <gensim.models.keyedvectors.Vocab at 0x93e3668>,
#  'diŋir[deity]N': <gensim.models.keyedvectors.Vocab at 0x93e36a0>,
#  'dumu-nun-šita': <gensim.models.keyedvectors.Vocab at 0x93e36d8>,
#  'ba-ba': <gensim.models.keyedvectors.Vocab at 0x93e3748>,
#  'x-zi-x': <gensim.models.keyedvectors.Vocab at 0x93e37b8>,
#  'KA-zi': <gensim.models.keyedvectors.Vocab at 0x93e3828>,
#  'e₂-sahar-ta-e₃': <gensim.models.keyedvectors.Vocab at 0x93e3860>,
#  'šu[hand]N': <gensim.models.keyedvectors.Vocab at 0x93e3898>,
#  'ar₃-du₂': <gensim.models.keyedvectors.Vocab at 0x93e38d0>,
#  'šag[heart]N': <gensim.models.keyedvectors.Vocab at 0x93e3908>,
#  'dingir-ur-sag': <gensim.models.keyedvectors.Vocab at 0x93e3940>,
#  'i₃-li₂-a': <gensim.models.keyedvectors.Vocab at 0x93e3978>,
#  'nam-mah₂': <gensim.models.keyedvectors.Vocab at 0x93e39b0>,
#  'ursaŋ[hero]N': <gensim.models.keyedvectors.Vocab at 0x93e39e8>,
#  'KISAL': <gensim.models.keyedvectors.Vocab at 0x93e3a58>,
#  'niŋ[thing]N': <gensim.models.keyedvectors.Vocab at 0x93e3a90>,
#  'umma[old-woman]N': <gensim.models.keyedvectors.Vocab at 0x93e3ac8>,
#  '{d}sud₃-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x93e3b00>,
#  '4(u@c)': <gensim.models.keyedvectors.Vocab at 0x93e3b70>,
#  '1(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x93e3ba8>,
#  'lul[false]V/i': <gensim.models.keyedvectors.Vocab at 0x93e3be0>,
#  'lu-lu': <gensim.models.keyedvectors.Vocab at 0x93e3c50>,
#  'eden-si': <gensim.models.keyedvectors.Vocab at 0x93e3cc0>,
#  'nimgir-mete-na': <gensim.models.keyedvectors.Vocab at 0x93e3cf8>,
#  'sanga-GAR': <gensim.models.keyedvectors.Vocab at 0x93e3d30>,
#  'e₂-ušum-gal': <gensim.models.keyedvectors.Vocab at 0x93e3d68>,
#  'e₂-hur-sag': <gensim.models.keyedvectors.Vocab at 0x93e3da0>,
#  'nam-mah-{d}sud₃-da': <gensim.models.keyedvectors.Vocab at 0x93e3dd8>,
#  'amar-abzu': <gensim.models.keyedvectors.Vocab at 0x93e3e10>,
#  'a-du₆-la': <gensim.models.keyedvectors.Vocab at 0x93e3e48>,
#  'KU-sag': <gensim.models.keyedvectors.Vocab at 0x93e3eb8>,
#  'AK-du₆': <gensim.models.keyedvectors.Vocab at 0x93e3ef0>,
#  'ama-ig-gal': <gensim.models.keyedvectors.Vocab at 0x93e3f28>,
#  'al₆-la': <gensim.models.keyedvectors.Vocab at 0x93e3f60>,
#  'šul-la': <gensim.models.keyedvectors.Vocab at 0x93e3f98>,
#  'pa₄-ur-sag': <gensim.models.keyedvectors.Vocab at 0x93e3fd0>,
#  'za-ra': <gensim.models.keyedvectors.Vocab at 0x93eb080>,
#  'gissu-še₃': <gensim.models.keyedvectors.Vocab at 0x93eb0b8>,
#  'lu₂-pa₃': <gensim.models.keyedvectors.Vocab at 0x93eb0f0>,
#  'ensi₂-GAR-gal': <gensim.models.keyedvectors.Vocab at 0x93eb128>,
#  'AŠ': <gensim.models.keyedvectors.Vocab at 0x93eb160>,
#  'ur-lugal-DU': <gensim.models.keyedvectors.Vocab at 0x93eb198>,
#  'gal-kinda₂': <gensim.models.keyedvectors.Vocab at 0x93eb1d0>,
#  'muhaldim[cook]N': <gensim.models.keyedvectors.Vocab at 0x93eb208>,
#  'SUR-gu-nun': <gensim.models.keyedvectors.Vocab at 0x93eb240>,
#  '{d}gibil₆': <gensim.models.keyedvectors.Vocab at 0x93eb278>,
#  'gal-unken': <gensim.models.keyedvectors.Vocab at 0x93eb2b0>,
#  'kur[different]V/i': <gensim.models.keyedvectors.Vocab at 0x93eb2e8>,
#  'pa-e₃': <gensim.models.keyedvectors.Vocab at 0x93eb320>,
#  'x-ra': <gensim.models.keyedvectors.Vocab at 0x93eb390>,
#  'enku{ku₆}': <gensim.models.keyedvectors.Vocab at 0x93eb3c8>,
#  'lumagur[boatman]N': <gensim.models.keyedvectors.Vocab at 0x93eb400>,
#  'dubsarmah[official]N': <gensim.models.keyedvectors.Vocab at 0x93eb438>,
#  '3(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x93eb470>,
#  'ur-dumu-zi-da': <gensim.models.keyedvectors.Vocab at 0x93eb4a8>,
#  'lu₂-bara₂-si': <gensim.models.keyedvectors.Vocab at 0x93eb4e0>,
#  'mah[great]V/i': <gensim.models.keyedvectors.Vocab at 0x93eb518>,
#  'maškim-gi₄': <gensim.models.keyedvectors.Vocab at 0x93eb550>,
#  'gu-ni-DU': <gensim.models.keyedvectors.Vocab at 0x93eb588>,
#  'ugulaʾek[overseer]N': <gensim.models.keyedvectors.Vocab at 0x93eb5c0>,
#  'nargal[musician]N': <gensim.models.keyedvectors.Vocab at 0x93eb5f8>,
#  'AB': <gensim.models.keyedvectors.Vocab at 0x93eb668>,
#  '{d}en-lil₂': <gensim.models.keyedvectors.Vocab at 0x93eb6a0>,
#  'šugi[senior]N': <gensim.models.keyedvectors.Vocab at 0x93eb6d8>,
#  'lu₂-e₂-zi': <gensim.models.keyedvectors.Vocab at 0x93eb710>,
#  'lugal-ezem': <gensim.models.keyedvectors.Vocab at 0x93eb748>,
#  'e₂-UD-nu-dib': <gensim.models.keyedvectors.Vocab at 0x93eb780>,
#  'sa-HAR': <gensim.models.keyedvectors.Vocab at 0x93eb7f0>,
#  'dar[split]V/t': <gensim.models.keyedvectors.Vocab at 0x93eb828>,
#  'e₂-ki-gal-la': <gensim.models.keyedvectors.Vocab at 0x93eb860>,
#  'AK-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x93eb898>,
#  'ekur[prison]N': <gensim.models.keyedvectors.Vocab at 0x93eb8d0>,
#  'AN': <gensim.models.keyedvectors.Vocab at 0x93eb940>,
#  'zi₃@t': <gensim.models.keyedvectors.Vocab at 0x93eb978>,
#  'ba[animal]N': <gensim.models.keyedvectors.Vocab at 0x93eb9b0>,
#  '6(barig@c)': <gensim.models.keyedvectors.Vocab at 0x93eb9e8>,
#  'sila[unit]N': <gensim.models.keyedvectors.Vocab at 0x93eba20>,
#  'teŋ[approach]V/i': <gensim.models.keyedvectors.Vocab at 0x93eba58>,
#  'utu-di-ku₅': <gensim.models.keyedvectors.Vocab at 0x93eba90>,
#  'amar-e₂-gibil': <gensim.models.keyedvectors.Vocab at 0x93ebac8>,
#  'mušlah[charmer]N': <gensim.models.keyedvectors.Vocab at 0x93ebb00>,
#  'amar-{d}iškur': <gensim.models.keyedvectors.Vocab at 0x93ebb38>,
#  'ur-tul₂-sag': <gensim.models.keyedvectors.Vocab at 0x93ebb70>,
#  'pa-bilₓ(|GIŠ.PAP.NE|)-ga': <gensim.models.keyedvectors.Vocab at 0x93ebba8>,
#  'me-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x93ebbe0>,
#  'e₂-u₂': <gensim.models.keyedvectors.Vocab at 0x93ebc18>,
#  'u₄-kur-ra': <gensim.models.keyedvectors.Vocab at 0x93ebc50>,
#  'amar-{d}tu': <gensim.models.keyedvectors.Vocab at 0x93ebc88>,
#  'mes-nu-še₃': <gensim.models.keyedvectors.Vocab at 0x93ebcc0>,
#  '{d}sud₃-da-zi': <gensim.models.keyedvectors.Vocab at 0x93ebcf8>,
#  'addirₓ(|LAK589.A.SI|)': <gensim.models.keyedvectors.Vocab at 0x93ebd30>,
#  '{d}en-lil₂-unken-a': <gensim.models.keyedvectors.Vocab at 0x93ebd68>,
#  'šita-KAL': <gensim.models.keyedvectors.Vocab at 0x93ebda0>,
#  'a-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x93ebdd8>,
#  'a-NI': <gensim.models.keyedvectors.Vocab at 0x93ebe48>,
#  'ur-{d}en-ki': <gensim.models.keyedvectors.Vocab at 0x93ebe80>,
#  'e₂-du₆': <gensim.models.keyedvectors.Vocab at 0x93ebeb8>,
#  'ki-ni-du₁₀': <gensim.models.keyedvectors.Vocab at 0x93ebef0>,
#  'bilₓ(|GIŠ.PAP.NE|)-kalam-du₁₀': <gensim.models.keyedvectors.Vocab at 0x93ebf28>,
#  'e₂-{d}anzu': <gensim.models.keyedvectors.Vocab at 0x93ebf60>,
#  'utu-ki-gal': <gensim.models.keyedvectors.Vocab at 0x93ebf98>,
#  'UŠ': <gensim.models.keyedvectors.Vocab at 0x93ebfd0>,
#  'en-nam-zu₅-še₃': <gensim.models.keyedvectors.Vocab at 0x93f4048>,
#  'e₂-na-lu-lu': <gensim.models.keyedvectors.Vocab at 0x93f4080>,
#  'lu₂-{giš}BULUG₃': <gensim.models.keyedvectors.Vocab at 0x93f40b8>,
#  'e₂-nun-KA': <gensim.models.keyedvectors.Vocab at 0x93f40f0>,
#  'mes-u₄-ba': <gensim.models.keyedvectors.Vocab at 0x93f4128>,
#  'zig[rise]V/t': <gensim.models.keyedvectors.Vocab at 0x93f4160>,
#  'kur-ra-a₂-gal₂': <gensim.models.keyedvectors.Vocab at 0x93f4198>,
#  'ni₂-zu₅-kur-še₃': <gensim.models.keyedvectors.Vocab at 0x93f41d0>,
#  'a-hu-ti': <gensim.models.keyedvectors.Vocab at 0x93f4240>,
#  'pa₄-{d}anzu': <gensim.models.keyedvectors.Vocab at 0x93f4278>,
#  'šita-kalam': <gensim.models.keyedvectors.Vocab at 0x93f42b0>,
#  'ur-{d}en-lil₂': <gensim.models.keyedvectors.Vocab at 0x93f42e8>,
#  'ludag[official]N': <gensim.models.keyedvectors.Vocab at 0x93f4320>,
#  'e₂-{d}nanna': <gensim.models.keyedvectors.Vocab at 0x93f4358>,
#  'KA-ni-zi': <gensim.models.keyedvectors.Vocab at 0x93f4390>,
#  'ba-za₇': <gensim.models.keyedvectors.Vocab at 0x93f43c8>,
#  'aya[father]N': <gensim.models.keyedvectors.Vocab at 0x93f4400>,
#  'dub-hul-tar': <gensim.models.keyedvectors.Vocab at 0x93f4438>,
#  'mes-ni₃-lul-le': <gensim.models.keyedvectors.Vocab at 0x93f4470>,
#  'udu[sheep]N': <gensim.models.keyedvectors.Vocab at 0x93f44a8>,
#  'lugal-zi-kalam': <gensim.models.keyedvectors.Vocab at 0x93f44e0>,
#  'UR': <gensim.models.keyedvectors.Vocab at 0x93f4550>,
#  'nig₂-pa₃-da': <gensim.models.keyedvectors.Vocab at 0x93f4588>,
#  'uzud[goat]N': <gensim.models.keyedvectors.Vocab at 0x93f45c0>,
#  'aktum[garment]N': <gensim.models.keyedvectors.Vocab at 0x93f45f8>,
#  'tug[textile]N': <gensim.models.keyedvectors.Vocab at 0x93f4630>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x93f4668>,
#  'ur-{d}nin-mu₂': <gensim.models.keyedvectors.Vocab at 0x93f46a0>,
#  'sa[pay-for]V/t': <gensim.models.keyedvectors.Vocab at 0x93f46d8>,
#  'lugal-x-x': <gensim.models.keyedvectors.Vocab at 0x93f4710>,
#  'ki-inim': <gensim.models.keyedvectors.Vocab at 0x93f4780>,
#  'ara₃': <gensim.models.keyedvectors.Vocab at 0x93f47b8>,
#  'me-an-ne₂-si': <gensim.models.keyedvectors.Vocab at 0x93f47f0>,
#  'zabar[bronze]N': <gensim.models.keyedvectors.Vocab at 0x93f4828>,
#  'gamgam[fish]N': <gensim.models.keyedvectors.Vocab at 0x93f4860>,
#  'ak[do]V/t': <gensim.models.keyedvectors.Vocab at 0x93f4898>,
#  'KA-ki-bi-še₃': <gensim.models.keyedvectors.Vocab at 0x93f48d0>,
#  'nig₂-hu-bu₇{bu}': <gensim.models.keyedvectors.Vocab at 0x93f4908>,
#  'ki-ni': <gensim.models.keyedvectors.Vocab at 0x93f4978>,
#  'kun-du₆': <gensim.models.keyedvectors.Vocab at 0x93f49b0>,
#  'šukud[fisherman]N': <gensim.models.keyedvectors.Vocab at 0x93f49e8>,
#  '2/4(aš@c)': <gensim.models.keyedvectors.Vocab at 0x93f4a20>,
#  'x-si': <gensim.models.keyedvectors.Vocab at 0x93f4a90>,
#  'gukkal[sheep]N': <gensim.models.keyedvectors.Vocab at 0x93f4ac8>,
#  'en-x-x': <gensim.models.keyedvectors.Vocab at 0x93f4b38>,
#  'giŋ[unit]N': <gensim.models.keyedvectors.Vocab at 0x93f4b70>,
#  'sar[garden]N': <gensim.models.keyedvectors.Vocab at 0x93f4ba8>,
#  'niŋdirig[extra]N': <gensim.models.keyedvectors.Vocab at 0x93f4be0>,
#  'du[build]V/t': <gensim.models.keyedvectors.Vocab at 0x93f4c18>,
#  'niŋba[gift]N': <gensim.models.keyedvectors.Vocab at 0x93f4c50>,
#  'siki[hair]N': <gensim.models.keyedvectors.Vocab at 0x93f4c88>,
#  'gug[cake]N': <gensim.models.keyedvectors.Vocab at 0x93f4cc0>,
#  'kur[unit]N': <gensim.models.keyedvectors.Vocab at 0x93f4cf8>,
#  'tu₇(|HI×AŠ@c|)': <gensim.models.keyedvectors.Vocab at 0x93f4d30>,
#  '|LAGAB×(HA.A)|': <gensim.models.keyedvectors.Vocab at 0x93f4d68>,
#  'i[oil]N': <gensim.models.keyedvectors.Vocab at 0x93f4dd8>,
#  'nin-a-zu': <gensim.models.keyedvectors.Vocab at 0x93f4e10>,
#  'il[raise]V/t': <gensim.models.keyedvectors.Vocab at 0x93f4e48>,
#  'tu[soup]N': <gensim.models.keyedvectors.Vocab at 0x93f4e80>,
#  'e₂-ur₂-bi-du₁₀': <gensim.models.keyedvectors.Vocab at 0x93f4eb8>,
#  'giri₃-ni-ba-dab₅': <gensim.models.keyedvectors.Vocab at 0x93f4ef0>,
#  'RI-ti': <gensim.models.keyedvectors.Vocab at 0x93f4f60>,
#  'kigu[~land]N': <gensim.models.keyedvectors.Vocab at 0x93f4f98>,
#  'ur-abzu': <gensim.models.keyedvectors.Vocab at 0x93fb048>,
#  'ki-ni-mu-zu': <gensim.models.keyedvectors.Vocab at 0x93fb080>,
#  'me-an-ne₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x93fb0b8>,
#  'ur-{d}inanna': <gensim.models.keyedvectors.Vocab at 0x93fb0f0>,
#  'ummia[expert]N': <gensim.models.keyedvectors.Vocab at 0x93fb128>,
#  'ŋar[place]V/t': <gensim.models.keyedvectors.Vocab at 0x93fb160>,
#  'da-da': <gensim.models.keyedvectors.Vocab at 0x93fb1d0>,
#  'sila[street]N': <gensim.models.keyedvectors.Vocab at 0x93fb208>,
#  'gan-ezem': <gensim.models.keyedvectors.Vocab at 0x93fb240>,
#  'gallagal[policeman]N': <gensim.models.keyedvectors.Vocab at 0x93fb278>,
#  'bala[turn]V/t': <gensim.models.keyedvectors.Vocab at 0x93fb2b0>,
#  'AK-nab': <gensim.models.keyedvectors.Vocab at 0x93fb320>,
#  'ŠEŠ-KI-na': <gensim.models.keyedvectors.Vocab at 0x93fb358>,
#  'e₂-ezem-du₁₀': <gensim.models.keyedvectors.Vocab at 0x93fb390>,
#  'nin-sun₂-zi': <gensim.models.keyedvectors.Vocab at 0x93fb3c8>,
#  'GUR₈': <gensim.models.keyedvectors.Vocab at 0x93fb400>,
#  'mes-e₂-zi-da': <gensim.models.keyedvectors.Vocab at 0x93fb438>,
#  'amar-KID-NUN': <gensim.models.keyedvectors.Vocab at 0x93fb470>,
#  'šeš-pa₃': <gensim.models.keyedvectors.Vocab at 0x93fb4a8>,
#  'en-guruš-zi': <gensim.models.keyedvectors.Vocab at 0x93fb4e0>,
#  'gugal[inspector]N': <gensim.models.keyedvectors.Vocab at 0x93fb518>,
#  'luma[boatman]N': <gensim.models.keyedvectors.Vocab at 0x93fb550>,
#  '{an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x93fb588>,
#  'ur₂-x': <gensim.models.keyedvectors.Vocab at 0x93fb5c0>,
#  'e₂-sahar': <gensim.models.keyedvectors.Vocab at 0x93fb5f8>,
#  'ta': <gensim.models.keyedvectors.Vocab at 0x93fb668>,
#  '{d}sud₃-anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x93fb6a0>,
#  'utu-nu-me': <gensim.models.keyedvectors.Vocab at 0x93fb6d8>,
#  'x-NI': <gensim.models.keyedvectors.Vocab at 0x93fb748>,
#  'tugdu[felter]N': <gensim.models.keyedvectors.Vocab at 0x93fb780>,
#  'pa-bilₓ(|PAP.GEŠ.BIL|)-ga': <gensim.models.keyedvectors.Vocab at 0x93fb7b8>,
#  'za₇-gin₃': <gensim.models.keyedvectors.Vocab at 0x93fb7f0>,
#  'gu[pulse]N': <gensim.models.keyedvectors.Vocab at 0x93fb828>,
#  'gal-dam-gar₃': <gensim.models.keyedvectors.Vocab at 0x93fb860>,
#  '{d}PA': <gensim.models.keyedvectors.Vocab at 0x93fb8d0>,
#  'saŋ[head]N': <gensim.models.keyedvectors.Vocab at 0x93fb908>,
#  'us[side]N': <gensim.models.keyedvectors.Vocab at 0x93fb940>,
#  'saŋdu[beam]N': <gensim.models.keyedvectors.Vocab at 0x93fb978>,
#  'dalla[ring]N': <gensim.models.keyedvectors.Vocab at 0x93fb9b0>,
#  'su₆-mu₂': <gensim.models.keyedvectors.Vocab at 0x93fb9e8>,
#  'ba[allot]V/t': <gensim.models.keyedvectors.Vocab at 0x93fba20>,
#  'atu[doorkeeper?]N': <gensim.models.keyedvectors.Vocab at 0x93fba58>,
#  'mun[salt]V/i': <gensim.models.keyedvectors.Vocab at 0x93fba90>,
#  'ur[pluck]V/t': <gensim.models.keyedvectors.Vocab at 0x93fbac8>,
#  'dam[spouse]N': <gensim.models.keyedvectors.Vocab at 0x93fbb00>,
#  'be₆-li₂-li₂': <gensim.models.keyedvectors.Vocab at 0x93fbb38>,
#  'geme[worker]N': <gensim.models.keyedvectors.Vocab at 0x93fbb70>,
#  '{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x93fbba8>,
#  'ša₃-zu': <gensim.models.keyedvectors.Vocab at 0x93fbbe0>,
#  'kinud[bedroom]N': <gensim.models.keyedvectors.Vocab at 0x93fbc18>,
#  'ur-{d}nin-PA': <gensim.models.keyedvectors.Vocab at 0x93fbc50>,
#  'na-na': <gensim.models.keyedvectors.Vocab at 0x93fbcc0>,
#  '1(aš@v)': <gensim.models.keyedvectors.Vocab at 0x93fbcf8>,
#  'x-x-x': <gensim.models.keyedvectors.Vocab at 0x93fbd68>,
#  'allub[crab]N': <gensim.models.keyedvectors.Vocab at 0x93fbda0>,
#  'pa': <gensim.models.keyedvectors.Vocab at 0x93fbe10>,
#  'ezem[festival]N': <gensim.models.keyedvectors.Vocab at 0x93fbe48>,
#  'bahar₂': <gensim.models.keyedvectors.Vocab at 0x93fbe80>,
#  'ma': <gensim.models.keyedvectors.Vocab at 0x93fbef0>,
#  'ki[place]N': <gensim.models.keyedvectors.Vocab at 0x93fbf28>,
#  'niŋsi[provisions]N': <gensim.models.keyedvectors.Vocab at 0x93fbf60>,
#  'kuš[skin]N': <gensim.models.keyedvectors.Vocab at 0x93fbf98>,
#  'si[horn]N': <gensim.models.keyedvectors.Vocab at 0x93fbfd0>,
#  'kur[mountain]N': <gensim.models.keyedvectors.Vocab at 0x9404048>,
#  'maš-da₅': <gensim.models.keyedvectors.Vocab at 0x9404080>,
#  'zir[break]V/t': <gensim.models.keyedvectors.Vocab at 0x94040b8>,
#  'aš-ni': <gensim.models.keyedvectors.Vocab at 0x94040f0>,
#  'e₂-la-lumₓ(LAK218)': <gensim.models.keyedvectors.Vocab at 0x9404128>,
#  'amar-IMMAL': <gensim.models.keyedvectors.Vocab at 0x9404160>,
#  'nag-su': <gensim.models.keyedvectors.Vocab at 0x94041d0>,
#  'AN-ur₂-še₃': <gensim.models.keyedvectors.Vocab at 0x9404208>,
#  'azlag₄': <gensim.models.keyedvectors.Vocab at 0x9404240>,
#  'za₃-ta': <gensim.models.keyedvectors.Vocab at 0x9404278>,
#  'lugal-ki-tuš-du₁₀': <gensim.models.keyedvectors.Vocab at 0x94042b0>,
#  'lugal-dumu-zi': <gensim.models.keyedvectors.Vocab at 0x94042e8>,
#  'aša₅': <gensim.models.keyedvectors.Vocab at 0x9404320>,
#  'al₆-lu-lu': <gensim.models.keyedvectors.Vocab at 0x9404358>,
#  '5(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x9404390>,
#  '5(diš@t)': <gensim.models.keyedvectors.Vocab at 0x94043c8>,
#  'šidim[builder]N': <gensim.models.keyedvectors.Vocab at 0x9404400>,
#  'lugal-ki-gal-la': <gensim.models.keyedvectors.Vocab at 0x9404438>,
#  'ama-x': <gensim.models.keyedvectors.Vocab at 0x94044a8>,
#  'ga-x': <gensim.models.keyedvectors.Vocab at 0x9404518>,
#  '7(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x9404550>,
#  'sag-nin-tuku': <gensim.models.keyedvectors.Vocab at 0x9404588>,
#  'nin-ama-na': <gensim.models.keyedvectors.Vocab at 0x94045c0>,
#  'geš-kin': <gensim.models.keyedvectors.Vocab at 0x94045f8>,
#  'lugal[king]N': <gensim.models.keyedvectors.Vocab at 0x9404630>,
#  'šešbanda[relation]N': <gensim.models.keyedvectors.Vocab at 0x9404668>,
#  '2(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x94046a0>,
#  'lugal-bara₂-si': <gensim.models.keyedvectors.Vocab at 0x94046d8>,
#  '5(u@c)': <gensim.models.keyedvectors.Vocab at 0x9404748>,
#  'e₂-zi-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x9404780>,
#  'UD': <gensim.models.keyedvectors.Vocab at 0x94047f0>,
#  'x-du₁₀': <gensim.models.keyedvectors.Vocab at 0x9404828>,
#  '6(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x9404860>,
#  'kuli[unit]N': <gensim.models.keyedvectors.Vocab at 0x9404898>,
#  'gišgal-si': <gensim.models.keyedvectors.Vocab at 0x94048d0>,
#  '2(gešʾu@c)': <gensim.models.keyedvectors.Vocab at 0x9404908>,
#  'si-|NU×U|': <gensim.models.keyedvectors.Vocab at 0x9404940>,
#  'ensi₂-GAR': <gensim.models.keyedvectors.Vocab at 0x9404978>,
#  'en[priest]N': <gensim.models.keyedvectors.Vocab at 0x94049b0>,
#  'kinda[barber]N': <gensim.models.keyedvectors.Vocab at 0x94049e8>,
#  'niŋara[groats]N': <gensim.models.keyedvectors.Vocab at 0x9404a20>,
#  '{d}en-lil₂-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x9404a58>,
#  'lu₂-na-nam': <gensim.models.keyedvectors.Vocab at 0x9404a90>,
#  'pa₄-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x9404ac8>,
#  'sag-TAR': <gensim.models.keyedvectors.Vocab at 0x9404b38>,
#  '{d}suen': <gensim.models.keyedvectors.Vocab at 0x9404ba8>,
#  'e₂-x': <gensim.models.keyedvectors.Vocab at 0x9404be0>,
#  'lugal-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x9404c18>,
#  'lugal-ki-dur₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x9404c50>,
#  'amar[young]N': <gensim.models.keyedvectors.Vocab at 0x9404c88>,
#  '{d}ŠEŠ-KI-na': <gensim.models.keyedvectors.Vocab at 0x9404cc0>,
#  'a-x-x': <gensim.models.keyedvectors.Vocab at 0x9404d30>,
#  'AN-URUDU-si': <gensim.models.keyedvectors.Vocab at 0x9404d68>,
#  'du[go]V/t': <gensim.models.keyedvectors.Vocab at 0x9404da0>,
#  'e₂-kur-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x9404dd8>,
#  '{d}sud₃-nu-me': <gensim.models.keyedvectors.Vocab at 0x9404e10>,
#  'ab-ba-ni': <gensim.models.keyedvectors.Vocab at 0x9404e48>,
#  'amar-KID-nun': <gensim.models.keyedvectors.Vocab at 0x9404e80>,
#  'sila[lamb]N': <gensim.models.keyedvectors.Vocab at 0x9404eb8>,
#  'nita[male]N': <gensim.models.keyedvectors.Vocab at 0x9404ef0>,
#  'LAK020[goat]N': <gensim.models.keyedvectors.Vocab at 0x9404f28>,
#  'u[ewe]N': <gensim.models.keyedvectors.Vocab at 0x9404f98>,
#  'utu-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x9404fd0>,
#  'tur[small]V/i': <gensim.models.keyedvectors.Vocab at 0x940d048>,
#  'AN-AK': <gensim.models.keyedvectors.Vocab at 0x940d0b8>,
#  'ur-{d}dumu-zi': <gensim.models.keyedvectors.Vocab at 0x940d0f0>,
#  '|SUR.GU|': <gensim.models.keyedvectors.Vocab at 0x940d128>,
#  'nin-da-mah-di': <gensim.models.keyedvectors.Vocab at 0x940d160>,
#  'ur-{d}nin-pirig': <gensim.models.keyedvectors.Vocab at 0x940d198>,
#  'igi-ildu₃-še₃@90': <gensim.models.keyedvectors.Vocab at 0x940d1d0>,
#  'lugal-si-sa₂': <gensim.models.keyedvectors.Vocab at 0x940d208>,
#  'ab-ba-tur': <gensim.models.keyedvectors.Vocab at 0x940d240>,
#  'ku₃-la₂': <gensim.models.keyedvectors.Vocab at 0x940d278>,
#  'lugal-šeš': <gensim.models.keyedvectors.Vocab at 0x940d2b0>,
#  'lugal-an-dul₃': <gensim.models.keyedvectors.Vocab at 0x940d2e8>,
#  'dingir-a-zu': <gensim.models.keyedvectors.Vocab at 0x940d320>,
#  'lugal-e₂-ni-še₃': <gensim.models.keyedvectors.Vocab at 0x940d358>,
#  'ša₃-nu-gal₂': <gensim.models.keyedvectors.Vocab at 0x940d390>,
#  'e₂-šeš': <gensim.models.keyedvectors.Vocab at 0x940d3c8>,
#  'lugal-sa₆-ga': <gensim.models.keyedvectors.Vocab at 0x940d400>,
#  'gal[big]V/i': <gensim.models.keyedvectors.Vocab at 0x940d438>,
#  '2(gešmin@c)': <gensim.models.keyedvectors.Vocab at 0x940d470>,
#  'baza[dwarf]N': <gensim.models.keyedvectors.Vocab at 0x940d4a8>,
#  'la[hang]V/t': <gensim.models.keyedvectors.Vocab at 0x940d4e0>,
#  'ur-x-x': <gensim.models.keyedvectors.Vocab at 0x940d550>,
#  'mu-kur-ta': <gensim.models.keyedvectors.Vocab at 0x940d588>,
#  'an-dab₆-si': <gensim.models.keyedvectors.Vocab at 0x940d5c0>,
#  'x-nam': <gensim.models.keyedvectors.Vocab at 0x940d630>,
#  'me-mah-nu-sa₂': <gensim.models.keyedvectors.Vocab at 0x940d668>,
#  'dub[tablet]N': <gensim.models.keyedvectors.Vocab at 0x940d6a0>,
#  'dili[single]V/i': <gensim.models.keyedvectors.Vocab at 0x940d6d8>,
#  '3(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x940d710>,
#  'magur[barge]N': <gensim.models.keyedvectors.Vocab at 0x940d748>,
#  'RU[~architecture]N': <gensim.models.keyedvectors.Vocab at 0x940d780>,
#  'ŋeškiŋti[workshop]N': <gensim.models.keyedvectors.Vocab at 0x940d7b8>,
#  'zagšu[brand]N': <gensim.models.keyedvectors.Vocab at 0x940d7f0>,
#  'lah[bring]V/t': <gensim.models.keyedvectors.Vocab at 0x940d828>,
#  'iri[city]N': <gensim.models.keyedvectors.Vocab at 0x940d860>,
#  'ur-{d}eš-peš': <gensim.models.keyedvectors.Vocab at 0x940d898>,
#  '9(aš@c)': <gensim.models.keyedvectors.Vocab at 0x940d8d0>,
#  'nita-tur': <gensim.models.keyedvectors.Vocab at 0x940d908>,
#  '4(barig@c)': <gensim.models.keyedvectors.Vocab at 0x940d940>,
#  'lam-ma': <gensim.models.keyedvectors.Vocab at 0x940d9b0>,
#  'ašgar[kid]N': <gensim.models.keyedvectors.Vocab at 0x940d9e8>,
#  'ibadu[garment]N': <gensim.models.keyedvectors.Vocab at 0x940da20>,
#  '|GA₂×(HA.A)|': <gensim.models.keyedvectors.Vocab at 0x940da58>,
#  'ur-{d}nin-unu': <gensim.models.keyedvectors.Vocab at 0x940da90>,
#  'a-har-ši': <gensim.models.keyedvectors.Vocab at 0x940dac8>,
#  'da-du-lul': <gensim.models.keyedvectors.Vocab at 0x940db00>,
#  'engar-us₂': <gensim.models.keyedvectors.Vocab at 0x940db38>,
#  'inim-{d}sud₃-da-zi': <gensim.models.keyedvectors.Vocab at 0x940db70>,
#  'šeš-ama(LAK769)-na': <gensim.models.keyedvectors.Vocab at 0x940dba8>,
#  'inim-ni-zi': <gensim.models.keyedvectors.Vocab at 0x940dbe0>,
#  'usan₃-du₃': <gensim.models.keyedvectors.Vocab at 0x940dc18>,
#  'lu₂-x': <gensim.models.keyedvectors.Vocab at 0x940dc50>,
#  'me₃': <gensim.models.keyedvectors.Vocab at 0x940dc88>,
#  'niŋgu[food]N': <gensim.models.keyedvectors.Vocab at 0x940dcc0>,
#  'gi₄-za': <gensim.models.keyedvectors.Vocab at 0x940dcf8>,
#  'amar-{d}šuba₃': <gensim.models.keyedvectors.Vocab at 0x940dd30>,
#  'ki-nir': <gensim.models.keyedvectors.Vocab at 0x940dda0>,
#  'amar-{d}PA': <gensim.models.keyedvectors.Vocab at 0x940ddd8>,
#  'šul[youth]V/i': <gensim.models.keyedvectors.Vocab at 0x940de10>,
#  'a-du₇': <gensim.models.keyedvectors.Vocab at 0x940de48>,
#  'ur-NI': <gensim.models.keyedvectors.Vocab at 0x940deb8>,
#  'a-NE-nu': <gensim.models.keyedvectors.Vocab at 0x940df28>,
#  'KA-lugal-zi-da': <gensim.models.keyedvectors.Vocab at 0x940df60>,
#  'en-abzu-ta-mud': <gensim.models.keyedvectors.Vocab at 0x940df98>,
#  'sangaₓ(|ŠID.NIG₂|)': <gensim.models.keyedvectors.Vocab at 0x940dfd0>,
#  'ensikgal[governor]N': <gensim.models.keyedvectors.Vocab at 0x9418048>,
#  'a-du₆': <gensim.models.keyedvectors.Vocab at 0x9418080>,
#  'lu₂-HAR': <gensim.models.keyedvectors.Vocab at 0x94180b8>,
#  '{d}ad-ašgi₂{gi₄}-ur-sag': <gensim.models.keyedvectors.Vocab at 0x94180f0>,
#  'a-nun-pa₃': <gensim.models.keyedvectors.Vocab at 0x9418128>,
#  'lu₂-lal₃': <gensim.models.keyedvectors.Vocab at 0x9418160>,
#  'MI': <gensim.models.keyedvectors.Vocab at 0x94181d0>,
#  'e₂-du₇-du₇': <gensim.models.keyedvectors.Vocab at 0x9418208>,
#  'nig₂-gal₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x9418240>,
#  'AK-dingir': <gensim.models.keyedvectors.Vocab at 0x9418278>,
#  'ašgabgal[leatherworker]N': <gensim.models.keyedvectors.Vocab at 0x94182b0>,
#  'dabin[semolina]N': <gensim.models.keyedvectors.Vocab at 0x94182e8>,
#  'bur-nun-si': <gensim.models.keyedvectors.Vocab at 0x9418320>,
#  'babbar[white]V/i': <gensim.models.keyedvectors.Vocab at 0x9418358>,
#  'nida': <gensim.models.keyedvectors.Vocab at 0x94183c8>,
#  'aslum[sheep]N': <gensim.models.keyedvectors.Vocab at 0x9418400>,
#  'AK-AN': <gensim.models.keyedvectors.Vocab at 0x9418470>,
#  'mar[wagon]N': <gensim.models.keyedvectors.Vocab at 0x94184a8>,
#  'šir-ezen': <gensim.models.keyedvectors.Vocab at 0x94184e0>,
#  'ur-e₂': <gensim.models.keyedvectors.Vocab at 0x9418518>,
#  'ur-{d}TAG-nun': <gensim.models.keyedvectors.Vocab at 0x9418550>,
#  'ga-ri': <gensim.models.keyedvectors.Vocab at 0x94185c0>,
#  'lu₂-geme₂-zi': <gensim.models.keyedvectors.Vocab at 0x94185f8>,
#  'LAK343': <gensim.models.keyedvectors.Vocab at 0x9418668>,
#  'en-MU-du₁₀': <gensim.models.keyedvectors.Vocab at 0x94186a0>,
#  'ur-{d}lamma': <gensim.models.keyedvectors.Vocab at 0x94186d8>,
#  'zum-da': <gensim.models.keyedvectors.Vocab at 0x9418748>,
#  'ur-{d}{še₃}šer₇-da': <gensim.models.keyedvectors.Vocab at 0x9418780>,
#  'gissu-bi': <gensim.models.keyedvectors.Vocab at 0x94187b8>,
#  'a-nun-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x94187f0>,
#  'lu₂-ninda₂': <gensim.models.keyedvectors.Vocab at 0x9418828>,
#  'galla[policeman]N': <gensim.models.keyedvectors.Vocab at 0x9418860>,
#  'ša₃-TAR': <gensim.models.keyedvectors.Vocab at 0x9418898>,
#  'gal-sagi': <gensim.models.keyedvectors.Vocab at 0x94188d0>,
#  'bilₓ(|GIŠ.PAP.NE|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x9418908>,
#  'šenumun[seed]N': <gensim.models.keyedvectors.Vocab at 0x9418940>,
#  'kalam-du₁₀': <gensim.models.keyedvectors.Vocab at 0x9418978>,
#  'kur-a₂-gal₂': <gensim.models.keyedvectors.Vocab at 0x94189b0>,
#  'a-RI-ti': <gensim.models.keyedvectors.Vocab at 0x9418a20>,
#  '2(burʾu@c)': <gensim.models.keyedvectors.Vocab at 0x9418a58>,
#  '2(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x9418a90>,
#  'gu₂-u₂': <gensim.models.keyedvectors.Vocab at 0x9418ac8>,
#  'urtur[puppy]N': <gensim.models.keyedvectors.Vocab at 0x9418b00>,
#  'e₂-zi': <gensim.models.keyedvectors.Vocab at 0x9418b38>,
#  'mes-ki-erim₂': <gensim.models.keyedvectors.Vocab at 0x9418b70>,
#  'x-ki': <gensim.models.keyedvectors.Vocab at 0x9418be0>,
#  'amar-{d}nam-nir': <gensim.models.keyedvectors.Vocab at 0x9418c18>,
#  'ni₂-kur-ra': <gensim.models.keyedvectors.Vocab at 0x9418c50>,
#  'kiŋ[work]N': <gensim.models.keyedvectors.Vocab at 0x9418c88>,
#  'tur[stall]N': <gensim.models.keyedvectors.Vocab at 0x9418cc0>,
#  'NA': <gensim.models.keyedvectors.Vocab at 0x9418d30>,
#  'anna[metal]N': <gensim.models.keyedvectors.Vocab at 0x9418d68>,
#  'unken-a': <gensim.models.keyedvectors.Vocab at 0x9418dd8>,
#  'ur-kin-nir': <gensim.models.keyedvectors.Vocab at 0x9418e10>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x9418e48>,
#  'ur-sipa': <gensim.models.keyedvectors.Vocab at 0x9418eb8>,
#  'ba-zi': <gensim.models.keyedvectors.Vocab at 0x9418f28>,
#  'AN-x': <gensim.models.keyedvectors.Vocab at 0x9418f98>,
#  'susig[flayer]N': <gensim.models.keyedvectors.Vocab at 0x9418fd0>,
#  'a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x9420048>,
#  'lugal-šembi₃': <gensim.models.keyedvectors.Vocab at 0x9420080>,
#  'ur-nin': <gensim.models.keyedvectors.Vocab at 0x94200f0>,
#  '1(diš@t)': <gensim.models.keyedvectors.Vocab at 0x9420128>,
#  'e₂-gissu-du₁₀': <gensim.models.keyedvectors.Vocab at 0x9420160>,
#  'am[bull]N': <gensim.models.keyedvectors.Vocab at 0x9420198>,
#  'ša₁₃-dub': <gensim.models.keyedvectors.Vocab at 0x94201d0>,
#  'KA-x': <gensim.models.keyedvectors.Vocab at 0x9420240>,
#  'mes-nig₂-lul-le': <gensim.models.keyedvectors.Vocab at 0x9420278>,
#  'šubur-x': <gensim.models.keyedvectors.Vocab at 0x94202b0>,
#  'gudu₄': <gensim.models.keyedvectors.Vocab at 0x94202e8>,
#  'ŋeš[tree]N': <gensim.models.keyedvectors.Vocab at 0x9420320>,
#  'DU-x': <gensim.models.keyedvectors.Vocab at 0x9420390>,
#  'dul[cover]V/t': <gensim.models.keyedvectors.Vocab at 0x94203c8>,
#  'balaₓ(LAK020)': <gensim.models.keyedvectors.Vocab at 0x9420400>,
#  '1/4(aš@c)': <gensim.models.keyedvectors.Vocab at 0x9420438>,
#  'DI': <gensim.models.keyedvectors.Vocab at 0x94204a8>,
#  'tah[add]V/t': <gensim.models.keyedvectors.Vocab at 0x94204e0>,
#  'en-kalam-du₁₀': <gensim.models.keyedvectors.Vocab at 0x9420518>,
#  'en-abzu-mud': <gensim.models.keyedvectors.Vocab at 0x9420550>,
#  'pa₄-zi': <gensim.models.keyedvectors.Vocab at 0x9420588>,
#  'dur-narₓ(LAK244)': <gensim.models.keyedvectors.Vocab at 0x94205c0>,
#  'munus-{d}anzu': <gensim.models.keyedvectors.Vocab at 0x94205f8>,
#  'UŠ-x': <gensim.models.keyedvectors.Vocab at 0x9420630>,
#  'a-ru': <gensim.models.keyedvectors.Vocab at 0x94206a0>,
#  'nin-bad₃': <gensim.models.keyedvectors.Vocab at 0x94206d8>,
#  'pa₄-NAM₂': <gensim.models.keyedvectors.Vocab at 0x9420710>,
#  'ur-{d}aš₈-gi₄': <gensim.models.keyedvectors.Vocab at 0x9420748>,
#  'gal-zadim': <gensim.models.keyedvectors.Vocab at 0x9420780>,
#  'lagaš{ki}': <gensim.models.keyedvectors.Vocab at 0x94207b8>,
#  'x-ur-sag': <gensim.models.keyedvectors.Vocab at 0x94207f0>,
#  'iš-lul-il': <gensim.models.keyedvectors.Vocab at 0x9420828>,
#  'AN-ur-sag': <gensim.models.keyedvectors.Vocab at 0x9420860>,
#  'ur-PA': <gensim.models.keyedvectors.Vocab at 0x94208d0>,
#  'nin-unken-a': <gensim.models.keyedvectors.Vocab at 0x9420908>,
#  'ur-sag-zi': <gensim.models.keyedvectors.Vocab at 0x9420940>,
#  'zid[flour]N': <gensim.models.keyedvectors.Vocab at 0x9420978>,
#  'magid[boat-tower]N': <gensim.models.keyedvectors.Vocab at 0x94209b0>,
#  'ma[ship]N': <gensim.models.keyedvectors.Vocab at 0x94209e8>,
#  'a-hu-ti{ki}': <gensim.models.keyedvectors.Vocab at 0x9420a20>,
#  'sum': <gensim.models.keyedvectors.Vocab at 0x9420a90>,
#  'ti[arrow]N': <gensim.models.keyedvectors.Vocab at 0x9420ac8>,
#  'dug[pot]N': <gensim.models.keyedvectors.Vocab at 0x9420b00>,
#  'ga[milk]N': <gensim.models.keyedvectors.Vocab at 0x9420b38>,
#  'eš[rope]N': <gensim.models.keyedvectors.Vocab at 0x9420b70>,
#  'gisal': <gensim.models.keyedvectors.Vocab at 0x9420be0>,
#  'ŋešgu[stock]N': <gensim.models.keyedvectors.Vocab at 0x9420c18>,
#  'KAL': <gensim.models.keyedvectors.Vocab at 0x9420c88>,
#  'anur[horizon]N': <gensim.models.keyedvectors.Vocab at 0x9420cc0>,
#  'emuhaldim[kitchen]N': <gensim.models.keyedvectors.Vocab at 0x9420cf8>,
#  'n(aš@c)': <gensim.models.keyedvectors.Vocab at 0x9420d30>,
#  'lugal-uri₃': <gensim.models.keyedvectors.Vocab at 0x9420d68>,
#  'šeš-lu₂': <gensim.models.keyedvectors.Vocab at 0x9420da0>,
#  'ŋanun[storehouse]N': <gensim.models.keyedvectors.Vocab at 0x9420dd8>,
#  'pa₄-{+an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x9420e10>,
#  'agrig[steward]N': <gensim.models.keyedvectors.Vocab at 0x9420e48>,
#  'a-ru₁₂-da': <gensim.models.keyedvectors.Vocab at 0x9420e80>,
#  'kug[metal]N': <gensim.models.keyedvectors.Vocab at 0x9420eb8>,
#  'HAR-tu': <gensim.models.keyedvectors.Vocab at 0x9420f28>,
#  'ba-da-da': <gensim.models.keyedvectors.Vocab at 0x9420f60>,
#  'kiʾinimak[witness]N': <gensim.models.keyedvectors.Vocab at 0x9420f98>,
#  '2/3(|NINDA₂×(ŠE.2(AŠ@c))|)': <gensim.models.keyedvectors.Vocab at 0x9420fd0>,
#  'inim[word]N': <gensim.models.keyedvectors.Vocab at 0x9427048>,
#  'har-tu': <gensim.models.keyedvectors.Vocab at 0x94270b8>,
#  'dag-dag': <gensim.models.keyedvectors.Vocab at 0x9427128>,
#  'utul': <gensim.models.keyedvectors.Vocab at 0x9427198>,
#  'udu-nita': <gensim.models.keyedvectors.Vocab at 0x94271d0>,
#  'AB-x': <gensim.models.keyedvectors.Vocab at 0x9427240>,
#  'nin-PA': <gensim.models.keyedvectors.Vocab at 0x94272b0>,
#  '|LAHTAN×GU|': <gensim.models.keyedvectors.Vocab at 0x94272e8>,
#  'ki-za': <gensim.models.keyedvectors.Vocab at 0x9427358>,
#  'e₂-x-ka': <gensim.models.keyedvectors.Vocab at 0x9427390>,
#  '1/2(diš)': <gensim.models.keyedvectors.Vocab at 0x94273c8>,
#  '|NINDA₂×ŠE|': <gensim.models.keyedvectors.Vocab at 0x9427400>,
#  'lugud[short]V/i': <gensim.models.keyedvectors.Vocab at 0x9427438>,
#  'nin-me-du₁₀': <gensim.models.keyedvectors.Vocab at 0x9427470>,
#  'ir₁₁': <gensim.models.keyedvectors.Vocab at 0x94274a8>,
#  '1/2(DIŠ@c)': <gensim.models.keyedvectors.Vocab at 0x94274e0>,
#  'amar-{d}gu₂-la₂': <gensim.models.keyedvectors.Vocab at 0x9427518>,
#  'ambar{ki}': <gensim.models.keyedvectors.Vocab at 0x9427550>,
#  'eš[shrine]N': <gensim.models.keyedvectors.Vocab at 0x9427588>,
#  'HU': <gensim.models.keyedvectors.Vocab at 0x94275f8>,
# ...
#  'E₂-BALAG': <gensim.models.keyedvectors.Vocab at 0x94277f0>,
#  'ur-ku₃-su₂₀': <gensim.models.keyedvectors.Vocab at 0x9427828>,
#  'KA-utu-zi': <gensim.models.keyedvectors.Vocab at 0x9427860>,
#  'simuggal[smith]N': <gensim.models.keyedvectors.Vocab at 0x9427898>,
#  'IB-dingir': <gensim.models.keyedvectors.Vocab at 0x94278d0>,
#  '1(ban₂)': <gensim.models.keyedvectors.Vocab at 0x9427908>,
#  'PA-du₁₀': <gensim.models.keyedvectors.Vocab at 0x9427940>,
#  'amar-edin': <gensim.models.keyedvectors.Vocab at 0x9427978>,
#  '|DUMU×NUN|-šita': <gensim.models.keyedvectors.Vocab at 0x94279b0>,
#  'bilₓ(|GEŠ.PAP.BIL|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x94279e8>,
#  'kir[lamb]N': <gensim.models.keyedvectors.Vocab at 0x9427a20>,
#  'sila₄-tur': <gensim.models.keyedvectors.Vocab at 0x9427a58>,
#  'ur-{d}nin-kur': <gensim.models.keyedvectors.Vocab at 0x9427a90>,
#  'gibil[new]V/i': <gensim.models.keyedvectors.Vocab at 0x9427ac8>,
#  'kaš[beer]N': <gensim.models.keyedvectors.Vocab at 0x9427b00>,
#  'de[pour]V/t': <gensim.models.keyedvectors.Vocab at 0x9427b38>,
#  'luh[clean]V/t': <gensim.models.keyedvectors.Vocab at 0x9427b70>,
#  'me-gal₂': <gensim.models.keyedvectors.Vocab at 0x9427ba8>,
#  '5(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0x9427be0>,
#  '|LAGAB×HA|-A': <gensim.models.keyedvectors.Vocab at 0x9427c18>,
#  'sag-dingir-tuku': <gensim.models.keyedvectors.Vocab at 0x9427c50>,
#  'mu-ni-uri₃': <gensim.models.keyedvectors.Vocab at 0x9427c88>,
#  'lugal-utu': <gensim.models.keyedvectors.Vocab at 0x9427cc0>,
#  'utu-mu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x9427cf8>,
#  'lugal-me-gal-gal': <gensim.models.keyedvectors.Vocab at 0x9427d30>,
#  'lugal-zi-ša₃-gal₂': <gensim.models.keyedvectors.Vocab at 0x9427d68>,
#  'amar-kuara': <gensim.models.keyedvectors.Vocab at 0x9427da0>,
#  'eš₂-gar': <gensim.models.keyedvectors.Vocab at 0x9427dd8>,
#  'e₂-DU': <gensim.models.keyedvectors.Vocab at 0x9427e10>,
#  'ŋeštin[vine]N': <gensim.models.keyedvectors.Vocab at 0x9427e48>,
#  'ur-x': <gensim.models.keyedvectors.Vocab at 0x9427eb8>,
#  'x-x-x-x': <gensim.models.keyedvectors.Vocab at 0x9427f28>,
#  'URUDU': <gensim.models.keyedvectors.Vocab at 0x9427f98>,
#  'PAP': <gensim.models.keyedvectors.Vocab at 0x942f048>,
#  '|HI×AŠ@c|': <gensim.models.keyedvectors.Vocab at 0x942f080>,
#  'ama-bara₂-ge': <gensim.models.keyedvectors.Vocab at 0x942f0b8>,
#  'lu₂-sa₁₀-gu₇': <gensim.models.keyedvectors.Vocab at 0x942f0f0>,
#  'ur-šubur': <gensim.models.keyedvectors.Vocab at 0x942f128>,
#  'eš₃-ta-mud': <gensim.models.keyedvectors.Vocab at 0x942f160>,
#  'lukiʾinimak[witness]N': <gensim.models.keyedvectors.Vocab at 0x942f198>,
#  'lugal-inim-zi-da': <gensim.models.keyedvectors.Vocab at 0x942f1d0>,
#  'hašhur[apple]N': <gensim.models.keyedvectors.Vocab at 0x942f208>,
#  'niŋduʾa[string]N': <gensim.models.keyedvectors.Vocab at 0x942f240>,
#  'kisur[locus]N': <gensim.models.keyedvectors.Vocab at 0x942f278>,
#  'ama-a-si': <gensim.models.keyedvectors.Vocab at 0x942f2b0>,
#  'TUN₃': <gensim.models.keyedvectors.Vocab at 0x942f2e8>,
#  'PI[unit]N': <gensim.models.keyedvectors.Vocab at 0x942f320>,
#  'niŋla[clothing]N': <gensim.models.keyedvectors.Vocab at 0x942f358>,
#  '|GA₂×HA|': <gensim.models.keyedvectors.Vocab at 0x942f390>,
#  'sag-AN-tuku': <gensim.models.keyedvectors.Vocab at 0x942f3c8>,
#  'e₂-du-du': <gensim.models.keyedvectors.Vocab at 0x942f400>,
#  'e₂-abzu': <gensim.models.keyedvectors.Vocab at 0x942f438>,
#  'ur-{d}nin-unug': <gensim.models.keyedvectors.Vocab at 0x942f470>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x942f4e0>,
#  'sa₆-ga': <gensim.models.keyedvectors.Vocab at 0x942f518>,
#  'hulu[ruination]N': <gensim.models.keyedvectors.Vocab at 0x942f550>,
#  'DUR₂': <gensim.models.keyedvectors.Vocab at 0x942f588>,
#  'unu[dwelling]N': <gensim.models.keyedvectors.Vocab at 0x942f5c0>,
#  '4(diš)': <gensim.models.keyedvectors.Vocab at 0x942f5f8>,
#  'utu-šita': <gensim.models.keyedvectors.Vocab at 0x942f630>,
#  '{d}nin-mar': <gensim.models.keyedvectors.Vocab at 0x942f668>,
#  '6(u)': <gensim.models.keyedvectors.Vocab at 0x942f6d8>,
#  'ninda[seed-funnel]N': <gensim.models.keyedvectors.Vocab at 0x942f710>,
#  '1(u)': <gensim.models.keyedvectors.Vocab at 0x942f780>,
#  'nagargal[carpenter]N': <gensim.models.keyedvectors.Vocab at 0x942f7b8>,
#  '3(u)': <gensim.models.keyedvectors.Vocab at 0x942f828>,
#  '2(u)': <gensim.models.keyedvectors.Vocab at 0x942f898>,
#  '1(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x942f8d0>,
#  'ku₃-luh-ha': <gensim.models.keyedvectors.Vocab at 0x942f908>,
#  '1/3(diš@c)': <gensim.models.keyedvectors.Vocab at 0x942f940>,
#  '|GA₂×HA|-A': <gensim.models.keyedvectors.Vocab at 0x942f978>,
#  'šaŋan[flask]N': <gensim.models.keyedvectors.Vocab at 0x942f9b0>,
#  'ur-sukkal-{d}saman₃': <gensim.models.keyedvectors.Vocab at 0x942f9e8>,
#  'kas': <gensim.models.keyedvectors.Vocab at 0x942fa58>,
#  'amar-{d}sag-ku₅': <gensim.models.keyedvectors.Vocab at 0x942fa90>,
#  'ed[ascend]V/i': <gensim.models.keyedvectors.Vocab at 0x942fac8>,
#  'sag-a-ra₂-ba-šum₂': <gensim.models.keyedvectors.Vocab at 0x942fb00>,
#  'ba-da': <gensim.models.keyedvectors.Vocab at 0x942fb70>,
#  'nig₂-du₈-du₈': <gensim.models.keyedvectors.Vocab at 0x942fba8>,
#  'za₃-mu': <gensim.models.keyedvectors.Vocab at 0x942fbe0>,
#  'lugal-uš-suₓ(MUŠ)': <gensim.models.keyedvectors.Vocab at 0x942fc18>,
#  'gu-sur-NUN': <gensim.models.keyedvectors.Vocab at 0x942fc50>,
#  'ur-nusku₂': <gensim.models.keyedvectors.Vocab at 0x942fc88>,
#  'dingir-nu-dam': <gensim.models.keyedvectors.Vocab at 0x942fcc0>,
#  'ri[impose]V/t': <gensim.models.keyedvectors.Vocab at 0x942fcf8>,
#  'kiʾerim[enemy-territory]N': <gensim.models.keyedvectors.Vocab at 0x942fd30>,
#  'bara₂-x': <gensim.models.keyedvectors.Vocab at 0x942fd68>,
#  'ka-tar-zi': <gensim.models.keyedvectors.Vocab at 0x942fda0>,
#  'šeš-geštin': <gensim.models.keyedvectors.Vocab at 0x942fdd8>,
#  'gal-kiri₆': <gensim.models.keyedvectors.Vocab at 0x942fe10>,
#  'e₂-ki-du₁₀-ga': <gensim.models.keyedvectors.Vocab at 0x942fe48>,
#  'u₂-tuku': <gensim.models.keyedvectors.Vocab at 0x942fe80>,
#  'en-kur-nu-hun': <gensim.models.keyedvectors.Vocab at 0x942feb8>,
#  'az-za': <gensim.models.keyedvectors.Vocab at 0x942ff28>,
#  '{geš}geštu-la-bi': <gensim.models.keyedvectors.Vocab at 0x942ff60>,
#  'lu₂-gu₄': <gensim.models.keyedvectors.Vocab at 0x942ff98>,
#  'sag-nin-da': <gensim.models.keyedvectors.Vocab at 0x942ffd0>,
#  'KA-ni': <gensim.models.keyedvectors.Vocab at 0x943a080>,
#  'a-zu₅-zu₅': <gensim.models.keyedvectors.Vocab at 0x943a0b8>,
#  'en-nagar-ša₃': <gensim.models.keyedvectors.Vocab at 0x943a0f0>,
#  'šita[prayer]N': <gensim.models.keyedvectors.Vocab at 0x943a128>,
#  'e₂-gissu-bi-du₁₀': <gensim.models.keyedvectors.Vocab at 0x943a160>,
#  'lu₂-geme₂-zi-da': <gensim.models.keyedvectors.Vocab at 0x943a198>,
#  'ar₃-du₃-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x943a1d0>,
#  '2(aš@c@90)': <gensim.models.keyedvectors.Vocab at 0x943a208>,
#  'ur-ab-u₂': <gensim.models.keyedvectors.Vocab at 0x943a240>,
#  '1(aš@c@90)': <gensim.models.keyedvectors.Vocab at 0x943a278>,
#  '2(eše₃@c)': <gensim.models.keyedvectors.Vocab at 0x943a2b0>,
#  'šeš-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x943a2e8>,
#  'DI-utu': <gensim.models.keyedvectors.Vocab at 0x943a358>,
#  'amar-x': <gensim.models.keyedvectors.Vocab at 0x943a3c8>,
#  'x-su': <gensim.models.keyedvectors.Vocab at 0x943a438>,
#  'lugal-x-x-x': <gensim.models.keyedvectors.Vocab at 0x943a470>,
#  '6(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x943a4a8>,
#  '5(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0x943a4e0>,
#  'gamurₓ(LAK490)': <gensim.models.keyedvectors.Vocab at 0x943a518>,
#  'kam₄': <gensim.models.keyedvectors.Vocab at 0x943a550>,
#  'tag': <gensim.models.keyedvectors.Vocab at 0x943a5c0>,
#  'unud[cowherd]N': <gensim.models.keyedvectors.Vocab at 0x943a5f8>,
#  'sig₁₅': <gensim.models.keyedvectors.Vocab at 0x943a630>,
#  'KA': <gensim.models.keyedvectors.Vocab at 0x943a6a0>,
#  'GAR[former]AJ': <gensim.models.keyedvectors.Vocab at 0x943a6d8>,
#  'x-zi': <gensim.models.keyedvectors.Vocab at 0x943a748>,
#  'munus-en-kalam': <gensim.models.keyedvectors.Vocab at 0x943a780>,
#  'min[two]NU': <gensim.models.keyedvectors.Vocab at 0x943a7b8>,
#  'nesaŋ[offering]N': <gensim.models.keyedvectors.Vocab at 0x943a7f0>,
#  'ma-ma': <gensim.models.keyedvectors.Vocab at 0x943a860>,
#  'nu': <gensim.models.keyedvectors.Vocab at 0x943a8d0>,
#  'PA-PA': <gensim.models.keyedvectors.Vocab at 0x943a940>,
#  '4(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x943a978>,
#  '{ninda}nindaₓ(DU)': <gensim.models.keyedvectors.Vocab at 0x943a9b0>,
#  '7(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0x943a9e8>,
#  'nam[fate]N': <gensim.models.keyedvectors.Vocab at 0x943aa20>,
#  'TUR': <gensim.models.keyedvectors.Vocab at 0x943aa90>,
#  'kalam[land]N': <gensim.models.keyedvectors.Vocab at 0x943aac8>,
#  'lugididak[musician]N': <gensim.models.keyedvectors.Vocab at 0x943ab00>,
#  'ur-{d}gibil₆': <gensim.models.keyedvectors.Vocab at 0x943ab38>,
#  'x-mu': <gensim.models.keyedvectors.Vocab at 0x943aba8>,
#  'nin-mu': <gensim.models.keyedvectors.Vocab at 0x943ac18>,
#  'x-PA': <gensim.models.keyedvectors.Vocab at 0x943ac88>,
#  'nin-a-zu₅': <gensim.models.keyedvectors.Vocab at 0x943acc0>,
#  'e₂-UD-gin₇-e₃': <gensim.models.keyedvectors.Vocab at 0x943acf8>,
#  'nin-a₂-mah': <gensim.models.keyedvectors.Vocab at 0x943ad30>,
#  'a-ul₄-gal': <gensim.models.keyedvectors.Vocab at 0x943ad68>,
#  'lu₂-su₁₃': <gensim.models.keyedvectors.Vocab at 0x943ada0>,
#  'lu₂-si₄': <gensim.models.keyedvectors.Vocab at 0x943add8>,
#  'lugal-engar-zi': <gensim.models.keyedvectors.Vocab at 0x943ae10>,
#  'lugal-ezen': <gensim.models.keyedvectors.Vocab at 0x943ae48>,
#  '{d}x': <gensim.models.keyedvectors.Vocab at 0x943aeb8>,
#  'lammar[deity]N': <gensim.models.keyedvectors.Vocab at 0x943aef0>,
#  '{d}tu': <gensim.models.keyedvectors.Vocab at 0x943af60>,
#  '{d}nin-x': <gensim.models.keyedvectors.Vocab at 0x943af98>,
#  '{d}nin-ki-da': <gensim.models.keyedvectors.Vocab at 0x943afd0>,
#  '{d}nin-mug': <gensim.models.keyedvectors.Vocab at 0x9441048>,
#  '{d}nin-pirig': <gensim.models.keyedvectors.Vocab at 0x9441080>,
#  'ZI': <gensim.models.keyedvectors.Vocab at 0x94410f0>,
#  'ŠE₃': <gensim.models.keyedvectors.Vocab at 0x9441128>,
#  'ki-mu-gi₄': <gensim.models.keyedvectors.Vocab at 0x9441160>,
#  'al₆-lum': <gensim.models.keyedvectors.Vocab at 0x9441198>,
#  'AK-{d}tu': <gensim.models.keyedvectors.Vocab at 0x94411d0>,
#  'sipa-anše': <gensim.models.keyedvectors.Vocab at 0x9441208>,
#  'ša₃-iri': <gensim.models.keyedvectors.Vocab at 0x9441240>,
#  'munus-u₄-ba': <gensim.models.keyedvectors.Vocab at 0x9441278>,
#  'e₂-šud₃-du₁₀': <gensim.models.keyedvectors.Vocab at 0x94412b0>,
#  'e₂-geme₂': <gensim.models.keyedvectors.Vocab at 0x94412e8>,
#  'x-nun': <gensim.models.keyedvectors.Vocab at 0x9441358>,
#  'nu-nu': <gensim.models.keyedvectors.Vocab at 0x94413c8>,
#  'šukur[ration]N': <gensim.models.keyedvectors.Vocab at 0x9441400>,
#  'KU-KU': <gensim.models.keyedvectors.Vocab at 0x9441470>,
#  'sag-narₓ(X)': <gensim.models.keyedvectors.Vocab at 0x94414a8>,
#  'KA-nun-ki-ba': <gensim.models.keyedvectors.Vocab at 0x94414e0>,
#  'e₂-nam': <gensim.models.keyedvectors.Vocab at 0x9441518>,
#  'a-en-da': <gensim.models.keyedvectors.Vocab at 0x9441588>,
#  'maš-x': <gensim.models.keyedvectors.Vocab at 0x94415c0>,
#  'sag-ku₅': <gensim.models.keyedvectors.Vocab at 0x94415f8>,
#  'ur-{d}nanše': <gensim.models.keyedvectors.Vocab at 0x9441630>,
#  'sim[sieve]V/t': <gensim.models.keyedvectors.Vocab at 0x9441668>,
#  'igi-su₄': <gensim.models.keyedvectors.Vocab at 0x94416a0>,
#  'alim[bison]N': <gensim.models.keyedvectors.Vocab at 0x94416d8>,
#  'x-x-da': <gensim.models.keyedvectors.Vocab at 0x9441748>,
#  'imria[clan]N': <gensim.models.keyedvectors.Vocab at 0x9441780>,
#  'urur[functionary]N': <gensim.models.keyedvectors.Vocab at 0x94417b8>,
#  'ŋiri[dagger]N': <gensim.models.keyedvectors.Vocab at 0x94417f0>,
#  '2(diš)': <gensim.models.keyedvectors.Vocab at 0x9441828>,
#  'ša₃-ba': <gensim.models.keyedvectors.Vocab at 0x9441860>,
#  'ur-{d}nin-urta': <gensim.models.keyedvectors.Vocab at 0x9441898>,
#  'limum[thousand]NU': <gensim.models.keyedvectors.Vocab at 0x94418d0>,
#  'mi-at': <gensim.models.keyedvectors.Vocab at 0x9441940>,
#  'munus[woman]N': <gensim.models.keyedvectors.Vocab at 0x9441978>,
#  'e₂-{d}x': <gensim.models.keyedvectors.Vocab at 0x94419b0>,
#  'eʾara[mill]N': <gensim.models.keyedvectors.Vocab at 0x94419e8>,
#  'ukken-a': <gensim.models.keyedvectors.Vocab at 0x9441a58>,
#  'x-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x9441a90>,
#  'bilₓ(|GIŠ.PAP.BIL|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0x9441ac8>,
#  'x-AN-x': <gensim.models.keyedvectors.Vocab at 0x9441b38>,
#  'lugal-da-zi': <gensim.models.keyedvectors.Vocab at 0x9441b70>,
#  'gal-muhaldim': <gensim.models.keyedvectors.Vocab at 0x9441ba8>,
#  'gal-LI-LI': <gensim.models.keyedvectors.Vocab at 0x9441be0>,
#  'bilₓ(|GIŠ.PAP.BIL|)-la': <gensim.models.keyedvectors.Vocab at 0x9441c18>,
#  'ensiₓ(|PA.TE.SI.NIG₂|)-gal': <gensim.models.keyedvectors.Vocab at 0x9441c50>,
#  'nin-ukken-a': <gensim.models.keyedvectors.Vocab at 0x9441c88>,
#  'e₂-SAHAR-ta-e₃': <gensim.models.keyedvectors.Vocab at 0x9441cc0>,
#  'pa₄-ul₄-gal': <gensim.models.keyedvectors.Vocab at 0x9441cf8>,
#  '{d}buranunaₓ(|KIB@g.NUN|)-ur-sag': <gensim.models.keyedvectors.Vocab at 0x9441d30>,
#  'AB-BAR-TAB': <gensim.models.keyedvectors.Vocab at 0x9441d68>,
#  'eriš-dingir': <gensim.models.keyedvectors.Vocab at 0x9441da0>,
#  'ulu₃-di': <gensim.models.keyedvectors.Vocab at 0x9441dd8>,
#  'mu[year]N': <gensim.models.keyedvectors.Vocab at 0x9441e10>,
#  'libir[old]V/i': <gensim.models.keyedvectors.Vocab at 0x9441e48>,
#  '3(diš@t)': <gensim.models.keyedvectors.Vocab at 0x9441e80>,
#  '4(diš@t)': <gensim.models.keyedvectors.Vocab at 0x9441eb8>,
#  'x-x-DI': <gensim.models.keyedvectors.Vocab at 0x9441f28>,
#  'elam': <gensim.models.keyedvectors.Vocab at 0x9441f98>,
#  'lu₂-ma₂-x': <gensim.models.keyedvectors.Vocab at 0x9441fd0>,
#  '5(aš)': <gensim.models.keyedvectors.Vocab at 0x9447048>,
#  'ma₂-gal-gal': <gensim.models.keyedvectors.Vocab at 0x9447080>,
#  '|MI+ZA₇|': <gensim.models.keyedvectors.Vocab at 0x94470b8>,
#  'ama-bara₂-si': <gensim.models.keyedvectors.Vocab at 0x94470f0>,
#  'na-U₂-U₂': <gensim.models.keyedvectors.Vocab at 0x9447128>,
#  'e₂-an-da-mu₂': <gensim.models.keyedvectors.Vocab at 0x9447160>,
#  'e₂-{+an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x9447198>,
#  'dumu-{+an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0x94471d0>,
#  'lu₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0x9447208>,
#  'nig₂-lugud₂-da': <gensim.models.keyedvectors.Vocab at 0x9447240>,
#  'a-da-tuš': <gensim.models.keyedvectors.Vocab at 0x9447278>,
#  'gir₄-bil': <gensim.models.keyedvectors.Vocab at 0x94472b0>,
#  'e₂-al₆-la': <gensim.models.keyedvectors.Vocab at 0x94472e8>,
#  'nam-ša₃-ta': <gensim.models.keyedvectors.Vocab at 0x9447320>,
#  'NU': <gensim.models.keyedvectors.Vocab at 0x9447390>,
#  'gu[cord]N': <gensim.models.keyedvectors.Vocab at 0x94473c8>,
#  'šubur-tur': <gensim.models.keyedvectors.Vocab at 0x9447400>,
#  'gada[flax]N': <gensim.models.keyedvectors.Vocab at 0x9447438>,
#  'UD-UD': <gensim.models.keyedvectors.Vocab at 0x94474a8>,
#  'GAL': <gensim.models.keyedvectors.Vocab at 0x9447518>,
#  'mu-x': <gensim.models.keyedvectors.Vocab at 0x9447588>,
#  'ŠUBUR': <gensim.models.keyedvectors.Vocab at 0x94475c0>,
#  'ME': <gensim.models.keyedvectors.Vocab at 0x9447630>,
#  'nanna{na}': <gensim.models.keyedvectors.Vocab at 0x9447668>,
#  'uš[die]V/i': <gensim.models.keyedvectors.Vocab at 0x94476a0>,
#  'x-x-ni': <gensim.models.keyedvectors.Vocab at 0x9447710>,
#  'mud[tube]N': <gensim.models.keyedvectors.Vocab at 0x9447748>,
#  'ua[provisioner]N': <gensim.models.keyedvectors.Vocab at 0x9447780>,
#  'ekas[road-house]N': <gensim.models.keyedvectors.Vocab at 0x94477b8>,
#  'kun-kun': <gensim.models.keyedvectors.Vocab at 0x9447828>,
#  'amar-giri₁₆': <gensim.models.keyedvectors.Vocab at 0x9447860>,
#  'na-x-x': <gensim.models.keyedvectors.Vocab at 0x94478d0>,
#  'x-ki-x': <gensim.models.keyedvectors.Vocab at 0x9447940>,
#  'za[bead]N': <gensim.models.keyedvectors.Vocab at 0x9447978>,
#  'balaŋdi[lamentation-singer]N': <gensim.models.keyedvectors.Vocab at 0x94479b0>,
#  ...}

# %% [markdown]
# # Similar words

# %%
model_akk.wv.most_similar("šarru[king]N", topn = 2), model_sux.wv.most_similar("lugal[king]N", topn=2)
# Out:
# ([('bēlu[lord]N', 0.9549878835678101), ('ana[to]PRP', 0.9517405033111572)],
#  [('ki[place]N', 0.9306298494338989), ('kalam[land]N', 0.9235943555831909)])

# %% [markdown]
# # Out of Vocabulary Words
# This is fasttext ... You may also use OOV words such as partial matches.

# %%
model_akk.wv.most_similar("palace", topn = 2), model_sux.wv.most_similar("[tiger]N", topn=2)
# Out:
# ([('Ekallu-eššetu[New-Palace-palace-in-Aššur]ON', 0.7083825469017029),
#   ('egalturrû[little-palace]N', 0.6874814033508301)],
#  [('uršub[tiger]N', 0.6488356590270996),
#   ('uršubkuda[wild-animal]N', 0.5293694138526917)])

# %% [markdown]
# # Kings and Queens
# Hmmmm. You may also try the Sumerian version with lugal[king]N, munus[woman]N and nita[man]N (it doesn't fare much better).

# %%
model_akk.wv.most_similar(positive=["šarru[king]N", "sinništu[woman]N"], negative = ["zikaru[male]N"])
# Out:
# [('ana[to]PRP', 0.8608435988426208),
#  ('bēlu[lord]N', 0.8355156183242798),
#  ('ša[of]DET', 0.8317270874977112),
#  ('ša[that]REL', 0.82342529296875),
#  ('ardu[slave]N', 0.8218632936477661),
#  ('ina[in]PRP', 0.8146045207977295),
#  ('māru[son]N', 0.80776047706604),
#  ('abu[father]N', 0.8045011758804321),
#  ('ēkallu[palace]N', 0.8006858229637146),
#  ('muhhu[skull]N', 0.7995380163192749)]

# %% [markdown]
# # Oxen and Sheep
# More culturally appropriate, perhaps.

# %%
model_sux.wv.most_similar(positive=["gud[oxen]N", "sila[lamb]N"], negative= ["amar[calf]N"])
# Out:
# [('mašgal[goat]N', 0.9077289700508118),
#  ('ašgar[kid]N', 0.9058449268341064),
#  ('u[ewe]N', 0.8994815349578857),
#  ('udu[sheep]N', 0.8990205526351929),
#  ('maš[goat]N', 0.8890479803085327),
#  ('nua[~animal]N', 0.8813501596450806),
#  ('niga[fattened]V/i', 0.875199556350708),
#  ('gukkal[sheep]N', 0.8608914613723755),
#  ('aslum[sheep]N', 0.8605831861495972),
#  ('mašda[gazelle]N', 0.8534128665924072)]

# %% [markdown]
# # The Challenge
# Is it possible to align the Sumerian and the Akkadian models? The [fasttext_multilingual](https://github.com/Babylonpartners/fastText_multilingual) repo of Babylonpartners (what's in a name?) provides a discussion of the concept and also includes a [notebook](https://github.com/Babylonpartners/fastText_multilingual/blob/master/align_your_own.ipynb) that allows you to align your own vector spaces. The notebook uses a different implementation of Fasttext.
#
# For the alignment you need an initial bilingual dictionary. This bilingual wordlist (to avoid confusion with the Python term `dictionary`) is a list of tuples in the format
# ```python
# [("Sumerian word", "Akkadian word"),
#  ...]
# ```
# The wordlist has almost 800 entries and was cobbled together from the electronic Pennsylvania Sumerian Dictionary ([ePSD2](http://oracc.org/epsd2)).

# %%
with open("pickles/bilingual_dict.p", "rb") as f: 
    sux_akk = pickle.load(f)
sux_akk
# Out:
# [('a[arm]N', 'ahu[arm]N'),
#  ('a[water]N', 'mû[water]N'),
#  ('aʾur[limbs]N', 'mešrêtu[limbs]N'),
#  ('ab[cow]N', 'arhu[cow]N'),
#  ('ab[window]N', 'aptu[window]N'),
#  ('aba[who?]QP', 'mannu[who?]QP'),
#  ('abara[sweat]N', 'zūtu[sweat]N'),
#  ('abba[father]N', 'abu[father]N'),
#  ('ablal[nest]N', 'qinnu[nest]N'),
#  ('abula[gate]N', 'abullu[gate]N'),
#  ('ad[voice]N', 'rigmu[voice]N'),
#  ('adbar[basalt]N', 'atbaru[basalt]N'),
#  ('adda[father]N', 'abu[father]N'),
#  ('addir[hire]N', 'igru[hire]N'),
#  ('adhal[copper]N', 'erû[copper]N'),
#  ('aga[tiara]N', 'agû[tiara]N'),
#  ('agaʾus[soldier]N', 'rēdû[soldier]N'),
#  ('agrig[steward]N', 'abarakku[steward]N'),
#  ('aŋ[measure]V/t', 'madādu[measure]V'),
#  ('aŋeštinak[vinegar]N', 'ṭābātu[vinegar]N'),
#  ('aŋi[wave]N', 'agû[wave]N'),
#  ('aŋiba[night]N', 'mūšu[night]N'),
#  ('ahiaš[quickly]AV', 'zamar[quickly]AV'),
#  ('ak[do]V/t', 'epēšu[do]V'),
#  ('aka[fleece]N', 'itqu[fleece]N'),
#  ('aku[cripple]N', 'akû[cripple]N'),
#  ('al[hoe]N', 'allu[hoe]N'),
#  ('alim[bison]N', 'ditānu[bison]N'),
#  ('alla[oak]N', 'allānu[oak]N'),
#  ('allanum[oak]N', 'allānu[oak]N'),
#  ('allub[crab]N', 'alluttu[crab]N'),
#  ('ama[chamber]N', 'maštaku[chamber]N'),
#  ('ama[mother]N', 'ummu[mother]N'),
#  ('amaš[sheepfold]N', 'supūru[sheepfold]N'),
#  ('ambar[reed-bed]N', 'appāru[reed-bed]N'),
#  ('amsi[elephant]N', 'pīru[elephant]N'),
#  ('amsikurak[camel]N', 'ibilu[camel]N'),
#  ('an[sky]N', 'šamû[sky]N'),
#  ('anbar[iron]N', 'parzillu[iron]N'),
#  ('anbarsug[iron]N', 'parzillu[iron]N'),
#  ('annibatu[ecstatic]N', 'mahhû[ecstatic]N'),
#  ('anzagar[tower]N', 'dimtu[tower]N'),
#  ('ar[praise]N', 'tanittu[praise]N'),
#  ('ara[voice]N', 'rigmu[voice]N'),
#  ('arad[slave]N', 'ardu[slave]N'),
#  ('arah[storehouse]N', 'arahhu[storehouse]N'),
#  ('arali[earth]N', 'erṣetu[earth]N'),
#  ('arar[miller]N', 'ararru[miller]N'),
#  ('asal[poplar]N', 'ṣarbatu[poplar]N'),
#  ('aslum[unit]N', 'aslu[unit]N'),
#  ('aš[curse]N', 'arratu[curse]N'),
#  ('ašag[field]N', 'eqlu[field]N'),
#  ('ašgab[leatherworker]N', 'aškāpu[leatherworker]N'),
#  ('ašlug[storeroom]N', 'ašlukkatu[storeroom]N'),
#  ('ašnan[grain]N', 'ašnan[grain]N'),
#  ('ašša[lamentation]N', 'ikkillu[lamentation]N'),
#  ('ašte[chair]N', 'kussû[chair]N'),
#  ('aya[father]N', 'abu[father]N'),
#  ('aya[marshland]N', 'išiktu[marshland]N'),
#  ('ayalum[stag]N', 'ayyalu[stag]N'),
#  ('az[bear]N', 'asu[bear]N'),
#  ('az[myrtle]N', 'asu[myrtle]N'),
#  ('azag[taboo]N', 'asakku[taboo]N'),
#  ('azlag[fuller]N', 'ašlāku[fuller]N'),
#  ('ba[half]N', 'bāmtu[half]N'),
#  ('badbad[defeat]N', 'dabdû[defeat]N'),
#  ('bahar[potter]N', 'pahāru[potter]N'),
#  ('bal[dig]V/t', 'herû[dig]V'),
#  ('balak[spindle]N', 'pilaqqu[spindle]N'),
#  ('ban[unit]N', 'sūtu[unit]N'),
#  ('bed[defecate]V/t', 'teṣû[defecate]V'),
#  ('bilga[fruit]N', 'inbu[fruit]N'),
#  ('binum[tamarisk]N', 'bīnu[tamarisk]N'),
#  ('bir[scatter]V/t', 'sapāhu[scatter]V'),
#  ('birri[spleen]N', 'ṭulīmu[spleen]N'),
#  ('birtu[fort]N', 'birtu[fort]N'),
#  ('bulug[needle]N', 'pulukku[needle]N'),
#  ('buluh[vomit]V/i', 'arû[vomit]V'),
#  ('bun[bladder]N', 'ellabbuhhu[bladder]N'),
#  ('bus[pluck]V/t', 'baqāmu[pluck]V'),
#  ('bu.bu.I[ration]N', 'ipru[ration]N'),
#  ('BU.I[face]V/t', 'mahāru[face]V'),
#  ('dag[demolish]V/t', 'naqāru[demolish]V'),
#  ('dag[dwelling]N', 'šubtu[dwelling]N'),
#  ('dag[side]N', 'idu[side]N'),
#  ('dagan[totality]N', 'kullatu[totality]N'),
#  ('dal[fly]V/i', 'naprušu[fly]V'),
#  ('daluš[sling]N', 'waṣpu[sling]N'),
#  ('damgar[merchant]N', 'tamkāru[merchant]N'),
#  ('damhara[battle]N', 'tamhāru[battle]N'),
#  ('daparu[defeat]N', 'kamāru[defeat]N'),
#  ('de[shape]V/t', 'patāqu[shape]V'),
#  ('dehi[support]N', 'imdu[support]N'),
#  ('dib[burn]V/t', 'kabābu[burn]V'),
#  ('dibida[donkey]N', 'imēru[donkey]N'),
#  ('dilibad[shining]AJ', 'nebû[shining]AJ'),
#  ('dilim[oven]N', 'tinūru[oven]N'),
#  ('dilim[spoon]N', 'itqūru[spoon]N'),
#  ('dim[check]V/t', 'sanāqu[check]V'),
#  ('dim[create]V/t', 'banû[create]V'),
#  ('dinig[kiln]N', 'kūru[kiln]N'),
#  ('dirida[instruction]N', 'têrtu[instruction]N'),
#  ('diš[one]NU', 'ištēn[one]NU'),
#  ('du[go]V/i', 'alāku[go]V'),
#  ('du[push]V/t', 'nakāpu[push]V'),
#  ('dub[tablet]N', 'ṭuppu[tablet]N'),
#  ('dubran[juniper]N', 'daprānu[juniper]N'),
#  ('dubsaŋ[first]AJ', 'mahrû[first]AJ'),
#  ('dubsar[scribe]N', 'ṭupšarru[scribe]N'),
#  ('dubul[sprout]V/i', 'elēpu[sprout]V'),
#  ('dubur[foundation]N', 'išdu[foundation]N'),
#  ('dud[combat]N', 'ṣāltu[combat]N'),
#  ('dug[pot]N', 'karpatu[pot]N'),
#  ('duh[loosen]V/t', 'paṭāru[loosen]V'),
#  ('dul[cover]V/t', 'katāmu[cover]V'),
#  ('dul[gather]V/t', 'pahāru[gather]V'),
#  ('dula[depth]N', 'šuplu[depth]N'),
#  ('dun[dig]V/t', 'herû[dig]V'),
#  ('dungu[cloud]N', 'erpetu[cloud]N'),
#  ('dur[fart]V/i', 'ṣarātu[fart]V'),
#  ('dur[totality]N', 'kullatu[totality]N'),
#  ('durŋar[chair]N', 'kussû[chair]N'),
#  ('duri[male]N', 'zikaru[male]N'),
#  ('durmina[breccia]N', 'turminû[breccia]N'),
#  ('e[chaff]N', 'hāmū[chaff]N'),
#  ('e[house]N', 'bītu[house]N'),
#  ('e[trust]N', 'tukultu[trust]N'),
#  ('e[tube]N', 'uppu[tube]N'),
#  ('eʾurre[grave]N', 'qubūru[grave]N'),
#  ('eden[back]N', 'ṣēru[back]N'),
#  ('eduru[heir]N', 'aplu[heir]N'),
#  ('eduru[village]N', 'kapru[village]N'),
#  ('egar[form]N', 'lānu[form]N'),
#  ('egar[wall]N', 'igāru[wall]N'),
#  ('egir[princess]N', 'rubātu[princess]N'),
#  ('ellaŋ[kidney]N', 'kalītu[kidney]N'),
#  ('ellamkuš[bladder]N', 'ellabbuhhu[bladder]N'),
#  ('emarru[quiver]N', 'išpatu[quiver]N'),
#  ('eme[tongue]N', 'lišānu[tongue]N'),
#  ('eme.ŠID[lizard]N', 'ṣurārû[lizard]N'),
#  ('en[incantation]N', 'šiptu[incantation]N'),
#  ('en[lord]N', 'bēlu[lord]N'),
#  ('endib[cook]N', 'nuhatimmu[cook]N'),
#  ('enedi[game]N', 'mēlultu[game]N'),
#  ('engar[farmer]N', 'ikkaru[farmer]N'),
#  ('enkud[tax-collector]N', 'mākisu[tax-collector]N'),
#  ('enuru[incantation]N', 'šiptu[incantation]N'),
#  ('ere[go]V/i', 'alāku[go]V'),
#  ('eren[cedar]N', 'erēnu[cedar]N'),
#  ('ereš[lady]N', 'bēltu[lady]N'),
#  ('erib[leatherworker]N', 'aškāpu[leatherworker]N'),
#  ('erim[enemy]N', 'ayyābu[enemy]N'),
#  ('erim[storeroom]N', 'išittu[storeroom]N'),
#  ('erimhuš[battle]N', 'anantu[battle]N'),
#  ('erin[people]N', 'ṣābu[people]N'),
#  ('erišti[wise]AJ', 'eršu[wise]AJ'),
#  ('esaŋ[heir]N', 'aplu[heir]N'),
#  ('esi[diorite]N', 'ušû[diorite]N'),
#  ('esir[bitumen]N', 'iṭṭû[bitumen]N'),
#  ('esir[street]N', 'sūqu[street]N'),
#  ('esirhia[bitumen]N', 'kupru[bitumen]N'),
#  ('eš[flour]N', 'qēmu[flour]N'),
#  ('eš[rope]N', 'eblu[rope]N'),
#  ('eš[water]N', 'mû[water]N'),
#  ('ešda[one]NU', 'ištēn[one]NU'),
#  ('ešdam[discussion]N', 'šitūltu[discussion]N'),
#  ('ešdam[tavern]N', 'aštammu[tavern]N'),
#  ('eše[unit]N', 'eblu[unit]N'),
#  ('eštub[carp]N', 'arsuppu[carp]N'),
#  ('etutum[darkness]N', 'eṭûtu[darkness]N'),
#  ('ezem[festival]N', 'isinnu[festival]N'),
#  ('ezina[grain]N', 'ašnan[grain]N'),
#  ('e.ur₁₁.ru.KU[song]N', 'zamāru[song]N'),
#  ('ga[milk]N', 'šizbu[milk]N'),
#  ('gab[left]N', 'šumēlu[left]N'),
#  ('gaba[chest]N', 'irtu[chest]N'),
#  ('gababum[shield]N', 'kabābu[shield]N'),
#  ('gabiri[mountain]N', 'šadû[mountain]N'),
#  ('gabus[shepherd]N', 'rēʾû[shepherd]N'),
#  ('gabzi[remover]N', 'nāsihu[remover]N'),
#  ('gada[flax]N', 'kitû[flax]N'),
#  ('gagar[ground]N', 'qaqqaru[ground]N'),
#  ('galanzu[wise]AJ', 'eršu[wise]AJ'),
#  ('galdi[exalted]AJ', 'tizqāru[exalted]AJ'),
#  ('GAM[depth]N', 'šuplu[depth]N'),
#  ('gana[field]N', 'eqlu[field]N'),
#  ('ganba[price]N', 'mahīru[price]N'),
#  ('gansis[darkness]N', 'ekletu[darkness]N'),
#  ('ganzer[earth]N', 'erṣetu[earth]N'),
#  ('gar[knob]N', 'karru[knob]N'),
#  ('garaš[leek]N', 'karašu[leek]N'),
#  ('gaz[kill]V/t', 'dâku[kill]V'),
#  ('gi[kill]V/t', 'dâku[kill]V'),
#  ('gi[reed]N', 'qanû[reed]N'),
#  ('giʾizila[torch]N', 'dipāru[torch]N'),
#  ('gid[length]N', 'mūraku[length]N'),
#  ('gidim[ghost]N', 'eṭemmu[ghost]N'),
#  ('gigam[conflict]N', 'ippīru[conflict]N'),
#  ('gigir[chariot]N', 'narkabtu[chariot]N'),
#  ('giguru[edge]N', 'pātu[edge]N'),
#  ('giŋ[unit]N', 'šiqlu[unit]N'),
#  ('gin[mountain]N', 'šadû[mountain]N'),
#  ('gir[anger]N', 'uzzu[anger]N'),
#  ('gir[gift]N', 'šerku[gift]N'),
#  ('gir[oven]N', 'kīru[oven]N'),
#  ('gir[runner]N', 'šānû[runner]N'),
#  ('gira[concealment]N', 'puzru[concealment]N'),
#  ('giranum[wailing]N', 'gerrānu[wailing]N'),
#  ('gu[eat]V/t', 'akālu[eat]V'),
#  ('gu[voice]N', 'rigmu[voice]N'),
#  ('guʾana[battle]N', 'qablu[battle]N'),
#  ('guʾena[silt]N', 'qadūtu[silt]N'),
#  ('gub[bathe]V/i', 'ramāku[bathe]V'),
#  ('gub[stand]V/i', 'izuzzu[stand]V'),
#  ('gud[ox]N', 'alpu[ox]N'),
#  ('gug[enmity]N', 'nukurtu[enmity]N'),
#  ('gug[seal]V/t', 'kanāku[seal]V'),
#  ('gug[stick]N', 'kakku[stick]N'),
#  ('guŋiri[breach]N', 'pilšu[breach]N'),
#  ('gul[destroy]V/t', 'abātu[destroy]V'),
#  ('guli[friend]N', 'ibru[friend]N'),
#  ('gullum[cat]N', 'šurānu[cat]N'),
#  ('gum[mange]N', 'garābu[mange]N'),
#  ('gun[load]N', 'biltu[load]N'),
#  ('gunu[dwelling]N', 'šubtu[dwelling]N'),
#  ('gur[circle]N', 'kippatu[circle]N'),
#  ('gur[lift]V/t', 'našû[lift]V'),
#  ('gur[unit]N', 'kurru[unit]N'),
#  ('gurud[throw]V/t', 'nadû[throw]V'),
#  ('gurum[dwelling]N', 'mūšabu[dwelling]N'),
#  ('gurun[fruit]N', 'inbu[fruit]N'),
#  ('gutar[back]N', 'kutallu[back]N'),
#  ('guza[chair]N', 'kussû[chair]N'),
#  ('ŋa[house]N', 'bītu[house]N'),
#  ('ŋal[be]V/i', 'bašû[be]V'),
#  ('ŋal[guard]V/t', 'naṣāru[guard]V'),
#  ('ŋal[open]V/t', 'petû[open]V'),
#  ('ŋen[go]V/i', 'alāku[go]V'),
#  ('ŋeš[penis]N', 'išaru[penis]N'),
#  ('ŋeš[tree]N', 'iṣu[tree]N'),
#  ('ŋešbun[meal]N', 'tākultu[meal]N'),
#  ('ŋešdab[footstool]N', 'gištappu[footstool]N'),
#  ('ŋešgida[length]N', 'ariktu[length]N'),
#  ('ŋeši[sesame]N', 'šamaššammū[sesame]N'),
#  ('ŋeškim[sign]N', 'giskimmu[sign]N'),
#  ('ŋeškimtil[trust]N', 'tukultu[trust]N'),
#  ('ŋešnu[light]N', 'nūru[light]N'),
#  ('ŋešnud[bed]N', 'eršu[bed]N'),
#  ('ŋešnugal[alabaster]N', 'ašnugallu[alabaster]N'),
#  ('ŋešpar[trap]N', 'gišparru[trap]N'),
#  ('ŋešrin[scales]N', 'gišrinnu[scales]N'),
#  ('ŋeššub[lot]N', 'isqu[lot]N'),
#  ('ŋeštaʾe[cypress]N', 'šurmēnu[cypress]N'),
#  ('ŋeštin[vine]N', 'karānu[vine]N'),
#  ('ŋešu[600]NU', 'nēr[600]NU'),
#  ('ŋi[night]N', 'mūšu[night]N'),
#  ('ŋiri[foot]N', 'šēpu[foot]N'),
#  ('ŋirigub[footstool]N', 'gištappu[footstool]N'),
#  ('ŋirila[butcher]N', 'ṭābihu[butcher]N'),
#  ('ŋiripadra[bone]N', 'eṣemtu[bone]N'),
#  ('ŋissu[shade]N', 'ṣillu[shade]N'),
#  ('ŋizzal[ear]N', 'hasīsu[ear]N'),
#  ('ŋušur[harrow]N', 'maškakātu[harrow]N'),
#  ('habruda[hole]N', 'hurru[hole]N'),
#  ('had[stick]N', 'haṭṭu[stick]N'),
#  ('hala[share]N', 'zittu[share]N'),
#  ('harran[route]N', 'mētequ[route]N'),
#  ('haza[hold]V/t', 'kullu[hold]V'),
#  ('hazanum[mayor]N', 'hazannu[mayor]N'),
#  ('heŋal[plenty]N', 'hengallu[plenty]N'),
#  ('hi[mix]V/t', 'balālu[mix]V'),
#  ('hibira[son]N', 'māru[son]N'),
#  ('hibiz[heir]N', 'aplu[heir]N'),
#  ('hibiz[red]AJ', 'ruššû[red]AJ'),
#  ('hili[attractiveness]N', 'kuzbu[attractiveness]N'),
#  ('HI.GAR[revolt]N', 'bārtu[revolt]N'),
#  ('huŋ[hire]V/t', 'agāru[hire]V'),
#  ('hulu[ruination]N', 'šalputtu[ruination]N'),
#  ('humunzer[mouse]N', 'humṣīru[mouse]N'),
#  ('hursaŋ[barber]N', 'gallābu[barber]N'),
#  ('HUŠ.ma[king]N', 'šarru[king]N'),
#  ('i[clothing]N', 'lubuštu[clothing]N'),
#  ('iʾiz[seed]N', 'zēru[seed]N'),
#  ('ib[hips]N', 'qablu[hips]N'),
#  ('ibi[smoke]N', 'qutru[smoke]N'),
#  ('ibila[heir]N', 'aplu[heir]N'),
#  ('ibira[merchant]N', 'tamkāru[merchant]N'),
#  ('ibtag[remainder]N', 'šittu[remainder]N'),
#  ('id[river]N', 'nāru[river]N'),
#  ('idim[wild]AJ', 'ekdu[wild]AJ'),
#  ('ig[door]N', 'daltu[door]N'),
#  ('igi[eye]N', 'īnu[eye]N'),
#  ('igiŋal[unit]N', 'ammatu[unit]N'),
#  ('igiŋaltuku[wise]AJ', 'emqu[wise]AJ'),
#  ('igira[heron]N', 'igirû[heron]N'),
#  ('igisigsig[jaundice]N', 'awurriqānu[jaundice]N'),
#  ('ilim[radiance]N', 'šalummatu[radiance]N'),
#  ('illu[water]N', 'mû[water]N'),
#  ('ilu[god]N', 'ilu[god]N'),
#  ('im[rain]N', 'zunnu[rain]N'),
#  ('imbabbar[gypsum]N', 'gaṣṣu[gypsum]N'),
#  ('imbasur[shivering]N', 'raʾību[shivering]N'),
#  ('imma[physiognomy]N', 'bunnannu[physiognomy]N'),
#  ('immal[cow]N', 'arhu[cow]N'),
#  ('immindu[oven]N', 'tinūru[oven]N'),
#  ('imminte[thirst]N', 'laplaptu[thirst]N'),
#  ('in[abuse]N', 'pištu[abuse]N'),
#  ('inbir[conflict]N', 'ippīru[conflict]N'),
#  ('induba[boundary]N', 'pilku[boundary]N'),
#  ('inimdug[peace]N', 'salīmu[peace]N'),
#  ('inna[fleece]N', 'itqu[fleece]N'),
#  ('inti[way]N', 'alaktu[way]N'),
#  ('inu[straw]N', 'tibnu[straw]N'),
#  ('ir[saying]N', 'tēltu[saying]N'),
#  ('irhandi[sorcerer]N', 'āšipu[sorcerer]N'),
#  ('iri[city]N', 'ālu[city]N'),
#  ('iš[mountain]N', 'šadû[mountain]N'),
#  ('išpatum[quiver]N', 'išpatu[quiver]N'),
#  ('itima[darkness]N', 'eṭûtu[darkness]N'),
#  ('itima[shrine]N', 'kiṣṣu[shrine]N'),
#  ('izi[fire]N', 'išātu[fire]N'),
#  ('izi[wave]N', 'agû[wave]N'),
#  ('iziŋar[torch]N', 'dipāru[torch]N'),
#  ('izzi[wall]N', 'igāru[wall]N'),
#  ('kaʾa[fox]N', 'šēlebu[fox]N'),
#  ('kag[mouth]N', 'pû[mouth]N'),
#  ('kagsilim[glorification]N', 'tašrihtu[glorification]N'),
#  ('kaku[run]V/t', 'lasāmu[run]V'),
#  ('kalam[land]N', 'mātu[land]N'),
#  ('kam[board]N', 'kammu[board]N'),
#  ('kan[gate]N', 'bābu[gate]N'),
#  ('kar[blow]V/i', 'napāhu[blow]V'),
#  ('karam[heap]N', 'karmu[heap]N'),
#  ('kaskal[way]N', 'harrānu[way]N'),
#  ('kaš[beer]N', 'šikaru[beer]N'),
#  ('kaš[run]V/i', 'lasāmu[run]V'),
#  ('kaš[runner]N', 'lāsimu[runner]N'),
#  ('kaš[urine]N', 'šīnātu[urine]N'),
#  ('kašdea[banquet]N', 'qerītu[banquet]N'),
#  ('katuŋal[exorcist]N', 'āšipu[exorcist]N'),
#  ('KA.muš[worm]N', 'tûltu[worm]N'),
#  ('kešed[bind]V/t', 'rakāsu[bind]V'),
#  ('ki[place]N', 'ašru[place]N'),
#  ('kib[wheat]N', 'kibtu[wheat]N'),
#  ('kid[cut]V/t', 'nakāsu[cut]V'),
#  ('kid[demolish]V/t', 'naqāru[demolish]V'),
#  ('kilib[total]N', 'napharu[total]N'),
#  ('kim[willow]N', 'hilēpu[willow]N'),
#  ('kimah[grave]N', 'kimahhu[grave]N'),
#  ('kin[grind]V/t', 'ṭênu[grind]V'),
#  ('kin[sickle]N', 'niggallu[sickle]N'),
#  ('kinda[barber]N', 'gallābu[barber]N'),
#  ('kindu[earth]N', 'erṣetu[earth]N'),
#  ('kiri[nose]N', 'appu[nose]N'),
#  ('kirizal[joy]N', 'hidûtu[joy]N'),
#  ('kisal[courtyard]N', 'kisallu[courtyard]N'),
#  ('kiš[totality]N', 'kiššatu[totality]N'),
#  ('kiši[ant]N', 'kulbābu[ant]N'),
#  ('kiši[half]N', 'muttatu[half]N'),
#  ('kiši[secret]N', 'pirištu[secret]N'),
#  ('kišib[hand]N', 'rittu[hand]N'),
#  ('kišib[seal]N', 'kunukku[seal]N'),
#  ('kišur[grave]N', 'qubūru[grave]N'),
#  ('kituš[dwelling]N', 'mūšabu[dwelling]N'),
#  ('KI.BI.KAK[banquet]N', 'qerītu[banquet]N'),
#  ('kud[fish]N', 'nūnu[fish]N'),
#  ('kugbabbar[silver]N', 'kaspu[silver]N'),
#  ('kugsig[gold]N', 'hurāṣu[gold]N'),
#  ('kullum[cook]N', 'nuhatimmu[cook]N'),
#  ('kun[tail]N', 'zibbatu[tail]N'),
#  ('kunu[approach]V/i', 'qerēbu[approach]V'),
#  ('kur[enter]V/i', 'erēbu[enter]V'),
#  ('kurgi[goose]N', 'kurkû[goose]N'),
#  ('kurum[ration]N', 'kurummatu[ration]N'),
#  ('kuš[devastation]N', 'naspantu[devastation]N'),
#  ('kuš[skin]N', 'mašku[skin]N'),
#  ('kuš[unit]N', 'ammatu[unit]N'),
#  ('kušu[animals]N', 'būlu[animals]N'),
#  ('KU₃.UD.KI[gold]N', 'hurāṣu[gold]N'),
#  ('laʾu[arrears]N', 'ribbatu[arrears]N'),
#  ('lagab[block]N', 'šibirtu[block]N'),
#  ('lah[beat]V/t', 'mašādu[beat]V'),
#  ('lal[strap]N', 'kurussu[strap]N'),
#  ('lala[plenty]N', 'lalû[plenty]N'),
#  ('lalari[owl]N', 'qadû[owl]N'),
#  ('laldar[pomegranate]N', 'nurmû[pomegranate]N'),
#  ('lal₃.HI×AŠ₂[wax]N', 'iškūru[wax]N'),
#  ('li[branch]N', 'larû[branch]N'),
#  ('li[oil]N', 'šamnu[oil]N'),
#  ('lib[heart]N', 'libbu[heart]N'),
#  ('lipišbala[anger]N', 'uggatu[anger]N'),
#  ('lu[mix]V/t', 'balālu[mix]V'),
#  ('luʾerimdu[enemy]N', 'ayyābu[enemy]N'),
#  ('lubuštum[clothing]N', 'lubuštu[clothing]N'),
#  ('lugud[pus]N', 'šarku[pus]N'),
#  ('luhuŋa[hireling]N', 'agru[hireling]N'),
#  ('lukiʾinimak[witness]N', 'šību[witness]N'),
#  ('lum[excrement]N', 'tabāštānu[excrement]N'),
#  ('lungak[brewer]N', 'sīrāšû[brewer]N'),
#  ('luniŋzuha[thief]N', 'šarrāqu[thief]N'),
#  ('lunisub[ecstatic]N', 'mahhû[ecstatic]N'),
#  ('luzuha[thief]N', 'šarrāqu[thief]N'),
#  ('luzuhzuha[thief]N', 'šarrāqu[thief]N'),
#  ('ma[ship]N', 'eleppu[ship]N'),
#  ('mabi[frost]N', 'mammû[frost]N'),
#  ('mahdi[exalted]AJ', 'tizqāru[exalted]AJ'),
#  ('mamud[dream]N', 'šuttu[dream]N'),
#  ('man[companion]N', 'tappû[companion]N'),
#  ('mana[unit]N', 'manû[unit]N'),
#  ('mar[shovel]N', 'marru[shovel]N'),
#  ('mar[winnow]V/t', 'zarû[winnow]V'),
#  ('margida[cart]N', 'ereqqu[cart]N'),
#  ('masila[heel]N', 'eqbu[heel]N'),
#  ('massu[leader]N', 'massû[leader]N'),
#  ('maš[border]N', 'miṣru[border]N'),
#  ('maš[interest]N', 'ṣibtu[interest]N'),
#  ('maš[twin]N', 'māšu[twin]N'),
#  ('mašanše[animals]N', 'būlu[animals]N'),
#  ('mašda[gazelle]N', 'ṣabītu[gazelle]N'),
#  ('mašdara[inscription]N', 'mašṭaru[inscription]N'),
#  ('mašmin[twin]N', 'māšu[twin]N'),
#  ('maššugidgid[diviner]N', 'bārû[diviner]N'),
#  ('me[battle]N', 'tāhāzu[battle]N'),
#  ('me[silence]N', 'qūlu[silence]N'),
#  ('mea[where?]QP', 'ali[where?]QP'),
#  ('megida[sow]N', 'šahītu[sow]N'),
#  ('men[tiara]N', 'agû[tiara]N'),
#  ('menari[administrator]N', 'šatammu[administrator]N'),
#  ('menden[we]IP', 'nīnu[we]IP'),
#  ('mes[blackness]N', 'ṣulmu[blackness]N'),
#  ('mete[appropriate-thing]N', 'simtu[appropriate-thing]N'),
#  ('metelum[bolt]N', 'mēdelu[bolt]N'),
#  ('meze[jaw]N', 'isu[jaw]N'),
#  ('min[two]NU', 'šina[two]NU'),
#  ('mu[good]AJ', 'banû[good]AJ'),
#  ('mu[incantation]N', 'šiptu[incantation]N'),
#  ('mu[manly]AJ', 'eṭlu[manly]AJ'),
#  ('mu[name]N', 'šumu[name]N'),
#  ('mu[year]N', 'šattu[year]N'),
#  ('mud[blood]N', 'dāmu[blood]N'),
#  ('mud[create]V/t', 'banû[create]V'),
#  ('mud[tube]N', 'uppu[tube]N'),
#  ('muhaldim[cook]N', 'nuhatimmu[cook]N'),
#  ('mul[foundation]N', 'uššu[foundation]N'),
#  ('mul[star]N', 'kakkabu[star]N'),
#  ('mulsig[darkness]N', 'ekletu[darkness]N'),
#  ('munsub[hair]N', 'šārtu[hair]N'),
#  ('munsub[shepherd]N', 'rēʾû[shepherd]N'),
#  ('munu[malt]N', 'buqlu[malt]N'),
#  ('munus[woman]N', 'sinništu[woman]N'),
#  ('mur[fodder]N', 'imrû[fodder]N'),
#  ('murgu[draw]V/t', 'eṣēru[draw]V'),
#  ('murgu[excrement]N', 'tabāštānu[excrement]N'),
#  ('murgu[fodder]N', 'imrû[fodder]N'),
#  ('murgu[rage]N', 'libbātu[rage]N'),
#  ('murub[assembly]N', 'puhru[assembly]N'),
#  ('muš[face]N', 'zīmu[face]N'),
#  ('mušen[bird]N', 'iṣṣūru[bird]N'),
#  ('mušendu[bird-catcher]N', 'usandû[bird-catcher]N'),
#  ('mušme[face]N', 'zīmu[face]N'),
#  ('mu.DU[delivery]N', 'šūrubtu[delivery]N'),
#  ('na[box]N', 'pitnu[box]N'),
#  ('na[stone]N', 'abnu[stone]N'),
#  ('nab[musician]N', 'nāru[musician]N'),
#  ('naŋ[drink]V/t', 'šatû[drink]V'),
#  ('naŋa[potash]N', 'uhūlu[potash]N'),
#  ('nam[fate]N', 'šīmtu[fate]N'),
#  ('namarum[mirror]N', 'nāmaru[mirror]N'),
#  ('namerim[oath]N', 'māmītu[oath]N'),
#  ('nar[musician]N', 'nāru[musician]N'),
#  ('narua[stele]N', 'narû[stele]N'),
#  ('ne[brazier]N', 'kinūnu[brazier]N'),
#  ('ne[strength]N', 'emūqu[strength]N'),
#  ('neha[calm]N', 'nēhtu[calm]N'),
#  ('nemur[leopard]N', 'nimru[leopard]N'),
#  ('ni[self]RP', 'ramānu[self]RP'),
#  ('niŋar[cella]N', 'kummu[cella]N'),
#  ('niŋba[gift]N', 'qīštu[gift]N'),
#  ('niŋbuna[turtle]N', 'šeleppû[turtle]N'),
#  ('niŋdara[rag]N', 'ulāpu[rag]N'),
#  ('niŋgalam[skill]N', 'nikiltu[skill]N'),
#  ('niŋgalgal[greatness]N', 'narbû[greatness]N'),
#  ('niŋgul[hatchet]N', 'akkullu[hatchet]N'),
#  ('niŋŋal[sickle]N', 'niggallu[sickle]N'),
#  ('niŋhalama[destruction]N', 'šahluqtu[destruction]N'),
#  ('niŋhul[joy]N', 'hidiātu[joy]N'),
#  ('niŋhulu[evil]N', 'lemuttu[evil]N'),
#  ('niŋin[total]N', 'napharu[total]N'),
#  ('niŋkešed[band]N', 'riksu[band]N'),
#  ('niŋkiluha[stone]N', 'abnu[stone]N'),
#  ('niŋlul[falsehood]N', 'sartu[falsehood]N'),
#  ('niŋmeŋar[silence]N', 'qūlu[silence]N'),
#  ('niŋsaga[goodness]N', 'dumqu[goodness]N'),
#  ('niŋsed[cold]N', 'kaṣû[cold]N'),
#  ('niŋsiga[meal]N', 'mākālu[meal]N'),
#  ('niŋsisa[justice]N', 'mīšaru[justice]N'),
#  ('niŋšu[goods]N', 'būšu[goods]N'),
#  ('niŋur[nest]N', 'qinnu[nest]N'),
#  ('niŋus[shin]N', 'kimṣu[shin]N'),
#  ('niŋ₂.ŠID[account]N', 'nikkassu[account]N'),
#  ('nin[lady]N', 'bēltu[lady]N'),
#  ('nin[sister]N', 'ahātu[sister]N'),
#  ('ninda[bread]N', 'akalu[bread]N'),
#  ('ninda[seed-funnel]N', 'ittû[seed-funnel]N'),
#  ('ninka[mongoose]N', 'šikkû[mongoose]N'),
#  ('ninkilim[mongoose]N', 'šikkû[mongoose]N'),
#  ('nir[lord]N', 'etellu[lord]N'),
#  ('nir[trust]N', 'tukultu[trust]N'),
#  ('nita[male]N', 'zikaru[male]N'),
#  ('nizuh[thief]N', 'šarrāqu[thief]N'),
#  ('nu[creator]N', 'bānû[creator]N'),
#  ('nu[man]N', 'awīlu[man]N'),
#  ('nukirik[gardener]N', 'nukaribbu[gardener]N'),
#  ('numma[vulture]N', 'zību[vulture]N'),
#  ('numun[seed]N', 'zēru[seed]N'),
#  ('numunkuš[widow]N', 'almattu[widow]N'),
#  ('nun[fight]N', 'anuntu[fight]N'),
#  ('nun[prince]N', 'rubû[prince]N'),
#  ('nundum[lip]N', 'šaptu[lip]N'),
#  ('nurma[pomegranate]N', 'nurmû[pomegranate]N'),
#  ('nushu[container]N', 'nushu[container]N'),
#  ('pag[enclose]V/t', 'esēru[enclose]V'),
#  ('pah[leg]N', 'purīdu[leg]N'),
#  ('pamušenak[wing]N', 'kappu[wing]N'),
#  ('pana[bow]N', 'qaštu[bow]N'),
#  ('papah[cella]N', 'papāhu[cella]N'),
#  ('peš[anoint]V/t', 'pašāšu[anoint]V'),
#  ('peš[fig]N', 'tittu[fig]N'),
#  ('peš[mouse]N', 'humṣīru[mouse]N'),
#  ('peš[tuft]N', 'nipšu[tuft]N'),
#  ('pil[male]N', 'zikaru[male]N'),
#  ('piš[bank]N', 'kibru[bank]N'),
#  ('pu[mouth]N', 'pû[mouth]N'),
#  ('puhrum[assembly]N', 'puhru[assembly]N'),
#  ('ragaba[rider]N', 'rākibu[rider]N'),
#  ('rig[eat]V/t', 'akālu[eat]V'),
#  ('rig[stick]N', 'kakku[stick]N'),
#  ('rum[perfect]AJ', 'gitmālu[perfect]AJ'),
#  ('sa[advice]N', 'milku[advice]N'),
#  ('sa[half]N', 'mišlu[half]N'),
#  ('sabad[battle]N', 'qablu[battle]N'),
#  ('sadu[companion]N', 'tappû[companion]N'),
#  ('sag[beat]V/t', 'mahāṣu[beat]V'),
#  ('saŋ[head]N', 'qaqqadu[head]N'),
#  ('saŋ[king]N', 'šarru[king]N'),
#  ('saŋba[oath]N', 'māmītu[oath]N'),
#  ('saŋdu[head]N', 'qaqqadu[head]N'),
#  ('saŋdu[triangle]N', 'santakku[triangle]N'),
#  ('saŋim[craftsman]N', 'ummiānu[craftsman]N'),
#  ('saŋkul[bolt]N', 'sikkūru[bolt]N'),
#  ('saŋlul[falsehood]N', 'sartu[falsehood]N'),
#  ('saŋmin[twin]N', 'tūʾamu[twin]N'),
#  ('saŋtak[triangle]N', 'santakku[triangle]N'),
#  ('sahar[frost]N', 'hurbāšu[frost]N'),
#  ('sam[price]N', 'šīmu[price]N'),
#  ('sanimmara[back]N', 'ṣēru[back]N'),
#  ('sar[write]V/t', 'šaṭāru[write]V'),
#  ('sas[grass]N', 'sassatu[grass]N'),
#  ('si[horn]N', 'qarnu[horn]N'),
#  ('sibsib[sorceress]N', 'kaššaptu[sorceress]N'),
#  ('sig[burn]V/t', 'ṣarāpu[burn]V'),
#  ('sig[equal]V/t', 'mašālu[equal]V'),
#  ('siki[hair]N', 'šārtu[hair]N'),
#  ('sila[heel]N', 'eqbu[heel]N'),
#  ('sila[lamb]N', 'puhādu[lamb]N'),
#  ('sila[street]N', 'sūqu[street]N'),
#  ('siladaŋal[square]N', 'rebītu[square]N'),
#  ('silig[bed]N', 'mayyaltu[bed]N'),
#  ('sim[sieve]V/t', 'napû[sieve]V'),
#  ('sim[swallow]N', 'sinuntu[swallow]N'),
#  ('simug[smith]N', 'nappāhu[smith]N'),
#  ('simul[stag]N', 'ayyalu[stag]N'),
#  ('simuš[brilliance]N', 'šarūru[brilliance]N'),
#  ('sipad[shepherd]N', 'rēʾû[shepherd]N'),
#  ('sir[bind]V/t', 'rakāsu[bind]V'),
#  ('sir[check]V/t', 'sanāqu[check]V'),
#  ('su[sink]V/t', 'ṭebû[sink]V'),
#  ('sua[cat]N', 'šurānu[cat]N'),
#  ('sub[go]V/i', 'alāku[go]V'),
#  ('subur[chariot]N', 'narkabtu[chariot]N'),
#  ('subur[slave]N', 'ardu[slave]N'),
#  ('sug[shrine]N', 'sukku[shrine]N'),
#  ('sugin[rot]N', 'sumkīnu[rot]N'),
#  ('sugu[need]N', 'hušahhu[need]N'),
#  ('suhub[bolt]N', 'mēdelu[bolt]N'),
#  ('suhub[tread]V/t', 'kabāsu[tread]V'),
#  ('suhur[tuft]N', 'qimmatu[tuft]N'),
#  ('suhuš[foundation]N', 'išdu[foundation]N'),
#  ('sukud[height]N', 'mēlû[height]N'),
#  ('sul[cover]V/t', 'katāmu[cover]V'),
#  ('sulim[radiance]N', 'šalummatu[radiance]N'),
#  ('sum[beard]N', 'ziqnu[beard]N'),
#  ('sur[cut]V/t', 'nakāsu[cut]V'),
#  ('sur[spin]V/t', 'ṭawû[spin]V'),
#  ('suzig[radiance]N', 'šalummatu[radiance]N'),
#  ('šab[hips]N', 'qablu[hips]N'),
#  ('šag[heart]N', 'libbu[heart]N'),
#  ('šagniŋin[intestines]N', 'erru[intestines]N'),
#  ('šagultum[meal]N', 'tākultu[meal]N'),
#  ('šaŋan[flask]N', 'šikkatu[flask]N'),
#  ('šamanur[verdigris]N', 'šuhtu[verdigris]N'),
#  ('šanabi[two-thirds]NU', 'šinipu[two-thirds]NU'),
#  ('šaneša[supplication]N', 'unnīnu[supplication]N'),
#  ('šar[mix]V/t', 'balālu[mix]V'),
#  ('še[barley]N', 'uṭṭatu[barley]N'),
#  ('še[call]V/t', 'nabû[call]V'),
#  ('šed[defecate]V/t', 'teṣû[defecate]V'),
#  ('šedu[abundant]AJ', 'duššû[abundant]AJ'),
#  ('šeg[voice]N', 'rigmu[voice]N'),
#  ('šega[agreement]N', 'mitgurtu[agreement]N'),
#  ('šeknu[verdigris]N', 'šuhtu[verdigris]N'),
#  ('šen[battle]N', 'qablu[battle]N'),
#  ('šen[cauldron]N', 'ruqqu[cauldron]N'),
#  ('šen[verdigris]N', 'šuhtu[verdigris]N'),
#  ('šennur[plum]N', 'šallūru[plum]N'),
#  ('šeš[anoint]V/t', 'pašāšu[anoint]V'),
#  ('šeš[brother]N', 'ahu[brother]N'),
#  ('šeš[weep]V/t', 'bakû[weep]V'),
#  ('šid[count]V/t', 'minûtu[count]V'),
#  ('šid[ride]V/t', 'rakābu[ride]V'),
#  ('šidim[builder]N', 'itinnu[builder]N'),
#  ('šikangu[leatherworker]N', 'aškāpu[leatherworker]N'),
#  ('šilam[cow]N', 'arhu[cow]N'),
#  ('šilig[dough]N', 'līšu[dough]N'),
#  ('šinig[tamarisk]N', 'bīnu[tamarisk]N'),
#  ('šir[song]N', 'zamāru[song]N'),
#  ('šir[testicle]N', 'išku[testicle]N'),
#  ('šita[weapon]N', 'kakku[weapon]N'),
#  ('šitan[water-channel]N', 'rāṭu[water-channel]N'),
#  ('šu[hand]N', 'qātu[hand]N'),
#  ('šu[totality]N', 'kiššatu[totality]N'),
#  ('šub[rush]N', 'šuppatu[rush]N'),
#  ('šud[prayer]N', 'ikribu[prayer]N'),
#  ('šudul[yoke]N', 'nīru[yoke]N'),
#  ('šugalanzu[potter]N', 'pahāru[potter]N'),
#  ('šugi[bolt]N', 'napraku[bolt]N'),
#  ('šukur[lance]N', 'šukurru[lance]N'),
#  ('šukur[ration]N', 'kurummatu[ration]N'),
#  ('šum[garlic]N', 'šūmū[garlic]N'),
#  ('šum[give]V/t', 'nadānu[give]V'),
#  ('šum[slaughter]V/t', 'ṭabāhu[slaughter]V'),
#  ('šuniŋin[total]N', 'napharu[total]N'),
#  ('šur[branches]N', 'kisittu[branches]N'),
#  ('šurun[cricket]N', 'ṣāṣiru[cricket]N'),
#  ('šusar[string]N', 'pitiltu[string]N'),
#  ('šusi[finger]N', 'ubānu[finger]N'),
#  ('šuš[cut]V/t', 'nakāsu[cut]V'),
#  ('šuš[one-sixth]NU', 'šuššu[one-sixth]NU'),
#  ('šušer[road]N', 'harrānu[road]N'),
#  ('šušer[sign]N', 'ittu[sign]N'),
#  ('šutug[reed-hut]N', 'šutukku[reed-hut]N'),
#  ('šutul[bag]N', 'tākaltu[bag]N'),
#  ('šutum[storehouse]N', 'šutummu[storehouse]N'),
#  ('tab[begin]V/t', 'šurrû[begin]V'),
#  ('tab[flatten]V/t', 'sapānu[flatten]V'),
#  ('tab[grasp]V/t', 'tamāhu[grasp]V'),
#  ('tab[illness]N', 'murṣu[illness]N'),
#  ('taba[companion]N', 'tappû[companion]N'),
#  ('tag[touch]V/t', 'lapātu[touch]V'),
#  ('te[cheek]N', 'lētu[cheek]N'),
#  ('teŋ[approach]V/i', 'ṭehû[approach]V'),
#  ('tehi[approach]V/t', 'ṭehû[approach]V'),
#  ('teš[voice]N', 'rigmu[voice]N'),
#  ('tibir[hand]N', 'qātu[hand]N'),
#  ('tigul[pot]N', 'karpatu[pot]N'),
#  ('til[complete]V/i', 'gamāru[complete]V'),
#  ('tilhar[cloud]N', 'upû[cloud]N'),
#  ('tilla[street]N', 'sūqu[street]N'),
#  ('tir[forest]N', 'qištu[forest]N'),
#  ('tišub[pot]N', 'karpatu[pot]N'),
#  ('tu[beat]V/t', 'mahāṣu[beat]V'),
#  ('tu[incantation]N', 'šiptu[incantation]N'),
#  ('tu[soup]N', 'ummaru[soup]N'),
#  ('tug[textile]N', 'ṣubātu[textile]N'),
#  ('tugur[dove]N', 'sukannīnu[dove]N'),
#  ('tuku[acquire]V/t', 'rašû[acquire]V'),
#  ('tuku[beat]V/t', 'mahāṣu[beat]V'),
#  ('tuku[rock]V/t', 'nâšu[rock]V'),
#  ('tukul[weapon]N', 'kakku[weapon]N'),
#  ('tukumbi[if]CNJ', 'šumma[if]CNJ'),
#  ('tulu[slacken]V/t', 'ramû[slacken]V'),
#  ('tun[lip]N', 'šaptu[lip]N'),
#  ('u[abuse]N', 'pištu[abuse]N'),
#  ('u[and]CNJ', 'u[and]CNJ'),
#  ('u[bed]N', 'eršu[bed]N'),
#  ('u[earth]N', 'qaqqaru[earth]N'),
#  ('u[finger]N', 'ubānu[finger]N'),
#  ('u[gift]N', 'qīštu[gift]N'),
#  ('u[grain]N', 'û[grain]N'),
#  ('u[horn]N', 'qarnu[horn]N'),
#  ('u[load]N', 'biltu[load]N'),
#  ('u[shepherd]N', 'rēʾû[shepherd]N'),
#  ('u[totality]N', 'kiššatu[totality]N'),
#  ('ua[provisioner]N', 'zāninu[provisioner]N'),
#  ('ub[corner]N', 'tubqu[corner]N'),
#  ('ubara[protection]N', 'kidinnu[protection]N'),
#  ('ubduga[corner]N', 'tubqu[corner]N'),
#  ('ubri[lance]N', 'šukurru[lance]N'),
#  ('ubur[breast]N', 'tulû[breast]N'),
#  ('uda[if]CNJ', 'šumma[if]CNJ'),
#  ('udu[sheep]N', 'immeru[sheep]N'),
#  ('udug[weapon]N', 'kakku[weapon]N'),
#  ('udul[herdsman]N', 'utullu[herdsman]N'),
#  ('udun[kiln]N', 'utūnu[kiln]N'),
#  ('ug[light]N', 'nūru[light]N'),
#  ('ugnim[army]N', 'ummānu[army]N'),
#  ('ugu[pasture]N', 'merītu[pasture]N'),
#  ('ugu[watering-place]N', 'mašqītu[watering-place]N'),
#  ('ugunu[lady]N', 'bēltu[lady]N'),
#  ('ugur[sword]N', 'namṣāru[sword]N'),
#  ('uŋ[people]N', 'nišu[people]N'),
#  ('uh[turtle]N', 'šeleppû[turtle]N'),
#  ('uhrum[stream]N', 'nahallu[stream]N'),
#  ('uktin[physiognomy]N', 'bunnannu[physiognomy]N'),
#  ('ukuš[cucumber]N', 'qiššû[cucumber]N'),
#  ('ul[fruit]N', 'inbu[fruit]N'),
#  ('ul[grind]V/t', 'qemû[grind]V'),
#  ('ul[hasten]V/i', 'arāhu[hasten]V'),
#  ('ul[terror]N', 'pirittu[terror]N'),
#  ('ula[battle]N', 'qablu[battle]N'),
#  ('ulal[oven]N', 'tinūru[oven]N'),
#  ('uli[lamentation]N', 'lallarātu[lamentation]N'),
#  ('uma[triumph]N', 'ernittu[triumph]N'),
#  ('umbin[wheel]N', 'magarru[wheel]N'),
#  ('umbinšeba[nail]N', 'ṣupru[nail]N'),
#  ('umia[people]N', 'nišū[people]N'),
#  ('umun[blood]N', 'dāmu[blood]N'),
#  ('umuš[exalted]AJ', 'ṣīru[exalted]AJ'),
#  ('unkin[assembly]N', 'puhru[assembly]N'),
#  ('unu[adornment]N', 'šukuttu[adornment]N'),
#  ('unu[meal]N', 'mākālu[meal]N'),
#  ('unumun[saffron]N', 'azupīru[saffron]N'),
#  ('upila[deaf]AJ', 'sukkuku[deaf]AJ'),
#  ('upu[unit]N', 'ubû[unit]N'),
#  ('ur[dog]N', 'kalbu[dog]N'),
#  ('ur[harness]N', 'naṣmadu[harness]N'),
#  ('ur[liver]N', 'kabattu[liver]N'),
#  ('ur[pluck]V/t', 'baqāmu[pluck]V'),
#  ('ur[roof]N', 'ūru[roof]N'),
#  ('ur[shut]V/t', 'edēlu[shut]V'),
#  ('uraš[earth]N', 'erṣetu[earth]N'),
#  ('uraš[secret]N', 'pirištu[secret]N'),
#  ('urbara[wolf]N', 'barbaru[wolf]N'),
#  ('urdib[cub]N', 'gerru[cub]N'),
#  ('urgir[dog]N', 'kalbu[dog]N'),
#  ('urig[corner]N', 'tubqu[corner]N'),
#  ('urin[standard]N', 'urinnu[standard]N'),
#  ('urki[dog]N', 'kalbu[dog]N'),
#  ('urmah[lion]N', 'nēšu[lion]N'),
#  ('ursaŋ[hero]N', 'qarrādu[hero]N'),
#  ('uru[flood]N', 'abūbu[flood]N'),
#  ('uru[guard]V/t', 'naṣāru[guard]V'),
#  ('uru[seat]N', 'šubtu[seat]N'),
#  ('uru[sow]V/t', 'erēšu[sow]V'),
#  ('uru[support]N', 'imdu[support]N'),
#  ('urud[copper]N', 'erû[copper]N'),
#  ('urum[male]N', 'zikaru[male]N'),
#  ('us[sheep]N', 'lahru[sheep]N'),
#  ('usag[sleep]N', 'šittu[sleep]N'),
#  ('usan[whip]N', 'qinnāzu[whip]N'),
#  ('usandu[wise]AJ', 'emqu[wise]AJ'),
#  ('uš[foundation]N', 'uššu[foundation]N'),
#  ('uš[membrane]N', 'ipu[membrane]N'),
#  ('uš[poison]N', 'imtu[poison]N'),
#  ('ušbar[staff]N', 'ušparu[staff]N'),
#  ('ušbar[weaver]N', 'išparu[weaver]N'),
#  ('utah[heaven]N', 'šamû[heaven]N'),
#  ('uzu[diviner]N', 'bārû[diviner]N'),
#  ('uzu[flesh]N', 'šīru[flesh]N'),
#  ('uzud[goat]N', 'enzu[goat]N'),
#  ('zag[nose-rope]N', 'ṣerretu[nose-rope]N'),
#  ('zagša[rival]N', 'šāninu[rival]N'),
#  ('zagše[shoulder]N', 'būdu[shoulder]N'),
#  ('zalam[tent]N', 'kuštāru[tent]N'),
#  ('zalamŋar[tent]N', 'kuštāru[tent]N'),
#  ('zamin[lyre]N', 'sammû[lyre]N'),
#  ('zamrutum[lance]N', 'azmarû[lance]N'),
#  ('zana[larva]N', 'mūnu[larva]N'),
#  ('zara[overlap]V/i', 'nentû[overlap]V'),
#  ('zarah[wailing]N', 'nissatu[wailing]N'),
#  ('ze[gall-bladder]N', 'martu[gall-bladder]N'),
#  ('zela[cloud]N', 'erpetu[cloud]N'),
#  ('zib[mark]N', 'šimtu[mark]N'),
#  ('zibin[caterpillar]N', 'nappillu[caterpillar]N'),
#  ('zid[flour]N', 'qēmu[flour]N'),
#  ('zidsura[magic-circle]N', 'zisurrû[magic-circle]N'),
#  ('zikura[earth]N', 'erṣetu[earth]N'),
#  ('zu[know]V/t', 'edû[know]V'),
#  ('zu[tooth]N', 'šinnu[tooth]N'),
#  ('zubi[watercourse]N', 'miṭirtu[watercourse]N'),
#  ('zuh[steal]V/t', 'šarāqu[steal]V'),
#  ('zukum[tread]V/t', 'kabāsu[tread]V'),
#  ('zulum[date]N', 'suluppu[date]N')]
