# %% [markdown]
# # Sumerian and Akkadian Word Embeddings
#
# This notebook loads Sumerian and Akkadian word embedding models and gives some hints for how to explore these models. Will someone be brave enough to try and align the two models?

# %%
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
warnings.filterwarnings(action='ignore', category=FutureWarning, module='gensim' )
import gensim
import pickle
from sklearn.manifold import TSNE
from gensim.models.fasttext import FastText as FT_gensim
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file, save
from bokeh.models import ColumnDataSource, LabelSet, Legend, LegendItem #, HoverTool, CustomJS, , Slider
from bokeh.layouts import column
from bokeh.palettes import all_palettes
output_notebook()
# note: more recent bokeh versions require notebook 5 or JupyterLab
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fc3a08e9-839a-4f7f-815a-cddfe5f1334d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load the Models
# There is one Akkadian model, three Sumerian models (all three use the same data, but different data representations). If your Sumerian is rusty, the lemmatized model is recommended.
# - model_cuneiform.model: the Sumerian copus in Unicode cuneiform
# - model_tl.model: the Sumerian corpus in transliteration
# - model_lemm.model: the Sumerian corpus in lemmatization

# %%
model_sux = FT_gensim.load("model/model_lemm.model")
model_akk = FT_gensim.load("model/akk_model_lemm.model")

# %% [markdown]
# # Vocabulary
# Lemmatized tokens have the form CitationForm[GuideWord]POS. To find possible vocabulary items you may inspect the `vocabulary`attribute.

# %%
model_sux.wv.vocab
# Out:
# ({'1(barig@c)': <gensim.models.keyedvectors.Vocab at 0x4fbb860>,
#   'še[barley]N': <gensim.models.keyedvectors.Vocab at 0x4fbb908>,
#   'ba-lul': <gensim.models.keyedvectors.Vocab at 0x4fbb978>,
#   'nagar[carpenter]N': <gensim.models.keyedvectors.Vocab at 0x4fbb9b0>,
#   'niŋdu[appropriate-thing]N': <gensim.models.keyedvectors.Vocab at 0x4fbb9e8>,
#   'aŋ[measure]V/t': <gensim.models.keyedvectors.Vocab at 0x4fbba20>,
#   'hur-sag-še₃-mah': <gensim.models.keyedvectors.Vocab at 0x4fbba58>,
#   'saŋ.DUN₃[recorder]N': <gensim.models.keyedvectors.Vocab at 0x4fbba90>,
#   '2(iku@c)': <gensim.models.keyedvectors.Vocab at 0x4fbbac8>,
#   'iku[unit]N': <gensim.models.keyedvectors.Vocab at 0x4fbbb00>,
#   'har-tu-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0x4fbbb38>,
#   'nukirik[gardener]N': <gensim.models.keyedvectors.Vocab at 0x4fbbb70>,
#   'me-zi-pa-e₃': <gensim.models.keyedvectors.Vocab at 0x4fbbba8>,
#   '1/2(iku@c)': <gensim.models.keyedvectors.Vocab at 0x4fbbbe0>,
#   'ša₃-gu₂-ba': <gensim.models.keyedvectors.Vocab at 0x4fbbc18>,
#   '4(iku@c)': <gensim.models.keyedvectors.Vocab at 0x4fbbc50>,
#   'AŠ₂-mud': <gensim.models.keyedvectors.Vocab at 0x4fbbc88>,
#   '3(iku@c)': <gensim.models.keyedvectors.Vocab at 0x4fbbcc0>,
#   'dud[mound]N': <gensim.models.keyedvectors.Vocab at 0xb695588>,
#   'gala[singer]N': <gensim.models.keyedvectors.Vocab at 0xbb5fbe0>,
#   'a-lu-lu': <gensim.models.keyedvectors.Vocab at 0xbb5fc50>,
#   'lugušudu[profession]N': <gensim.models.keyedvectors.Vocab at 0xbb5fba8>,
#   '1(iku@c)': <gensim.models.keyedvectors.Vocab at 0xbb5fb38>,
#   'e[house]N': <gensim.models.keyedvectors.Vocab at 0xbb5fb00>,
#   'zadim[stone-cutter]N': <gensim.models.keyedvectors.Vocab at 0xbb5fb70>,
#   '1/4(iku@c)': <gensim.models.keyedvectors.Vocab at 0xbb5fc18>,
#   'amar-tur₃': <gensim.models.keyedvectors.Vocab at 0xbb5fc88>,
#   'dumu-šita': <gensim.models.keyedvectors.Vocab at 0xbb5fcc0>,
#   'ur-dumu-zi': <gensim.models.keyedvectors.Vocab at 0xbb5fcf8>,
#   'ašgab[leatherworker]N': <gensim.models.keyedvectors.Vocab at 0xbb5fd30>,
#   'u₂-KA-KA': <gensim.models.keyedvectors.Vocab at 0xbb5fd68>,
#   'AN-nu-me': <gensim.models.keyedvectors.Vocab at 0xbb5fda0>,
#   'kuš[official]N': <gensim.models.keyedvectors.Vocab at 0xbb5fdd8>,
#   'amar-ku₃': <gensim.models.keyedvectors.Vocab at 0xbb5fe10>,
#   'lum-ma': <gensim.models.keyedvectors.Vocab at 0xbb5fe80>,
#   '5(iku@c)': <gensim.models.keyedvectors.Vocab at 0xbb5feb8>,
#   '{d}sud₃-ur-sag': <gensim.models.keyedvectors.Vocab at 0xbb5fef0>,
#   '1(eše₃@c)': <gensim.models.keyedvectors.Vocab at 0xbb5ff28>,
#   'pap[relation]N': <gensim.models.keyedvectors.Vocab at 0xbb5ff60>,
#   'x': <gensim.models.keyedvectors.Vocab at 0xbb5ff98>,
#   'sag-narₓ(LAK244)': <gensim.models.keyedvectors.Vocab at 0xbb5ffd0>,
#   '2(u@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a080>,
#   'lal[small]V/i': <gensim.models.keyedvectors.Vocab at 0xbb7a0b8>,
#   '1(aš@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a0f0>,
#   'ŋuruš[male]N': <gensim.models.keyedvectors.Vocab at 0xbb7a128>,
#   '1(u@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a198>,
#   '4(aš@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a1d0>,
#   'ur-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0xbb7a208>,
#   '1(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a240>,
#   '2(aš@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a278>,
#   'munus-geštin': <gensim.models.keyedvectors.Vocab at 0x4fbb048>,
#   '3(aš@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a2e8>,
#   'mes-lu-lu': <gensim.models.keyedvectors.Vocab at 0xbb7a320>,
#   '6(aš@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a358>,
#   'adda[father]N': <gensim.models.keyedvectors.Vocab at 0xbb7a390>,
#   'di-utu': <gensim.models.keyedvectors.Vocab at 0xbb7a400>,
#   '5(aš@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a438>,
#   'simug[smith]N': <gensim.models.keyedvectors.Vocab at 0xbb7a470>,
#   'abgal[sage]N': <gensim.models.keyedvectors.Vocab at 0xbb7a4a8>,
#   '7(aš@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a4e0>,
#   'gal-nimgir': <gensim.models.keyedvectors.Vocab at 0xbb7a518>,
#   '3(u@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a588>,
#   'e₂-su₁₃-ag₂': <gensim.models.keyedvectors.Vocab at 0xbb7a5c0>,
#   'nin-ur-sag': <gensim.models.keyedvectors.Vocab at 0xbb7a5f8>,
#   'amar-šuba₃': <gensim.models.keyedvectors.Vocab at 0xbb7a630>,
#   'enkud[tax-collector]N': <gensim.models.keyedvectors.Vocab at 0xbb7a668>,
#   'šuniŋin[total]N': <gensim.models.keyedvectors.Vocab at 0xbb7a6a0>,
#   '1(gešʾu@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a6d8>,
#   '4(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0xbb7a710>,
#   'diš[one]NU': <gensim.models.keyedvectors.Vocab at 0xbb7a748>,
#   'šeš-tur': <gensim.models.keyedvectors.Vocab at 0xbb7a780>,
#   '7(diš)': <gensim.models.keyedvectors.Vocab at 0xbb7a7b8>,
#   '1(diš)': <gensim.models.keyedvectors.Vocab at 0xbb7a7f0>,
#   'bilₓ(|PAP.GEŠ.BIL|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0xbb7a828>,
#   'si-du₃': <gensim.models.keyedvectors.Vocab at 0xbb7a860>,
#   'en-kas₄': <gensim.models.keyedvectors.Vocab at 0xbb7a898>,
#   '6(diš)': <gensim.models.keyedvectors.Vocab at 0xbb7a8d0>,
#   'sipad[shepherd]N': <gensim.models.keyedvectors.Vocab at 0xbb7a908>,
#   'giš': <gensim.models.keyedvectors.Vocab at 0xbb7a940>,
#   'BAD': <gensim.models.keyedvectors.Vocab at 0xbb7a9b0>,
#   'munsub[shepherd]N': <gensim.models.keyedvectors.Vocab at 0xbb7a9e8>,
#   'dubsar[scribe]N': <gensim.models.keyedvectors.Vocab at 0xbb7aa20>,
#   'anše[equid]N': <gensim.models.keyedvectors.Vocab at 0xbb7aa58>,
#   'a-ki-gal': <gensim.models.keyedvectors.Vocab at 0xbb7aa90>,
#   'subur[slave]N': <gensim.models.keyedvectors.Vocab at 0xbb7aac8>,
#   'mes-ki-na': <gensim.models.keyedvectors.Vocab at 0xbb7ab00>,
#   'engar[farmer]N': <gensim.models.keyedvectors.Vocab at 0xbb7ab38>,
#   'nin-gu₂-gal': <gensim.models.keyedvectors.Vocab at 0xbb7ab70>,
#   'nagada[herdsman]N': <gensim.models.keyedvectors.Vocab at 0xbb7aba8>,
#   'išib[priest]N': <gensim.models.keyedvectors.Vocab at 0xbb7abe0>,
#   'abzu-mud': <gensim.models.keyedvectors.Vocab at 0xbb7ac18>,
#   '{d}nusku₂': <gensim.models.keyedvectors.Vocab at 0xbb7ac50>,
#   'e₂-pirig-gal': <gensim.models.keyedvectors.Vocab at 0xbb7ac88>,
#   'dilmun[important]V/i': <gensim.models.keyedvectors.Vocab at 0xbb7acc0>,
#   'a-NI-NI': <gensim.models.keyedvectors.Vocab at 0xbb7ad30>,
#   '{d}nin-PA': <gensim.models.keyedvectors.Vocab at 0xbb7ad68>,
#   'gal-ukken': <gensim.models.keyedvectors.Vocab at 0xbb7ada0>,
#   'e₂-na-lu': <gensim.models.keyedvectors.Vocab at 0xbb7add8>,
#   '{d}nu-muš-da': <gensim.models.keyedvectors.Vocab at 0xbb7ae10>,
#   'du₁₁-ga-ni': <gensim.models.keyedvectors.Vocab at 0xbb7ae48>,
#   'ušum-ma': <gensim.models.keyedvectors.Vocab at 0xbb7ae80>,
#   'kin-nir': <gensim.models.keyedvectors.Vocab at 0xbb7aef0>,
#   'lugal-he₂-gal₂': <gensim.models.keyedvectors.Vocab at 0xbb7af28>,
#   'IB': <gensim.models.keyedvectors.Vocab at 0xbb7af98>,
#   'nig₂-si₄': <gensim.models.keyedvectors.Vocab at 0xbb7afd0>,
#   'nammah[greatness]N': <gensim.models.keyedvectors.Vocab at 0xbb83048>,
#   'e₂-pa-e₃': <gensim.models.keyedvectors.Vocab at 0xbb83080>,
#   'AK-utu': <gensim.models.keyedvectors.Vocab at 0xbb830f0>,
#   'x-x': <gensim.models.keyedvectors.Vocab at 0xbb83160>,
#   'nubanda[overseer]N': <gensim.models.keyedvectors.Vocab at 0xbb83198>,
#   'ugula[overseer]N': <gensim.models.keyedvectors.Vocab at 0xbb831d0>,
#   '{d}en-lil₂-ukken-a': <gensim.models.keyedvectors.Vocab at 0xbb83208>,
#   'sukkal[secretary]N': <gensim.models.keyedvectors.Vocab at 0xbb83240>,
#   'guʾanše[total]N': <gensim.models.keyedvectors.Vocab at 0xbb83278>,
#   'anše-apin': <gensim.models.keyedvectors.Vocab at 0xbb832b0>,
#   'u₂-dul₄': <gensim.models.keyedvectors.Vocab at 0xbb832e8>,
#   'dumu[child]N': <gensim.models.keyedvectors.Vocab at 0xbb83320>,
#   'luʾad[official]N': <gensim.models.keyedvectors.Vocab at 0xbb83358>,
#   'ur-e₂-gal': <gensim.models.keyedvectors.Vocab at 0xbb83390>,
#   'nar[musician]N': <gensim.models.keyedvectors.Vocab at 0xbb833c8>,
#   'AK': <gensim.models.keyedvectors.Vocab at 0xbb83438>,
#   'munu[malt]N': <gensim.models.keyedvectors.Vocab at 0xbb83470>,
#   'KA-zi-da': <gensim.models.keyedvectors.Vocab at 0xbb834a8>,
#   'gal-x': <gensim.models.keyedvectors.Vocab at 0xbb83518>,
#   'de[bring]V/t': <gensim.models.keyedvectors.Vocab at 0xbb83550>,
#   'gub[stand]V/i': <gensim.models.keyedvectors.Vocab at 0xbb83588>,
#   'lugal-u₃-ma': <gensim.models.keyedvectors.Vocab at 0xbb835c0>,
#   'inim-ma-ni-zi': <gensim.models.keyedvectors.Vocab at 0xbb835f8>,
#   'lugal-nig₂': <gensim.models.keyedvectors.Vocab at 0xbb83630>,
#   'dag[side]N': <gensim.models.keyedvectors.Vocab at 0xbb83668>,
#   'peš[fig]N': <gensim.models.keyedvectors.Vocab at 0xbb836a0>,
#   'ur-e₂-zi-da': <gensim.models.keyedvectors.Vocab at 0xbb836d8>,
#   'x-na': <gensim.models.keyedvectors.Vocab at 0xbb83748>,
#   'x-ma': <gensim.models.keyedvectors.Vocab at 0xbb837b8>,
#   'a-da-DUR₂': <gensim.models.keyedvectors.Vocab at 0xbb837f0>,
#   'e₂-da': <gensim.models.keyedvectors.Vocab at 0xbb83828>,
#   'šeš-ama-na': <gensim.models.keyedvectors.Vocab at 0xbb83860>,
#   'maškim[administrator]N': <gensim.models.keyedvectors.Vocab at 0xbb83898>,
#   'damgargal[merchant]N': <gensim.models.keyedvectors.Vocab at 0xbb838d0>,
#   'šuba[stone]N': <gensim.models.keyedvectors.Vocab at 0xbb83908>,
#   'KA-x-x': <gensim.models.keyedvectors.Vocab at 0xbb83978>,
#   'urud[copper]N': <gensim.models.keyedvectors.Vocab at 0xbb839b0>,
#   'mana[unit]N': <gensim.models.keyedvectors.Vocab at 0xbb839e8>,
#   'šah[pig]N': <gensim.models.keyedvectors.Vocab at 0xbb83a20>,
#   'ad-da-tur': <gensim.models.keyedvectors.Vocab at 0xbb83a58>,
#   '3(barig@c)': <gensim.models.keyedvectors.Vocab at 0xbb83a90>,
#   'ur-e₂-nun-gal': <gensim.models.keyedvectors.Vocab at 0xbb83ac8>,
#   '2(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0xbb83b00>,
#   'RI-RI': <gensim.models.keyedvectors.Vocab at 0xbb83b70>,
#   'šuʾi[barber]N': <gensim.models.keyedvectors.Vocab at 0xbb83ba8>,
#   'a₂-ag₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0xbb83be0>,
#   'ad.KID[weaver]N': <gensim.models.keyedvectors.Vocab at 0xbb83c18>,
#   '1/2(diš@c)': <gensim.models.keyedvectors.Vocab at 0xbb83c50>,
#   'en-nu-kur-še₃': <gensim.models.keyedvectors.Vocab at 0xbb83c88>,
#   '2(barig@c)': <gensim.models.keyedvectors.Vocab at 0xbb83cc0>,
#   'e₂-a-nun': <gensim.models.keyedvectors.Vocab at 0xbb83cf8>,
#   'lungak[brewer]N': <gensim.models.keyedvectors.Vocab at 0xbb83d30>,
#   'KA-nun-zi': <gensim.models.keyedvectors.Vocab at 0xbb83d68>,
#   'lidga[vessel]N': <gensim.models.keyedvectors.Vocab at 0xbb83da0>,
#   'lu[person]N': <gensim.models.keyedvectors.Vocab at 0xbb83dd8>,
#   'du₁₁-ga': <gensim.models.keyedvectors.Vocab at 0xbb83e10>,
#   'NI': <gensim.models.keyedvectors.Vocab at 0xbb83e80>,
#   'DU': <gensim.models.keyedvectors.Vocab at 0xbb83ef0>,
#   '4(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0xbb83f28>,
#   '5(diš)': <gensim.models.keyedvectors.Vocab at 0xbb83f60>,
#   'ninda[bread]N': <gensim.models.keyedvectors.Vocab at 0xbb83f98>,
#   'ud[sun]N': <gensim.models.keyedvectors.Vocab at 0xbb83fd0>,
#   'bad[wall]N': <gensim.models.keyedvectors.Vocab at 0xbb8b048>,
#   'ŋi[night]N': <gensim.models.keyedvectors.Vocab at 0xbb8b080>,
#   'šeba[ration]N': <gensim.models.keyedvectors.Vocab at 0xbb8b0b8>,
#   'itud[moon]N': <gensim.models.keyedvectors.Vocab at 0xbb8b0f0>,
#   'gu[eat]V/t': <gensim.models.keyedvectors.Vocab at 0xbb8b128>,
#   'en-il₂': <gensim.models.keyedvectors.Vocab at 0xbb8b160>,
#   '8(aš@c)': <gensim.models.keyedvectors.Vocab at 0xbb8b198>,
#   '3(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0xbb8b1d0>,
#   'maš[goat]N': <gensim.models.keyedvectors.Vocab at 0xbb8b208>,
#   'ur[root]N': <gensim.models.keyedvectors.Vocab at 0xbb8b240>,
#   'šum[give]V/t': <gensim.models.keyedvectors.Vocab at 0xbb8b278>,
#   'PA': <gensim.models.keyedvectors.Vocab at 0xbb8b2e8>,
#   'TAG': <gensim.models.keyedvectors.Vocab at 0xbb8b358>,
#   'kib[wheat]N': <gensim.models.keyedvectors.Vocab at 0xbb8b390>,
#   'he₂-sa₆': <gensim.models.keyedvectors.Vocab at 0xbb8b3c8>,
#   'šud₃': <gensim.models.keyedvectors.Vocab at 0xbb8b400>,
#   'sanga': <gensim.models.keyedvectors.Vocab at 0xbb8b470>,
#   'HAR-tu-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0xbb8b4a8>,
#   'zag[side]N': <gensim.models.keyedvectors.Vocab at 0xbb8b4e0>,
#   'gud[ox]N': <gensim.models.keyedvectors.Vocab at 0xbb8b518>,
#   'urra[loan]N': <gensim.models.keyedvectors.Vocab at 0xbb8b550>,
#   'egal[palace]N': <gensim.models.keyedvectors.Vocab at 0xbb8b588>,
#   'tuku[acquire]V/t': <gensim.models.keyedvectors.Vocab at 0xbb8b5c0>,
#   'gur[unit]N': <gensim.models.keyedvectors.Vocab at 0xbb8b5f8>,
#   'idu[doorkeeper]N': <gensim.models.keyedvectors.Vocab at 0xbb8b630>,
#   'ur-dumu-nun': <gensim.models.keyedvectors.Vocab at 0xbb8b668>,
#   'niŋir[herald]N': <gensim.models.keyedvectors.Vocab at 0xbb8b6a0>,
#   'ama-bur-ra': <gensim.models.keyedvectors.Vocab at 0xbb8b6d8>,
#   'sug[replace]V/t': <gensim.models.keyedvectors.Vocab at 0xbb8b710>,
#   'e₂-ki-ba': <gensim.models.keyedvectors.Vocab at 0xbb8b748>,
#   'šagia[cup-bearer]N': <gensim.models.keyedvectors.Vocab at 0xbb8b780>,
#   'ša₃-ta-nu-e₃': <gensim.models.keyedvectors.Vocab at 0xbb8b7b8>,
#   'a-nun-{d}sud₃-da': <gensim.models.keyedvectors.Vocab at 0xbb8b7f0>,
#   'munumud[maltster]N': <gensim.models.keyedvectors.Vocab at 0xbb8b828>,
#   'me-lam₂-kur-ra': <gensim.models.keyedvectors.Vocab at 0xbb8b860>,
#   'ur-{d}tu': <gensim.models.keyedvectors.Vocab at 0xbb8b898>,
#   'lugal-a₂-mah': <gensim.models.keyedvectors.Vocab at 0xbb8b8d0>,
#   'e₂-nu-kur-si': <gensim.models.keyedvectors.Vocab at 0xbb8b908>,
#   'lu₂-lum-ma': <gensim.models.keyedvectors.Vocab at 0xbb8b940>,
#   'tul₂-sag-du₁₀': <gensim.models.keyedvectors.Vocab at 0xbb8b978>,
#   'ugula-sukkal': <gensim.models.keyedvectors.Vocab at 0xbb8b9b0>,
#   'šeš[brother]N': <gensim.models.keyedvectors.Vocab at 0xbb8b9e8>,
#   'ur-nigin₃-si': <gensim.models.keyedvectors.Vocab at 0xbb8ba20>,
#   'utu-ur-sag': <gensim.models.keyedvectors.Vocab at 0xbb8ba58>,
#   'unug{ki}': <gensim.models.keyedvectors.Vocab at 0xbb8ba90>,
#   'nin[lady]N': <gensim.models.keyedvectors.Vocab at 0xbb8bac8>,
#   'pa₄-nu-la₂': <gensim.models.keyedvectors.Vocab at 0xbb8bb00>,
#   'UR-UR': <gensim.models.keyedvectors.Vocab at 0xbb8bb70>,
#   'e₂-nu-si': <gensim.models.keyedvectors.Vocab at 0xbb8bba8>,
#   'gurmah[unit]N': <gensim.models.keyedvectors.Vocab at 0xbb8bbe0>,
#   'ur-{d}nu-muš-da': <gensim.models.keyedvectors.Vocab at 0xbb8bc18>,
#   'lal[syrup]N': <gensim.models.keyedvectors.Vocab at 0xbb8bc50>,
#   'abzu-ki-du₁₀': <gensim.models.keyedvectors.Vocab at 0xbb8bc88>,
#   'bara₂-ki-ba': <gensim.models.keyedvectors.Vocab at 0xbb8bcc0>,
#   'ur-utu': <gensim.models.keyedvectors.Vocab at 0xbb8bd30>,
#   '1/2(aš@c)': <gensim.models.keyedvectors.Vocab at 0xbb8bd68>,
#   'AK-{d}NE': <gensim.models.keyedvectors.Vocab at 0xbb8bda0>,
#   'uru[flood]N': <gensim.models.keyedvectors.Vocab at 0xbb8bdd8>,
#   '{d}sud₃-anzu': <gensim.models.keyedvectors.Vocab at 0xbb8be10>,
#   'NI-NI': <gensim.models.keyedvectors.Vocab at 0xbb8be80>,
#   'maš-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0xbb8beb8>,
#   'sikil[pure]V/i': <gensim.models.keyedvectors.Vocab at 0xbb8bef0>,
#   'munus-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0xbb8bf28>,
#   'SAL.UŠ[sheath]N': <gensim.models.keyedvectors.Vocab at 0xbb8bf60>,
#   'mes-pa₃': <gensim.models.keyedvectors.Vocab at 0xbb8bf98>,
#   'ba-dag': <gensim.models.keyedvectors.Vocab at 0xbb95048>,
#   'a-geštin': <gensim.models.keyedvectors.Vocab at 0xbb95080>,
#   'damgar[merchant]N': <gensim.models.keyedvectors.Vocab at 0xbb950b8>,
#   'AN-sag-tuku': <gensim.models.keyedvectors.Vocab at 0xbb950f0>,
#   'amar-AN': <gensim.models.keyedvectors.Vocab at 0xbb95160>,
#   'adab{ki}': <gensim.models.keyedvectors.Vocab at 0xbb95198>,
#   'nibru{ki}': <gensim.models.keyedvectors.Vocab at 0xbb951d0>,
#   'umma{ki}': <gensim.models.keyedvectors.Vocab at 0xbb95208>,
#   'azu[doctor]N': <gensim.models.keyedvectors.Vocab at 0xbb95240>,
#   'a-si₄': <gensim.models.keyedvectors.Vocab at 0xbb95278>,
#   'geš-DUL₃': <gensim.models.keyedvectors.Vocab at 0xbb952b0>,
#   'ar₃-du₂-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0xbb952e8>,
#   'gi₄-za₇': <gensim.models.keyedvectors.Vocab at 0xbb95320>,
#   'edin-si': <gensim.models.keyedvectors.Vocab at 0xbb95390>,
#   'ur-{d}gu₂-la₂': <gensim.models.keyedvectors.Vocab at 0xbb953c8>,
#   'KA-lugal-da-zi': <gensim.models.keyedvectors.Vocab at 0xbb95400>,
#   'dingir-nu-me': <gensim.models.keyedvectors.Vocab at 0xbb95438>,
#   'diŋir[deity]N': <gensim.models.keyedvectors.Vocab at 0xbb95470>,
#   'dumu-nun-šita': <gensim.models.keyedvectors.Vocab at 0xbb954a8>,
#   'ba-ba': <gensim.models.keyedvectors.Vocab at 0xbb95518>,
#   'x-zi-x': <gensim.models.keyedvectors.Vocab at 0xbb95588>,
#   'KA-zi': <gensim.models.keyedvectors.Vocab at 0xbb955f8>,
#   'e₂-sahar-ta-e₃': <gensim.models.keyedvectors.Vocab at 0xbb95630>,
#   'šu[hand]N': <gensim.models.keyedvectors.Vocab at 0xbb95668>,
#   'ar₃-du₂': <gensim.models.keyedvectors.Vocab at 0xbb956a0>,
#   'šag[heart]N': <gensim.models.keyedvectors.Vocab at 0xbb956d8>,
#   'dingir-ur-sag': <gensim.models.keyedvectors.Vocab at 0xbb95710>,
#   'i₃-li₂-a': <gensim.models.keyedvectors.Vocab at 0xbb95748>,
#   'nam-mah₂': <gensim.models.keyedvectors.Vocab at 0xbb95780>,
#   'ursaŋ[hero]N': <gensim.models.keyedvectors.Vocab at 0xbb957b8>,
#   'KISAL': <gensim.models.keyedvectors.Vocab at 0xbb95828>,
#   'niŋ[thing]N': <gensim.models.keyedvectors.Vocab at 0xbb95860>,
#   'umma[old-woman]N': <gensim.models.keyedvectors.Vocab at 0xbb95898>,
#   '{d}sud₃-a₂-mah': <gensim.models.keyedvectors.Vocab at 0xbb958d0>,
#   '4(u@c)': <gensim.models.keyedvectors.Vocab at 0xbb95940>,
#   '1(ban₂@c)': <gensim.models.keyedvectors.Vocab at 0xbb95978>,
#   'lul[false]V/i': <gensim.models.keyedvectors.Vocab at 0xbb959b0>,
#   'lu-lu': <gensim.models.keyedvectors.Vocab at 0xbb95a20>,
#   'eden-si': <gensim.models.keyedvectors.Vocab at 0xbb95a90>,
#   'nimgir-mete-na': <gensim.models.keyedvectors.Vocab at 0xbb95ac8>,
#   'sanga-GAR': <gensim.models.keyedvectors.Vocab at 0xbb95b00>,
#   'e₂-ušum-gal': <gensim.models.keyedvectors.Vocab at 0xbb95b38>,
#   'e₂-hur-sag': <gensim.models.keyedvectors.Vocab at 0xbb95b70>,
#   'nam-mah-{d}sud₃-da': <gensim.models.keyedvectors.Vocab at 0xbb95ba8>,
#   'amar-abzu': <gensim.models.keyedvectors.Vocab at 0xbb95be0>,
#   'a-du₆-la': <gensim.models.keyedvectors.Vocab at 0xbb95c18>,
#   'KU-sag': <gensim.models.keyedvectors.Vocab at 0xbb95c88>,
#   'AK-du₆': <gensim.models.keyedvectors.Vocab at 0xbb95cc0>,
#   'ama-ig-gal': <gensim.models.keyedvectors.Vocab at 0xbb95cf8>,
#   'al₆-la': <gensim.models.keyedvectors.Vocab at 0xbb95d30>,
#   'šul-la': <gensim.models.keyedvectors.Vocab at 0xbb95d68>,
#   'pa₄-ur-sag': <gensim.models.keyedvectors.Vocab at 0xbb95da0>,
#   'za-ra': <gensim.models.keyedvectors.Vocab at 0xbb95e10>,
#   'gissu-še₃': <gensim.models.keyedvectors.Vocab at 0xbb95e48>,
#   'lu₂-pa₃': <gensim.models.keyedvectors.Vocab at 0xbb95e80>,
#   'ensi₂-GAR-gal': <gensim.models.keyedvectors.Vocab at 0xbb95eb8>,
#   'AŠ': <gensim.models.keyedvectors.Vocab at 0xbb95ef0>,
#   'ur-lugal-DU': <gensim.models.keyedvectors.Vocab at 0xbb95f28>,
#   'gal-kinda₂': <gensim.models.keyedvectors.Vocab at 0xbb95f60>,
#   'muhaldim[cook]N': <gensim.models.keyedvectors.Vocab at 0xbb95f98>,
#   'SUR-gu-nun': <gensim.models.keyedvectors.Vocab at 0xbb95fd0>,
#   '{d}gibil₆': <gensim.models.keyedvectors.Vocab at 0xbb9e048>,
#   'gal-unken': <gensim.models.keyedvectors.Vocab at 0xbb9e080>,
#   'kur[different]V/i': <gensim.models.keyedvectors.Vocab at 0xbb9e0b8>,
#   'pa-e₃': <gensim.models.keyedvectors.Vocab at 0xbb9e0f0>,
#   'x-ra': <gensim.models.keyedvectors.Vocab at 0xbb9e160>,
#   'enku{ku₆}': <gensim.models.keyedvectors.Vocab at 0xbb9e198>,
#   'lumagur[boatman]N': <gensim.models.keyedvectors.Vocab at 0xbb9e1d0>,
#   'dubsarmah[official]N': <gensim.models.keyedvectors.Vocab at 0xbb9e208>,
#   '3(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0xbb9e240>,
#   'ur-dumu-zi-da': <gensim.models.keyedvectors.Vocab at 0xbb9e278>,
#   'lu₂-bara₂-si': <gensim.models.keyedvectors.Vocab at 0xbb9e2b0>,
#   'mah[great]V/i': <gensim.models.keyedvectors.Vocab at 0xbb9e2e8>,
#   'maškim-gi₄': <gensim.models.keyedvectors.Vocab at 0xbb9e320>,
#   'gu-ni-DU': <gensim.models.keyedvectors.Vocab at 0xbb9e358>,
#   'ugulaʾek[overseer]N': <gensim.models.keyedvectors.Vocab at 0xbb9e390>,
#   'nargal[musician]N': <gensim.models.keyedvectors.Vocab at 0xbb9e3c8>,
#   'AB': <gensim.models.keyedvectors.Vocab at 0xbb9e438>,
#   '{d}en-lil₂': <gensim.models.keyedvectors.Vocab at 0xbb9e470>,
#   'šugi[senior]N': <gensim.models.keyedvectors.Vocab at 0xbb9e4a8>,
#   'lu₂-e₂-zi': <gensim.models.keyedvectors.Vocab at 0xbb9e4e0>,
#   'lugal-ezem': <gensim.models.keyedvectors.Vocab at 0xbb9e518>,
#   'e₂-UD-nu-dib': <gensim.models.keyedvectors.Vocab at 0xbb9e550>,
#   'sa-HAR': <gensim.models.keyedvectors.Vocab at 0xbb9e5c0>,
#   'dar[split]V/t': <gensim.models.keyedvectors.Vocab at 0xbb9e5f8>,
#   'e₂-ki-gal-la': <gensim.models.keyedvectors.Vocab at 0xbb9e630>,
#   'AK-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0xbb9e668>,
#   'ekur[prison]N': <gensim.models.keyedvectors.Vocab at 0xbb9e6a0>,
#   'AN': <gensim.models.keyedvectors.Vocab at 0xbb9e710>,
#   'zi₃@t': <gensim.models.keyedvectors.Vocab at 0xbb9e748>,
#   'ba[animal]N': <gensim.models.keyedvectors.Vocab at 0xbb9e780>,
#   '6(barig@c)': <gensim.models.keyedvectors.Vocab at 0xbb9e7b8>,
#   'sila[unit]N': <gensim.models.keyedvectors.Vocab at 0xbb9e7f0>,
#   'teŋ[approach]V/i': <gensim.models.keyedvectors.Vocab at 0xbb9e828>,
#   'utu-di-ku₅': <gensim.models.keyedvectors.Vocab at 0xbb9e860>,
#   'amar-e₂-gibil': <gensim.models.keyedvectors.Vocab at 0xbb9e898>,
#   'mušlah[charmer]N': <gensim.models.keyedvectors.Vocab at 0xbb9e8d0>,
#   'amar-{d}iškur': <gensim.models.keyedvectors.Vocab at 0xbb9e908>,
#   'ur-tul₂-sag': <gensim.models.keyedvectors.Vocab at 0xbb9e940>,
#   'pa-bilₓ(|GIŠ.PAP.NE|)-ga': <gensim.models.keyedvectors.Vocab at 0xbb9e978>,
#   'me-pa-e₃': <gensim.models.keyedvectors.Vocab at 0xbb9e9b0>,
#   'e₂-u₂': <gensim.models.keyedvectors.Vocab at 0xbb9e9e8>,
#   'u₄-kur-ra': <gensim.models.keyedvectors.Vocab at 0xbb9ea20>,
#   'amar-{d}tu': <gensim.models.keyedvectors.Vocab at 0xbb9ea58>,
#   'mes-nu-še₃': <gensim.models.keyedvectors.Vocab at 0xbb9ea90>,
#   '{d}sud₃-da-zi': <gensim.models.keyedvectors.Vocab at 0xbb9eac8>,
#   'addirₓ(|LAK589.A.SI|)': <gensim.models.keyedvectors.Vocab at 0xbb9eb00>,
#   '{d}en-lil₂-unken-a': <gensim.models.keyedvectors.Vocab at 0xbb9eb38>,
#   'šita-KAL': <gensim.models.keyedvectors.Vocab at 0xbb9eb70>,
#   'a-pa-e₃': <gensim.models.keyedvectors.Vocab at 0xbb9eba8>,
#   'a-NI': <gensim.models.keyedvectors.Vocab at 0xbb9ec18>,
#   'ur-{d}en-ki': <gensim.models.keyedvectors.Vocab at 0xbb9ec50>,
#   'e₂-du₆': <gensim.models.keyedvectors.Vocab at 0xbb9ec88>,
#   'ki-ni-du₁₀': <gensim.models.keyedvectors.Vocab at 0xbb9ecc0>,
#   'bilₓ(|GIŠ.PAP.NE|)-kalam-du₁₀': <gensim.models.keyedvectors.Vocab at 0xbb9ecf8>,
#   'e₂-{d}anzu': <gensim.models.keyedvectors.Vocab at 0xbb9ed30>,
#   'utu-ki-gal': <gensim.models.keyedvectors.Vocab at 0xbb9ed68>,
#   'UŠ': <gensim.models.keyedvectors.Vocab at 0xbb9eda0>,
#   'en-nam-zu₅-še₃': <gensim.models.keyedvectors.Vocab at 0xbb9edd8>,
#   'e₂-na-lu-lu': <gensim.models.keyedvectors.Vocab at 0xbb9ee10>,
#   'lu₂-{giš}BULUG₃': <gensim.models.keyedvectors.Vocab at 0xbb9ee48>,
#   'e₂-nun-KA': <gensim.models.keyedvectors.Vocab at 0xbb9ee80>,
#   'mes-u₄-ba': <gensim.models.keyedvectors.Vocab at 0xbb9eeb8>,
#   'zig[rise]V/t': <gensim.models.keyedvectors.Vocab at 0xbb9eef0>,
#   'kur-ra-a₂-gal₂': <gensim.models.keyedvectors.Vocab at 0xbb9ef28>,
#   'ni₂-zu₅-kur-še₃': <gensim.models.keyedvectors.Vocab at 0xbb9ef60>,
#   'a-hu-ti': <gensim.models.keyedvectors.Vocab at 0xbb9efd0>,
#   'pa₄-{d}anzu': <gensim.models.keyedvectors.Vocab at 0xc3d5048>,
#   'šita-kalam': <gensim.models.keyedvectors.Vocab at 0xc3d5080>,
#   'ur-{d}en-lil₂': <gensim.models.keyedvectors.Vocab at 0xc3d50b8>,
#   'ludag[official]N': <gensim.models.keyedvectors.Vocab at 0xc3d50f0>,
#   'e₂-{d}nanna': <gensim.models.keyedvectors.Vocab at 0xc3d5128>,
#   'KA-ni-zi': <gensim.models.keyedvectors.Vocab at 0xc3d5160>,
#   'ba-za₇': <gensim.models.keyedvectors.Vocab at 0xc3d5198>,
#   'aya[father]N': <gensim.models.keyedvectors.Vocab at 0xc3d51d0>,
#   'dub-hul-tar': <gensim.models.keyedvectors.Vocab at 0xc3d5208>,
#   'mes-ni₃-lul-le': <gensim.models.keyedvectors.Vocab at 0xc3d5240>,
#   'udu[sheep]N': <gensim.models.keyedvectors.Vocab at 0xc3d5278>,
#   'lugal-zi-kalam': <gensim.models.keyedvectors.Vocab at 0xc3d52b0>,
#   'UR': <gensim.models.keyedvectors.Vocab at 0xc3d5320>,
#   'nig₂-pa₃-da': <gensim.models.keyedvectors.Vocab at 0xc3d5358>,
#   'uzud[goat]N': <gensim.models.keyedvectors.Vocab at 0xc3d5390>,
#   'aktum[garment]N': <gensim.models.keyedvectors.Vocab at 0xc3d53c8>,
#   'tug[textile]N': <gensim.models.keyedvectors.Vocab at 0xc3d5400>,
#   'n': <gensim.models.keyedvectors.Vocab at 0xc3d5438>,
#   'ur-{d}nin-mu₂': <gensim.models.keyedvectors.Vocab at 0xc3d5470>,
#   'sa[pay-for]V/t': <gensim.models.keyedvectors.Vocab at 0xc3d54a8>,
#   'lugal-x-x': <gensim.models.keyedvectors.Vocab at 0xc3d54e0>,
#   'ki-inim': <gensim.models.keyedvectors.Vocab at 0xc3d5550>,
#   'ara₃': <gensim.models.keyedvectors.Vocab at 0xc3d5588>,
#   'me-an-ne₂-si': <gensim.models.keyedvectors.Vocab at 0xc3d55c0>,
#   'zabar[bronze]N': <gensim.models.keyedvectors.Vocab at 0xc3d55f8>,
#   'gamgam[fish]N': <gensim.models.keyedvectors.Vocab at 0xc3d5630>,
#   'ak[do]V/t': <gensim.models.keyedvectors.Vocab at 0xc3d5668>,
#   'KA-ki-bi-še₃': <gensim.models.keyedvectors.Vocab at 0xc3d56a0>,
#   'nig₂-hu-bu₇{bu}': <gensim.models.keyedvectors.Vocab at 0xc3d56d8>,
#   'ki-ni': <gensim.models.keyedvectors.Vocab at 0xc3d5748>,
#   'kun-du₆': <gensim.models.keyedvectors.Vocab at 0xc3d5780>,
#   'šukud[fisherman]N': <gensim.models.keyedvectors.Vocab at 0xc3d57b8>,
#   '2/4(aš@c)': <gensim.models.keyedvectors.Vocab at 0xc3d57f0>,
#   'x-si': <gensim.models.keyedvectors.Vocab at 0xc3d5860>,
#   'gukkal[sheep]N': <gensim.models.keyedvectors.Vocab at 0xc3d5898>,
#   'en-x-x': <gensim.models.keyedvectors.Vocab at 0xc3d5908>,
#   'giŋ[unit]N': <gensim.models.keyedvectors.Vocab at 0xc3d5940>,
#   'sar[garden]N': <gensim.models.keyedvectors.Vocab at 0xc3d5978>,
#   'niŋdirig[extra]N': <gensim.models.keyedvectors.Vocab at 0xc3d59b0>,
#   'du[build]V/t': <gensim.models.keyedvectors.Vocab at 0xc3d59e8>,
#   'niŋba[gift]N': <gensim.models.keyedvectors.Vocab at 0xc3d5a20>,
#   'siki[hair]N': <gensim.models.keyedvectors.Vocab at 0xc3d5a58>,
#   'gug[cake]N': <gensim.models.keyedvectors.Vocab at 0xc3d5a90>,
#   'kur[unit]N': <gensim.models.keyedvectors.Vocab at 0xc3d5ac8>,
#   'tu₇(|HI×AŠ@c|)': <gensim.models.keyedvectors.Vocab at 0xc3d5b00>,
#   '|LAGAB×(HA.A)|': <gensim.models.keyedvectors.Vocab at 0xc3d5b38>,
#   'i[oil]N': <gensim.models.keyedvectors.Vocab at 0xc3d5ba8>,
#   'nin-a-zu': <gensim.models.keyedvectors.Vocab at 0xc3d5be0>,
#   'il[raise]V/t': <gensim.models.keyedvectors.Vocab at 0xc3d5c18>,
#   'tu[soup]N': <gensim.models.keyedvectors.Vocab at 0xc3d5c50>,
#   'e₂-ur₂-bi-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3d5c88>,
#   'giri₃-ni-ba-dab₅': <gensim.models.keyedvectors.Vocab at 0xc3d5cc0>,
#   'RI-ti': <gensim.models.keyedvectors.Vocab at 0xc3d5d30>,
#   'kigu[~land]N': <gensim.models.keyedvectors.Vocab at 0xc3d5d68>,
#   'ur-abzu': <gensim.models.keyedvectors.Vocab at 0xc3d5dd8>,
#   'ki-ni-mu-zu': <gensim.models.keyedvectors.Vocab at 0xc3d5e10>,
#   'me-an-ne₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3d5e48>,
#   'ur-{d}inanna': <gensim.models.keyedvectors.Vocab at 0xc3d5e80>,
#   'ummia[expert]N': <gensim.models.keyedvectors.Vocab at 0xc3d5eb8>,
#   'ŋar[place]V/t': <gensim.models.keyedvectors.Vocab at 0xc3d5ef0>,
#   'da-da': <gensim.models.keyedvectors.Vocab at 0xc3d5f60>,
#   'sila[street]N': <gensim.models.keyedvectors.Vocab at 0xc3d5f98>,
#   'gan-ezem': <gensim.models.keyedvectors.Vocab at 0xc3d5fd0>,
#   'gallagal[policeman]N': <gensim.models.keyedvectors.Vocab at 0xc3de048>,
#   'bala[turn]V/t': <gensim.models.keyedvectors.Vocab at 0xc3de080>,
#   'AK-nab': <gensim.models.keyedvectors.Vocab at 0xc3de0f0>,
#   'ŠEŠ-KI-na': <gensim.models.keyedvectors.Vocab at 0xc3de128>,
#   'e₂-ezem-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3de160>,
#   'nin-sun₂-zi': <gensim.models.keyedvectors.Vocab at 0xc3de198>,
#   'GUR₈': <gensim.models.keyedvectors.Vocab at 0xc3de1d0>,
#   'mes-e₂-zi-da': <gensim.models.keyedvectors.Vocab at 0xc3de208>,
#   'amar-KID-NUN': <gensim.models.keyedvectors.Vocab at 0xc3de240>,
#   'šeš-pa₃': <gensim.models.keyedvectors.Vocab at 0xc3de278>,
#   'en-guruš-zi': <gensim.models.keyedvectors.Vocab at 0xc3de2b0>,
#   'gugal[inspector]N': <gensim.models.keyedvectors.Vocab at 0xc3de2e8>,
#   'luma[boatman]N': <gensim.models.keyedvectors.Vocab at 0xc3de320>,
#   '{an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0xc3de358>,
#   'ur₂-x': <gensim.models.keyedvectors.Vocab at 0xc3de390>,
#   'e₂-sahar': <gensim.models.keyedvectors.Vocab at 0xc3de3c8>,
#   'ta': <gensim.models.keyedvectors.Vocab at 0xc3de438>,
#   '{d}sud₃-anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0xc3de470>,
#   'utu-nu-me': <gensim.models.keyedvectors.Vocab at 0xc3de4a8>,
#   'x-NI': <gensim.models.keyedvectors.Vocab at 0xc3de518>,
#   'tugdu[felter]N': <gensim.models.keyedvectors.Vocab at 0xc3de550>,
#   'pa-bilₓ(|PAP.GEŠ.BIL|)-ga': <gensim.models.keyedvectors.Vocab at 0xc3de588>,
#   'za₇-gin₃': <gensim.models.keyedvectors.Vocab at 0xc3de5c0>,
#   'gu[pulse]N': <gensim.models.keyedvectors.Vocab at 0xc3de5f8>,
#   'gal-dam-gar₃': <gensim.models.keyedvectors.Vocab at 0xc3de630>,
#   '{d}PA': <gensim.models.keyedvectors.Vocab at 0xc3de6a0>,
#   'saŋ[head]N': <gensim.models.keyedvectors.Vocab at 0xc3de6d8>,
#   'us[side]N': <gensim.models.keyedvectors.Vocab at 0xc3de710>,
#   'saŋdu[beam]N': <gensim.models.keyedvectors.Vocab at 0xc3de748>,
#   'dalla[ring]N': <gensim.models.keyedvectors.Vocab at 0xc3de780>,
#   'su₆-mu₂': <gensim.models.keyedvectors.Vocab at 0xc3de7b8>,
#   'ba[allot]V/t': <gensim.models.keyedvectors.Vocab at 0xc3de7f0>,
#   'atu[doorkeeper?]N': <gensim.models.keyedvectors.Vocab at 0xc3de828>,
#   'mun[salt]V/i': <gensim.models.keyedvectors.Vocab at 0xc3de860>,
#   'ur[pluck]V/t': <gensim.models.keyedvectors.Vocab at 0xc3de898>,
#   'dam[spouse]N': <gensim.models.keyedvectors.Vocab at 0xc3de8d0>,
#   'be₆-li₂-li₂': <gensim.models.keyedvectors.Vocab at 0xc3de908>,
#   'geme[worker]N': <gensim.models.keyedvectors.Vocab at 0xc3de940>,
#   '{d}sud₃': <gensim.models.keyedvectors.Vocab at 0xc3de978>,
#   'ša₃-zu': <gensim.models.keyedvectors.Vocab at 0xc3de9b0>,
#   'kinud[bedroom]N': <gensim.models.keyedvectors.Vocab at 0xc3de9e8>,
#   'ur-{d}nin-PA': <gensim.models.keyedvectors.Vocab at 0xc3dea20>,
#   'na-na': <gensim.models.keyedvectors.Vocab at 0xc3dea90>,
#   '1(aš@v)': <gensim.models.keyedvectors.Vocab at 0xc3deac8>,
#   'x-x-x': <gensim.models.keyedvectors.Vocab at 0xc3deb38>,
#   'allub[crab]N': <gensim.models.keyedvectors.Vocab at 0xc3deb70>,
#   'pa': <gensim.models.keyedvectors.Vocab at 0xc3debe0>,
#   'ezem[festival]N': <gensim.models.keyedvectors.Vocab at 0xc3dec18>,
#   'bahar₂': <gensim.models.keyedvectors.Vocab at 0xc3dec50>,
#   'ma': <gensim.models.keyedvectors.Vocab at 0xc3decc0>,
#   'ki[place]N': <gensim.models.keyedvectors.Vocab at 0xc3decf8>,
#   'niŋsi[provisions]N': <gensim.models.keyedvectors.Vocab at 0xc3ded30>,
#   'kuš[skin]N': <gensim.models.keyedvectors.Vocab at 0xc3ded68>,
#   'si[horn]N': <gensim.models.keyedvectors.Vocab at 0xc3deda0>,
#   'kur[mountain]N': <gensim.models.keyedvectors.Vocab at 0xc3dedd8>,
#   'maš-da₅': <gensim.models.keyedvectors.Vocab at 0xc3dee10>,
#   'zir[break]V/t': <gensim.models.keyedvectors.Vocab at 0xc3dee48>,
#   'aš-ni': <gensim.models.keyedvectors.Vocab at 0xc3dee80>,
#   'e₂-la-lumₓ(LAK218)': <gensim.models.keyedvectors.Vocab at 0xc3deeb8>,
#   'amar-IMMAL': <gensim.models.keyedvectors.Vocab at 0xc3deef0>,
#   'nag-su': <gensim.models.keyedvectors.Vocab at 0xc3def60>,
#   'AN-ur₂-še₃': <gensim.models.keyedvectors.Vocab at 0xc3def98>,
#   'azlag₄': <gensim.models.keyedvectors.Vocab at 0xc3defd0>,
#   'za₃-ta': <gensim.models.keyedvectors.Vocab at 0xc3e7048>,
#   'lugal-ki-tuš-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3e7080>,
#   'lugal-dumu-zi': <gensim.models.keyedvectors.Vocab at 0xc3e70b8>,
#   'aša₅': <gensim.models.keyedvectors.Vocab at 0xc3e70f0>,
#   'al₆-lu-lu': <gensim.models.keyedvectors.Vocab at 0xc3e7128>,
#   '5(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0xc3e7160>,
#   '5(diš@t)': <gensim.models.keyedvectors.Vocab at 0xc3e7198>,
#   'šidim[builder]N': <gensim.models.keyedvectors.Vocab at 0xc3e71d0>,
#   'lugal-ki-gal-la': <gensim.models.keyedvectors.Vocab at 0xc3e7208>,
#   'ama-x': <gensim.models.keyedvectors.Vocab at 0xc3e7278>,
#   'ga-x': <gensim.models.keyedvectors.Vocab at 0xc3e72e8>,
#   '7(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0xc3e7320>,
#   'sag-nin-tuku': <gensim.models.keyedvectors.Vocab at 0xc3e7358>,
#   'nin-ama-na': <gensim.models.keyedvectors.Vocab at 0xc3e7390>,
#   'geš-kin': <gensim.models.keyedvectors.Vocab at 0xc3e73c8>,
#   'lugal[king]N': <gensim.models.keyedvectors.Vocab at 0xc3e7400>,
#   'šešbanda[relation]N': <gensim.models.keyedvectors.Vocab at 0xc3e7438>,
#   '2(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0xc3e7470>,
#   'lugal-bara₂-si': <gensim.models.keyedvectors.Vocab at 0xc3e74a8>,
#   '5(u@c)': <gensim.models.keyedvectors.Vocab at 0xc3e7518>,
#   'e₂-zi-pa-e₃': <gensim.models.keyedvectors.Vocab at 0xc3e7550>,
#   'UD': <gensim.models.keyedvectors.Vocab at 0xc3e75c0>,
#   'x-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3e75f8>,
#   '6(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0xc3e7630>,
#   'kuli[unit]N': <gensim.models.keyedvectors.Vocab at 0xc3e7668>,
#   'gišgal-si': <gensim.models.keyedvectors.Vocab at 0xc3e76a0>,
#   '2(gešʾu@c)': <gensim.models.keyedvectors.Vocab at 0xc3e76d8>,
#   'si-|NU×U|': <gensim.models.keyedvectors.Vocab at 0xc3e7710>,
#   'ensi₂-GAR': <gensim.models.keyedvectors.Vocab at 0xc3e7748>,
#   'en[priest]N': <gensim.models.keyedvectors.Vocab at 0xc3e7780>,
#   'kinda[barber]N': <gensim.models.keyedvectors.Vocab at 0xc3e77b8>,
#   'niŋara[groats]N': <gensim.models.keyedvectors.Vocab at 0xc3e77f0>,
#   '{d}en-lil₂-a₂-mah': <gensim.models.keyedvectors.Vocab at 0xc3e7828>,
#   'lu₂-na-nam': <gensim.models.keyedvectors.Vocab at 0xc3e7860>,
#   'pa₄-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0xc3e7898>,
#   'sag-TAR': <gensim.models.keyedvectors.Vocab at 0xc3e7908>,
#   '{d}suen': <gensim.models.keyedvectors.Vocab at 0xc3e7978>,
#   'e₂-x': <gensim.models.keyedvectors.Vocab at 0xc3e79b0>,
#   'lugal-pa-e₃': <gensim.models.keyedvectors.Vocab at 0xc3e79e8>,
#   'lugal-ki-dur₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3e7a20>,
#   'amar[young]N': <gensim.models.keyedvectors.Vocab at 0xc3e7a58>,
#   '{d}ŠEŠ-KI-na': <gensim.models.keyedvectors.Vocab at 0xc3e7a90>,
#   'a-x-x': <gensim.models.keyedvectors.Vocab at 0xc3e7b00>,
#   'AN-URUDU-si': <gensim.models.keyedvectors.Vocab at 0xc3e7b38>,
#   'du[go]V/t': <gensim.models.keyedvectors.Vocab at 0xc3e7b70>,
#   'e₂-kur-pa-e₃': <gensim.models.keyedvectors.Vocab at 0xc3e7ba8>,
#   '{d}sud₃-nu-me': <gensim.models.keyedvectors.Vocab at 0xc3e7be0>,
#   'ab-ba-ni': <gensim.models.keyedvectors.Vocab at 0xc3e7c18>,
#   'amar-KID-nun': <gensim.models.keyedvectors.Vocab at 0xc3e7c50>,
#   'sila[lamb]N': <gensim.models.keyedvectors.Vocab at 0xc3e7c88>,
#   'nita[male]N': <gensim.models.keyedvectors.Vocab at 0xc3e7cc0>,
#   'LAK020[goat]N': <gensim.models.keyedvectors.Vocab at 0xc3e7cf8>,
#   'u[ewe]N': <gensim.models.keyedvectors.Vocab at 0xc3e7d68>,
#   'utu-a₂-mah': <gensim.models.keyedvectors.Vocab at 0xc3e7da0>,
#   'tur[small]V/i': <gensim.models.keyedvectors.Vocab at 0xc3e7dd8>,
#   'AN-AK': <gensim.models.keyedvectors.Vocab at 0xc3e7e48>,
#   'ur-{d}dumu-zi': <gensim.models.keyedvectors.Vocab at 0xc3e7e80>,
#   '|SUR.GU|': <gensim.models.keyedvectors.Vocab at 0xc3e7eb8>,
#   'nin-da-mah-di': <gensim.models.keyedvectors.Vocab at 0xc3e7ef0>,
#   'ur-{d}nin-pirig': <gensim.models.keyedvectors.Vocab at 0xc3e7f28>,
#   'igi-ildu₃-še₃@90': <gensim.models.keyedvectors.Vocab at 0xc3e7f60>,
#   'lugal-si-sa₂': <gensim.models.keyedvectors.Vocab at 0xc3e7f98>,
#   'ab-ba-tur': <gensim.models.keyedvectors.Vocab at 0xc3e7fd0>,
#   'ku₃-la₂': <gensim.models.keyedvectors.Vocab at 0xc3f0048>,
#   'lugal-šeš': <gensim.models.keyedvectors.Vocab at 0xc3f0080>,
#   'lugal-an-dul₃': <gensim.models.keyedvectors.Vocab at 0xc3f00b8>,
#   'dingir-a-zu': <gensim.models.keyedvectors.Vocab at 0xc3f00f0>,
#   'lugal-e₂-ni-še₃': <gensim.models.keyedvectors.Vocab at 0xc3f0128>,
#   'ša₃-nu-gal₂': <gensim.models.keyedvectors.Vocab at 0xc3f0160>,
#   'e₂-šeš': <gensim.models.keyedvectors.Vocab at 0xc3f0198>,
#   'lugal-sa₆-ga': <gensim.models.keyedvectors.Vocab at 0xc3f01d0>,
#   'gal[big]V/i': <gensim.models.keyedvectors.Vocab at 0xc3f0208>,
#   '2(gešmin@c)': <gensim.models.keyedvectors.Vocab at 0xc3f0240>,
#   'baza[dwarf]N': <gensim.models.keyedvectors.Vocab at 0xc3f0278>,
#   'la[hang]V/t': <gensim.models.keyedvectors.Vocab at 0xc3f02b0>,
#   'ur-x-x': <gensim.models.keyedvectors.Vocab at 0xc3f0320>,
#   'mu-kur-ta': <gensim.models.keyedvectors.Vocab at 0xc3f0358>,
#   'an-dab₆-si': <gensim.models.keyedvectors.Vocab at 0xc3f0390>,
#   'x-nam': <gensim.models.keyedvectors.Vocab at 0xc3f0400>,
#   'me-mah-nu-sa₂': <gensim.models.keyedvectors.Vocab at 0xc3f0438>,
#   'dub[tablet]N': <gensim.models.keyedvectors.Vocab at 0xc3f0470>,
#   'dili[single]V/i': <gensim.models.keyedvectors.Vocab at 0xc3f04a8>,
#   '3(geš₂@c)': <gensim.models.keyedvectors.Vocab at 0xc3f04e0>,
#   'magur[barge]N': <gensim.models.keyedvectors.Vocab at 0xc3f0518>,
#   'RU[~architecture]N': <gensim.models.keyedvectors.Vocab at 0xc3f0550>,
#   'ŋeškiŋti[workshop]N': <gensim.models.keyedvectors.Vocab at 0xc3f0588>,
#   'zagšu[brand]N': <gensim.models.keyedvectors.Vocab at 0xc3f05c0>,
#   'lah[bring]V/t': <gensim.models.keyedvectors.Vocab at 0xc3f05f8>,
#   'iri[city]N': <gensim.models.keyedvectors.Vocab at 0xc3f0630>,
#   'ur-{d}eš-peš': <gensim.models.keyedvectors.Vocab at 0xc3f0668>,
#   '9(aš@c)': <gensim.models.keyedvectors.Vocab at 0xc3f06a0>,
#   'nita-tur': <gensim.models.keyedvectors.Vocab at 0xc3f06d8>,
#   '4(barig@c)': <gensim.models.keyedvectors.Vocab at 0xc3f0710>,
#   'lam-ma': <gensim.models.keyedvectors.Vocab at 0xc3f0780>,
#   'ašgar[kid]N': <gensim.models.keyedvectors.Vocab at 0xc3f07b8>,
#   'ibadu[garment]N': <gensim.models.keyedvectors.Vocab at 0xc3f07f0>,
#   '|GA₂×(HA.A)|': <gensim.models.keyedvectors.Vocab at 0xc3f0828>,
#   'ur-{d}nin-unu': <gensim.models.keyedvectors.Vocab at 0xc3f0860>,
#   'a-har-ši': <gensim.models.keyedvectors.Vocab at 0xc3f0898>,
#   'da-du-lul': <gensim.models.keyedvectors.Vocab at 0xc3f08d0>,
#   'engar-us₂': <gensim.models.keyedvectors.Vocab at 0xc3f0908>,
#   'inim-{d}sud₃-da-zi': <gensim.models.keyedvectors.Vocab at 0xc3f0940>,
#   'šeš-ama(LAK769)-na': <gensim.models.keyedvectors.Vocab at 0xc3f0978>,
#   'inim-ni-zi': <gensim.models.keyedvectors.Vocab at 0xc3f09b0>,
#   'usan₃-du₃': <gensim.models.keyedvectors.Vocab at 0xc3f09e8>,
#   'lu₂-x': <gensim.models.keyedvectors.Vocab at 0xc3f0a20>,
#   'me₃': <gensim.models.keyedvectors.Vocab at 0xc3f0a58>,
#   'niŋgu[food]N': <gensim.models.keyedvectors.Vocab at 0xc3f0a90>,
#   'gi₄-za': <gensim.models.keyedvectors.Vocab at 0xc3f0ac8>,
#   'amar-{d}šuba₃': <gensim.models.keyedvectors.Vocab at 0xc3f0b00>,
#   'ki-nir': <gensim.models.keyedvectors.Vocab at 0xc3f0b70>,
#   'amar-{d}PA': <gensim.models.keyedvectors.Vocab at 0xc3f0ba8>,
#   'šul[youth]V/i': <gensim.models.keyedvectors.Vocab at 0xc3f0be0>,
#   'a-du₇': <gensim.models.keyedvectors.Vocab at 0xc3f0c18>,
#   'ur-NI': <gensim.models.keyedvectors.Vocab at 0xc3f0c88>,
#   'a-NE-nu': <gensim.models.keyedvectors.Vocab at 0xc3f0cf8>,
#   'KA-lugal-zi-da': <gensim.models.keyedvectors.Vocab at 0xc3f0d30>,
#   'en-abzu-ta-mud': <gensim.models.keyedvectors.Vocab at 0xc3f0d68>,
#   'sangaₓ(|ŠID.NIG₂|)': <gensim.models.keyedvectors.Vocab at 0xc3f0da0>,
#   'ensikgal[governor]N': <gensim.models.keyedvectors.Vocab at 0xc3f0dd8>,
#   'a-du₆': <gensim.models.keyedvectors.Vocab at 0xc3f0e10>,
#   'lu₂-HAR': <gensim.models.keyedvectors.Vocab at 0xc3f0e48>,
#   '{d}ad-ašgi₂{gi₄}-ur-sag': <gensim.models.keyedvectors.Vocab at 0xc3f0e80>,
#   'a-nun-pa₃': <gensim.models.keyedvectors.Vocab at 0xc3f0eb8>,
#   'lu₂-lal₃': <gensim.models.keyedvectors.Vocab at 0xc3f0ef0>,
#   'MI': <gensim.models.keyedvectors.Vocab at 0xc3f0f60>,
#   'e₂-du₇-du₇': <gensim.models.keyedvectors.Vocab at 0xc3f0f98>,
#   'nig₂-gal₂-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3f0fd0>,
#   'AK-dingir': <gensim.models.keyedvectors.Vocab at 0xc3f9048>,
#   'ašgabgal[leatherworker]N': <gensim.models.keyedvectors.Vocab at 0xc3f9080>,
#   'dabin[semolina]N': <gensim.models.keyedvectors.Vocab at 0xc3f90b8>,
#   'bur-nun-si': <gensim.models.keyedvectors.Vocab at 0xc3f90f0>,
#   'babbar[white]V/i': <gensim.models.keyedvectors.Vocab at 0xc3f9128>,
#   'nida': <gensim.models.keyedvectors.Vocab at 0xc3f9198>,
#   'aslum[sheep]N': <gensim.models.keyedvectors.Vocab at 0xc3f91d0>,
#   'AK-AN': <gensim.models.keyedvectors.Vocab at 0xc3f9240>,
#   'mar[wagon]N': <gensim.models.keyedvectors.Vocab at 0xc3f9278>,
#   'šir-ezen': <gensim.models.keyedvectors.Vocab at 0xc3f92b0>,
#   'ur-e₂': <gensim.models.keyedvectors.Vocab at 0xc3f92e8>,
#   'ur-{d}TAG-nun': <gensim.models.keyedvectors.Vocab at 0xc3f9320>,
#   'ga-ri': <gensim.models.keyedvectors.Vocab at 0xc3f9390>,
#   'lu₂-geme₂-zi': <gensim.models.keyedvectors.Vocab at 0xc3f93c8>,
#   'LAK343': <gensim.models.keyedvectors.Vocab at 0xc3f9438>,
#   'en-MU-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3f9470>,
#   'ur-{d}lamma': <gensim.models.keyedvectors.Vocab at 0xc3f94a8>,
#   'zum-da': <gensim.models.keyedvectors.Vocab at 0xc3f9518>,
#   'ur-{d}{še₃}šer₇-da': <gensim.models.keyedvectors.Vocab at 0xc3f9550>,
#   'gissu-bi': <gensim.models.keyedvectors.Vocab at 0xc3f9588>,
#   'a-nun-{d}sud₃': <gensim.models.keyedvectors.Vocab at 0xc3f95c0>,
#   'lu₂-ninda₂': <gensim.models.keyedvectors.Vocab at 0xc3f95f8>,
#   'galla[policeman]N': <gensim.models.keyedvectors.Vocab at 0xc3f9630>,
#   'ša₃-TAR': <gensim.models.keyedvectors.Vocab at 0xc3f9668>,
#   'gal-sagi': <gensim.models.keyedvectors.Vocab at 0xc3f96a0>,
#   'bilₓ(|GIŠ.PAP.NE|)-a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0xc3f96d8>,
#   'šenumun[seed]N': <gensim.models.keyedvectors.Vocab at 0xc3f9710>,
#   'kalam-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3f9748>,
#   'kur-a₂-gal₂': <gensim.models.keyedvectors.Vocab at 0xc3f9780>,
#   'a-RI-ti': <gensim.models.keyedvectors.Vocab at 0xc3f97f0>,
#   '2(burʾu@c)': <gensim.models.keyedvectors.Vocab at 0xc3f9828>,
#   '2(bur₃@c)': <gensim.models.keyedvectors.Vocab at 0xc3f9860>,
#   'gu₂-u₂': <gensim.models.keyedvectors.Vocab at 0xc3f9898>,
#   'urtur[puppy]N': <gensim.models.keyedvectors.Vocab at 0xc3f98d0>,
#   'e₂-zi': <gensim.models.keyedvectors.Vocab at 0xc3f9908>,
#   'mes-ki-erim₂': <gensim.models.keyedvectors.Vocab at 0xc3f9940>,
#   'x-ki': <gensim.models.keyedvectors.Vocab at 0xc3f99b0>,
#   'amar-{d}nam-nir': <gensim.models.keyedvectors.Vocab at 0xc3f99e8>,
#   'ni₂-kur-ra': <gensim.models.keyedvectors.Vocab at 0xc3f9a20>,
#   'kiŋ[work]N': <gensim.models.keyedvectors.Vocab at 0xc3f9a58>,
#   'tur[stall]N': <gensim.models.keyedvectors.Vocab at 0xc3f9a90>,
#   'NA': <gensim.models.keyedvectors.Vocab at 0xc3f9b00>,
#   'anna[metal]N': <gensim.models.keyedvectors.Vocab at 0xc3f9b38>,
#   'unken-a': <gensim.models.keyedvectors.Vocab at 0xc3f9ba8>,
#   'ur-kin-nir': <gensim.models.keyedvectors.Vocab at 0xc3f9be0>,
#   'A': <gensim.models.keyedvectors.Vocab at 0xc3f9c18>,
#   'ur-sipa': <gensim.models.keyedvectors.Vocab at 0xc3f9c88>,
#   'ba-zi': <gensim.models.keyedvectors.Vocab at 0xc3f9cf8>,
#   'AN-x': <gensim.models.keyedvectors.Vocab at 0xc3f9d68>,
#   'susig[flayer]N': <gensim.models.keyedvectors.Vocab at 0xc3f9da0>,
#   'a₂-nu-kuš₂': <gensim.models.keyedvectors.Vocab at 0xc3f9dd8>,
#   'lugal-šembi₃': <gensim.models.keyedvectors.Vocab at 0xc3f9e10>,
#   'ur-nin': <gensim.models.keyedvectors.Vocab at 0xc3f9e80>,
#   '1(diš@t)': <gensim.models.keyedvectors.Vocab at 0xc3f9eb8>,
#   'e₂-gissu-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3f9ef0>,
#   'am[bull]N': <gensim.models.keyedvectors.Vocab at 0xc3f9f28>,
#   'ša₁₃-dub': <gensim.models.keyedvectors.Vocab at 0xc3f9f60>,
#   'KA-x': <gensim.models.keyedvectors.Vocab at 0xc3f9fd0>,
#   'mes-nig₂-lul-le': <gensim.models.keyedvectors.Vocab at 0xc3ff048>,
#   'šubur-x': <gensim.models.keyedvectors.Vocab at 0xc3ff080>,
#   'gudu₄': <gensim.models.keyedvectors.Vocab at 0xc3ff0b8>,
#   'ŋeš[tree]N': <gensim.models.keyedvectors.Vocab at 0xc3ff0f0>,
#   'DU-x': <gensim.models.keyedvectors.Vocab at 0xc3ff160>,
#   'dul[cover]V/t': <gensim.models.keyedvectors.Vocab at 0xc3ff198>,
#   'balaₓ(LAK020)': <gensim.models.keyedvectors.Vocab at 0xc3ff1d0>,
#   '1/4(aš@c)': <gensim.models.keyedvectors.Vocab at 0xc3ff208>,
#   'DI': <gensim.models.keyedvectors.Vocab at 0xc3ff278>,
#   'tah[add]V/t': <gensim.models.keyedvectors.Vocab at 0xc3ff2b0>,
#   'en-kalam-du₁₀': <gensim.models.keyedvectors.Vocab at 0xc3ff2e8>,
#   'en-abzu-mud': <gensim.models.keyedvectors.Vocab at 0xc3ff320>,
#   'pa₄-zi': <gensim.models.keyedvectors.Vocab at 0xc3ff358>,
#   'dur-narₓ(LAK244)': <gensim.models.keyedvectors.Vocab at 0xc3ff390>,
#   'munus-{d}anzu': <gensim.models.keyedvectors.Vocab at 0xc3ff3c8>,
#   'UŠ-x': <gensim.models.keyedvectors.Vocab at 0xc3ff400>,
#   'a-ru': <gensim.models.keyedvectors.Vocab at 0xc3ff470>,
#   'nin-bad₃': <gensim.models.keyedvectors.Vocab at 0xc3ff4a8>,
#   'pa₄-NAM₂': <gensim.models.keyedvectors.Vocab at 0xc3ff4e0>,
#   'ur-{d}aš₈-gi₄': <gensim.models.keyedvectors.Vocab at 0xc3ff518>,
#   'gal-zadim': <gensim.models.keyedvectors.Vocab at 0xc3ff550>,
#   'lagaš{ki}': <gensim.models.keyedvectors.Vocab at 0xc3ff588>,
#   'x-ur-sag': <gensim.models.keyedvectors.Vocab at 0xc3ff5c0>,
#   'iš-lul-il': <gensim.models.keyedvectors.Vocab at 0xc3ff5f8>,
#   'AN-ur-sag': <gensim.models.keyedvectors.Vocab at 0xc3ff630>,
#   'ur-PA': <gensim.models.keyedvectors.Vocab at 0xc3ff6a0>,
#   'nin-unken-a': <gensim.models.keyedvectors.Vocab at 0xc3ff6d8>,
#   'ur-sag-zi': <gensim.models.keyedvectors.Vocab at 0xc3ff710>,
#   'zid[flour]N': <gensim.models.keyedvectors.Vocab at 0xc3ff748>,
#   'magid[boat-tower]N': <gensim.models.keyedvectors.Vocab at 0xc3ff780>,
#   'ma[ship]N': <gensim.models.keyedvectors.Vocab at 0xc3ff7b8>,
#   'a-hu-ti{ki}': <gensim.models.keyedvectors.Vocab at 0xc3ff7f0>,
#   'sum': <gensim.models.keyedvectors.Vocab at 0xc3ff860>,
#   'ti[arrow]N': <gensim.models.keyedvectors.Vocab at 0xc3ff898>,
#   'dug[pot]N': <gensim.models.keyedvectors.Vocab at 0xc3ff8d0>,
#   'ga[milk]N': <gensim.models.keyedvectors.Vocab at 0xc3ff908>,
#   'eš[rope]N': <gensim.models.keyedvectors.Vocab at 0xc3ff940>,
#   'gisal': <gensim.models.keyedvectors.Vocab at 0xc3ff9b0>,
#   'ŋešgu[stock]N': <gensim.models.keyedvectors.Vocab at 0xc3ff9e8>,
#   'KAL': <gensim.models.keyedvectors.Vocab at 0xc3ffa58>,
#   'anur[horizon]N': <gensim.models.keyedvectors.Vocab at 0xc3ffa90>,
#   'emuhaldim[kitchen]N': <gensim.models.keyedvectors.Vocab at 0xc3ffac8>,
#   'n(aš@c)': <gensim.models.keyedvectors.Vocab at 0xc3ffb00>,
#   'lugal-uri₃': <gensim.models.keyedvectors.Vocab at 0xc3ffb38>,
#   'šeš-lu₂': <gensim.models.keyedvectors.Vocab at 0xc3ffb70>,
#   'ŋanun[storehouse]N': <gensim.models.keyedvectors.Vocab at 0xc3ffba8>,
#   'pa₄-{+an}anzuₓ(MI){mušen}': <gensim.models.keyedvectors.Vocab at 0xc3ffbe0>,
#   'agrig[steward]N': <gensim.models.keyedvectors.Vocab at 0xc3ffc18>,
#   'a-ru₁₂-da': <gensim.models.keyedvectors.Vocab at 0xc3ffc50>,
#   'kug[metal]N': <gensim.models.keyedvectors.Vocab at 0xc3ffc88>,
#   'HAR-tu': <gensim.models.keyedvectors.Vocab at 0xc3ffcf8>,
#   'ba-da-da': <gensim.models.keyedvectors.Vocab at 0xc3ffd30>,
#   'kiʾinimak[witness]N': <gensim.models.keyedvectors.Vocab at 0xc3ffd68>,
#   '2/3(|NINDA₂×(ŠE.2(AŠ@c))|)': <gensim.models.keyedvectors.Vocab at 0xc3ffda0>,
#   'inim[word]N': <gensim.models.keyedvectors.Vocab at 0xc3ffdd8>,
#   'har-tu': <gensim.models.keyedvectors.Vocab at 0xc3ffe48>,
#   'dag-dag': <gensim.models.keyedvectors.Vocab at 0xc3ffeb8>,
#   'utul': <gensim.models.keyedvectors.Vocab at 0xc3fff28>,
#   'udu-nita': <gensim.models.keyedvectors.Vocab at 0xc3fff60>,
#   'AB-x': <gensim.models.keyedvectors.Vocab at 0xc3fffd0>,
#   'nin-PA': <gensim.models.keyedvectors.Vocab at 0xc407080>,
#   '|LAHTAN×GU|': <gensim.models.keyedvectors.Vocab at 0xc4070b8>,
# ...
#   'ramû[thrown]AJ': <gensim.models.keyedvectors.Vocab at 0xc535ef0>,
#   'Namtar[1]DN': <gensim.models.keyedvectors.Vocab at 0xc535f28>,
#   'šamnu[oil]N': <gensim.models.keyedvectors.Vocab at 0xc535f60>,
#   'x-ma': <gensim.models.keyedvectors.Vocab at 0xc535fd0>,
#   'šizbu[milk]N': <gensim.models.keyedvectors.Vocab at 0xc54f048>,
#   'x-u₂': <gensim.models.keyedvectors.Vocab at 0xc54f080>,
#   '{d}MIN': <gensim.models.keyedvectors.Vocab at 0xc54f0f0>,
#   'šanû[second]NU': <gensim.models.keyedvectors.Vocab at 0xc54f128>,
#   'eššu[new]AJ': <gensim.models.keyedvectors.Vocab at 0xc54f160>,
#   'rēmēnû[merciful]AJ': <gensim.models.keyedvectors.Vocab at 0xc54f198>,
#   'kanšu[submissive-one]N': <gensim.models.keyedvectors.Vocab at 0xc54f1d0>,
#   'nūru[light]N': <gensim.models.keyedvectors.Vocab at 0xc54f208>,
#   'puqqu[pay-attention-to]V': <gensim.models.keyedvectors.Vocab at 0xc54f240>,
#   'Anunnaku[1]DN': <gensim.models.keyedvectors.Vocab at 0xc54f278>,
#   'lišānu[tongue]N': <gensim.models.keyedvectors.Vocab at 0xc54f2b0>,
#   'mithurtu[convergence]N': <gensim.models.keyedvectors.Vocab at 0xc54f2e8>,
#   'ešēru[go-well]V': <gensim.models.keyedvectors.Vocab at 0xc54f320>,
#   'hadû[joyful]AJ': <gensim.models.keyedvectors.Vocab at 0xc54f358>,
#   'rūqu[distant]AJ': <gensim.models.keyedvectors.Vocab at 0xc54f390>,
#   'diglu[vision]N': <gensim.models.keyedvectors.Vocab at 0xc54f3c8>,
#   'hadû[be(come)-joyful]V': <gensim.models.keyedvectors.Vocab at 0xc54f400>,
#   'eṣēnu[smell]V': <gensim.models.keyedvectors.Vocab at 0xc54f438>,
#   'qutrēnu[incense-(offering)]N': <gensim.models.keyedvectors.Vocab at 0xc54f470>,
#   'kurunnu[(a-kind-of-beer)]N': <gensim.models.keyedvectors.Vocab at 0xc54f4a8>,
#   'šittu[remnant]N': <gensim.models.keyedvectors.Vocab at 0xc54f4e0>,
#   'dalhu[troubled]AJ': <gensim.models.keyedvectors.Vocab at 0xc54f518>,
#   'ebbu[bright]AJ': <gensim.models.keyedvectors.Vocab at 0xc54f550>,
#   'arurtu[famine]N': <gensim.models.keyedvectors.Vocab at 0xc54f588>,
#   'dimtu[tear]N': <gensim.models.keyedvectors.Vocab at 0xc54f5c0>,
#   'qiddatu[bending-down]N': <gensim.models.keyedvectors.Vocab at 0xc54f5f8>,
#   'dīnu[legal-decision]N': <gensim.models.keyedvectors.Vocab at 0xc54f630>,
#   'diānu[judge]V': <gensim.models.keyedvectors.Vocab at 0xc54f668>,
#   'rihûtu[progeny]N': <gensim.models.keyedvectors.Vocab at 0xc54f6a0>,
#   'iššiakku[city-ruler]N': <gensim.models.keyedvectors.Vocab at 0xc54f6d8>,
#   'bikītu[weeping]N': <gensim.models.keyedvectors.Vocab at 0xc54f710>,
#   'LI': <gensim.models.keyedvectors.Vocab at 0xc54f780>,
#   'mala[as-much-as]PRP': <gensim.models.keyedvectors.Vocab at 0xc54f7b8>,
#   'nāgiru[(town)-crier]N': <gensim.models.keyedvectors.Vocab at 0xc54f7f0>,
#   'šuharruru[be(come)-deathly-still]V': <gensim.models.keyedvectors.Vocab at 0xc54f828>,
#   'karāmu[grasp]V': <gensim.models.keyedvectors.Vocab at 0xc54f860>,
#   'hiāšu[hurry]V': <gensim.models.keyedvectors.Vocab at 0xc54f898>,
#   'kīam[so]AV': <gensim.models.keyedvectors.Vocab at 0xc54f8d0>,
#   'ewû[become]V': <gensim.models.keyedvectors.Vocab at 0xc54f908>,
#   'zamāru[song]N': <gensim.models.keyedvectors.Vocab at 0xc54f940>,
#   'damqu[good]AJ': <gensim.models.keyedvectors.Vocab at 0xc54f978>,
#   'warkatu[rear]N': <gensim.models.keyedvectors.Vocab at 0xc54f9b0>,
#   'x{+u₂}': <gensim.models.keyedvectors.Vocab at 0xc54f9e8>,
#   'ṣupru[nail]N': <gensim.models.keyedvectors.Vocab at 0xc54fa20>,
#   'Alexander[1]RN': <gensim.models.keyedvectors.Vocab at 0xc54fa58>,
#   'pālihu[reverent-one]N': <gensim.models.keyedvectors.Vocab at 0xc54fa90>,
#   'Nanaya[1]DN': <gensim.models.keyedvectors.Vocab at 0xc54fac8>,
#   'Ezida[1]TN': <gensim.models.keyedvectors.Vocab at 0xc54fb00>,
#   'wāšipu[exorcist]N': <gensim.models.keyedvectors.Vocab at 0xc54fb38>,
#   'ṣimdu[binding]N': <gensim.models.keyedvectors.Vocab at 0xc54fb70>,
#   'x-gi': <gensim.models.keyedvectors.Vocab at 0xc54fbe0>,
#   'nesû[be(come)-distant]V': <gensim.models.keyedvectors.Vocab at 0xc54fc18>,
#   'rêqu[be(come)-distant]V': <gensim.models.keyedvectors.Vocab at 0xc54fc50>,
#   'zakāru[speak]V': <gensim.models.keyedvectors.Vocab at 0xc54fc88>,
#   'ṭarādu[send-off]V': <gensim.models.keyedvectors.Vocab at 0xc54fcc0>,
#   'tāmartu[view(ing)]N': <gensim.models.keyedvectors.Vocab at 0xc54fcf8>,
#   'šīmtu[fate]N': <gensim.models.keyedvectors.Vocab at 0xc54fd30>,
#   'šittu[sleep]N': <gensim.models.keyedvectors.Vocab at 0xc54fd68>,
#   'ṣabātu[seize]V': <gensim.models.keyedvectors.Vocab at 0xc54fda0>,
#   'gaṣṣu[cruel]AJ': <gensim.models.keyedvectors.Vocab at 0xc54fdd8>,
#   'eperu[earth]N': <gensim.models.keyedvectors.Vocab at 0xc54fe10>,
#   'werû[copper]N': <gensim.models.keyedvectors.Vocab at 0xc54fe48>,
#   'x-ru': <gensim.models.keyedvectors.Vocab at 0xc54feb8>,
#   'Anzu[1]DN': <gensim.models.keyedvectors.Vocab at 0xc54fef0>,
#   'U₂': <gensim.models.keyedvectors.Vocab at 0xc54ff28>,
#   'x-ti': <gensim.models.keyedvectors.Vocab at 0xc54ff98>,
#   'nesû[far]AJ': <gensim.models.keyedvectors.Vocab at 0xc54ffd0>,
#   'lummunu[very-bad]AJ': <gensim.models.keyedvectors.Vocab at 0xc724048>,
#   'ṭupšarru[scribe]N': <gensim.models.keyedvectors.Vocab at 0xc724080>,
#   'hišihtu[requirement]N': <gensim.models.keyedvectors.Vocab at 0xc7240b8>,
#   '{m}{d}x': <gensim.models.keyedvectors.Vocab at 0xc724128>,
#   'u₂': <gensim.models.keyedvectors.Vocab at 0xc724160>,
#   'apālu[pay]V': <gensim.models.keyedvectors.Vocab at 0xc724198>,
#   'x-an-ni': <gensim.models.keyedvectors.Vocab at 0xc724208>,
#   'x-u': <gensim.models.keyedvectors.Vocab at 0xc724278>,
#   'ṣuhāru[boy]N': <gensim.models.keyedvectors.Vocab at 0xc7242b0>,
#   'nasāsu[lament]V': <gensim.models.keyedvectors.Vocab at 0xc7242e8>,
#   'Mandanu[1]DN': <gensim.models.keyedvectors.Vocab at 0xc724320>,
#   'Babilu[1]SN': <gensim.models.keyedvectors.Vocab at 0xc724358>,
#   'Esaŋila[1]TN': <gensim.models.keyedvectors.Vocab at 0xc724390>,
#   'dadmū[villages]N': <gensim.models.keyedvectors.Vocab at 0xc7243c8>,
#   'ti-x': <gensim.models.keyedvectors.Vocab at 0xc724438>,
#   'duššû[abundant]AJ': <gensim.models.keyedvectors.Vocab at 0xc724470>,
#   'ṣēnu[flock]N': <gensim.models.keyedvectors.Vocab at 0xc7244a8>,
#   'parkullu[seal-cutter]N': <gensim.models.keyedvectors.Vocab at 0xc7244e0>,
#   'pūru[(stone)-bowl]N': <gensim.models.keyedvectors.Vocab at 0xc724518>,
#   'naqāru[demolish]V': <gensim.models.keyedvectors.Vocab at 0xc724550>,
#   'abnu[stone]N': <gensim.models.keyedvectors.Vocab at 0xc724588>,
#   'banû[create]V': <gensim.models.keyedvectors.Vocab at 0xc7245c0>,
#   'māhāzu[shrine]N': <gensim.models.keyedvectors.Vocab at 0xc7245f8>,
#   'tēdištu[renewal]N': <gensim.models.keyedvectors.Vocab at 0xc724630>,
#   'apsû[(cosmic)-underground-water]N': <gensim.models.keyedvectors.Vocab at 0xc724668>,
#   'kakkultu[mash-tub]N': <gensim.models.keyedvectors.Vocab at 0xc7246a0>,
#   'qalālu[be(come)-light]V': <gensim.models.keyedvectors.Vocab at 0xc7246d8>,
#   'šalālu[carry-off]V': <gensim.models.keyedvectors.Vocab at 0xc724710>,
#   'šuklulu[complete]V': <gensim.models.keyedvectors.Vocab at 0xc724748>,
#   'tubqu[corner]N': <gensim.models.keyedvectors.Vocab at 0xc724780>,
#   'pelludû[cult(ic-rites)]N': <gensim.models.keyedvectors.Vocab at 0xc7247b8>,
#   'palû[reign]N': <gensim.models.keyedvectors.Vocab at 0xc7247f0>,
#   'šupêlu[exchange]V': <gensim.models.keyedvectors.Vocab at 0xc724828>,
#   'x-a-x': <gensim.models.keyedvectors.Vocab at 0xc724898>,
#   'īku[dyke]N': <gensim.models.keyedvectors.Vocab at 0xc7248d0>,
#   'palgu[ditch]N': <gensim.models.keyedvectors.Vocab at 0xc724908>,
#   'pišannu[box]N': <gensim.models.keyedvectors.Vocab at 0xc724940>,
#   'ŠI': <gensim.models.keyedvectors.Vocab at 0xc724978>,
#   'KAL': <gensim.models.keyedvectors.Vocab at 0xc7249e8>,
#   'lītu[cow]N': <gensim.models.keyedvectors.Vocab at 0xc724a20>,
#   'Ekiur[1]TN': <gensim.models.keyedvectors.Vocab at 0xc724a58>,
#   'etelliš[as-a-lord]AV': <gensim.models.keyedvectors.Vocab at 0xc724a90>,
#   'taklu[reliable]AJ': <gensim.models.keyedvectors.Vocab at 0xc724ac8>,
#   'meṣherūtu[childhood]N': <gensim.models.keyedvectors.Vocab at 0xc724b00>,
#   'a-ma-x': <gensim.models.keyedvectors.Vocab at 0xc724b70>,
#   'šaknu[placed]AJ': <gensim.models.keyedvectors.Vocab at 0xc724ba8>,
#   'um': <gensim.models.keyedvectors.Vocab at 0xc724c18>,
#   'magāru[consent]V': <gensim.models.keyedvectors.Vocab at 0xc724c50>,
#   'libbātu[rage]N': <gensim.models.keyedvectors.Vocab at 0xc724c88>,
#   'šanîš[secondly]AV': <gensim.models.keyedvectors.Vocab at 0xc724cc0>,
#   'ahātu[sister]N': <gensim.models.keyedvectors.Vocab at 0xc724cf8>,
#   'gimillu[requital]N': <gensim.models.keyedvectors.Vocab at 0xc724d30>,
#   'mūdû[knowing]AJ': <gensim.models.keyedvectors.Vocab at 0xc724d68>,
#   'x-im-ma': <gensim.models.keyedvectors.Vocab at 0xc724dd8>,
#   'hašāšu[swell]V': <gensim.models.keyedvectors.Vocab at 0xc724e10>,
#   'duruššu[foundation-(platform)]N': <gensim.models.keyedvectors.Vocab at 0xc724e48>,
#   'naparkû[cease]V': <gensim.models.keyedvectors.Vocab at 0xc724e80>,
#   'šiāšim[to-her]IP': <gensim.models.keyedvectors.Vocab at 0xc724eb8>,
#   'šanû[do-twice]V': <gensim.models.keyedvectors.Vocab at 0xc724ef0>,
#   'šapāru[send]V': <gensim.models.keyedvectors.Vocab at 0xc724f28>,
#   'aššūtu[marriage]N': <gensim.models.keyedvectors.Vocab at 0xc724f60>,
#   'kittu[steadiness]N': <gensim.models.keyedvectors.Vocab at 0xc724f98>,
#   'biblu[bringing]N': <gensim.models.keyedvectors.Vocab at 0xc724fd0>,
#   'perʾu[bud]N': <gensim.models.keyedvectors.Vocab at 0xc73a048>,
#   'ilittu[birth]N': <gensim.models.keyedvectors.Vocab at 0xc73a080>,
#   'Anšar[1]DN': <gensim.models.keyedvectors.Vocab at 0xc73a0b8>,
#   'Ninlil[1]DN': <gensim.models.keyedvectors.Vocab at 0xc73a0f0>,
#   'išittu[storeroom]N': <gensim.models.keyedvectors.Vocab at 0xc73a128>,
#   'narāmu[loved-one]N': <gensim.models.keyedvectors.Vocab at 0xc73a160>,
#   'qīštu[gift]N': <gensim.models.keyedvectors.Vocab at 0xc73a198>,
#   'qiāšu[give]V': <gensim.models.keyedvectors.Vocab at 0xc73a1d0>,
#   'kâti[you]IP': <gensim.models.keyedvectors.Vocab at 0xc73a208>,
#   'paqādu[entrust]V': <gensim.models.keyedvectors.Vocab at 0xc73a240>,
#   'kuzbu[attractiveness]N': <gensim.models.keyedvectors.Vocab at 0xc73a278>,
#   'x-ta-x': <gensim.models.keyedvectors.Vocab at 0xc73a2e8>,
#   'šukênu[prostrate-oneself]V': <gensim.models.keyedvectors.Vocab at 0xc73a320>,
#   'ŠU': <gensim.models.keyedvectors.Vocab at 0xc73a358>,
#   'hubullu[debt]N': <gensim.models.keyedvectors.Vocab at 0xc73a390>,
#   'x-ni': <gensim.models.keyedvectors.Vocab at 0xc73a400>,
#   'agarinnu[womb]N': <gensim.models.keyedvectors.Vocab at 0xc73a438>,
#   'šikaru[beer]N': <gensim.models.keyedvectors.Vocab at 0xc73a470>,
#   'neqelpû[float]V': <gensim.models.keyedvectors.Vocab at 0xc73a4a8>,
#   'buqlu[malt]N': <gensim.models.keyedvectors.Vocab at 0xc73a4e0>,
#   'sapāhu[scatter]V': <gensim.models.keyedvectors.Vocab at 0xc73a518>,
#   'gišimmaru[date-palm]N': <gensim.models.keyedvectors.Vocab at 0xc73a550>,
#   'sarru[false]AJ': <gensim.models.keyedvectors.Vocab at 0xc73a588>,
#   'IŠ': <gensim.models.keyedvectors.Vocab at 0xc73a5c0>,
#   'tu-x-x': <gensim.models.keyedvectors.Vocab at 0xc73a630>,
#   'retû[drive-in]V': <gensim.models.keyedvectors.Vocab at 0xc73a668>,
#   'ta-x-x': <gensim.models.keyedvectors.Vocab at 0xc73a6d8>,
#   'salātu[family]N': <gensim.models.keyedvectors.Vocab at 0xc73a710>,
#   'talīmu[favourite-brother]N': <gensim.models.keyedvectors.Vocab at 0xc73a748>,
#   'semeru[ring]N': <gensim.models.keyedvectors.Vocab at 0xc73a780>,
#   'mi-x': <gensim.models.keyedvectors.Vocab at 0xc73a7f0>,
#   'qa-x': <gensim.models.keyedvectors.Vocab at 0xc73a860>,
#   'appāru[reed-bed]N': <gensim.models.keyedvectors.Vocab at 0xc73a898>,
#   'šuqlu[marsh]N': <gensim.models.keyedvectors.Vocab at 0xc73a8d0>,
#   'abālu[dry-(up)]V': <gensim.models.keyedvectors.Vocab at 0xc73a908>,
#   'ebūru[summer]N': <gensim.models.keyedvectors.Vocab at 0xc73a940>,
#   'ṭebû[sink]V': <gensim.models.keyedvectors.Vocab at 0xc73a978>,
#   'nâlu[lie-down]V': <gensim.models.keyedvectors.Vocab at 0xc73a9b0>,
#   'bērūtu[mound]N': <gensim.models.keyedvectors.Vocab at 0xc73a9e8>,
#   'qinnu[nest]N': <gensim.models.keyedvectors.Vocab at 0xc73aa20>,
#   'abūbu[flood]N': <gensim.models.keyedvectors.Vocab at 0xc73aa58>,
#   'raṣānu[be-powerful-(of-voice)]V': <gensim.models.keyedvectors.Vocab at 0xc73aa90>,
#   'šemû[hear]V': <gensim.models.keyedvectors.Vocab at 0xc73aac8>,
#   'patāqu[shape]V': <gensim.models.keyedvectors.Vocab at 0xc73ab00>,
#   'ilku[(state)-service]N': <gensim.models.keyedvectors.Vocab at 0xc73ab38>,
#   'lēʾû[powerful-one]N': <gensim.models.keyedvectors.Vocab at 0xc73ab70>,
#   'arāku[be(come)-long]V': <gensim.models.keyedvectors.Vocab at 0xc73aba8>,
#   'rapāšu[be(come)-broad]V': <gensim.models.keyedvectors.Vocab at 0xc73abe0>,
#   'ṣurru[interior]N': <gensim.models.keyedvectors.Vocab at 0xc73ac18>,
#   'hesû[cover-up]V': <gensim.models.keyedvectors.Vocab at 0xc73ac50>,
#   'nazāqu[creak]V': <gensim.models.keyedvectors.Vocab at 0xc73ac88>,
#   'kabātu[be(come)-heavy]V': <gensim.models.keyedvectors.Vocab at 0xc73acc0>,
#   'walādu[give-birth-(to)]V': <gensim.models.keyedvectors.Vocab at 0xc73acf8>,
#   'ṣīhtu[laughter]N': <gensim.models.keyedvectors.Vocab at 0xc73ad30>,
#   'tāhāzu[battle]N': <gensim.models.keyedvectors.Vocab at 0xc73ad68>,
#   'harrānu[path]N': <gensim.models.keyedvectors.Vocab at 0xc73ada0>,
#   'parāku[lie-across]V': <gensim.models.keyedvectors.Vocab at 0xc73add8>,
#   'sapānu[flatten]V': <gensim.models.keyedvectors.Vocab at 0xc73ae10>,
#   'rabṣu[recumbent]AJ': <gensim.models.keyedvectors.Vocab at 0xc73ae48>,
#   'šagāmu[roar]V': <gensim.models.keyedvectors.Vocab at 0xc73ae80>,
#   'x-tu₄': <gensim.models.keyedvectors.Vocab at 0xc73aeb8>,
#   '{d}x-x': <gensim.models.keyedvectors.Vocab at 0xc73af28>,
#   'danānu[power]N': <gensim.models.keyedvectors.Vocab at 0xc73af60>,
#   'šuklulu[complete]AJ': <gensim.models.keyedvectors.Vocab at 0xc73af98>,
#   'nukurtu[enmity]N': <gensim.models.keyedvectors.Vocab at 0xc73afd0>,
#   'tebû[arisen]AJ': <gensim.models.keyedvectors.Vocab at 0xc856048>,
#   'mešrêtu[limbs]N': <gensim.models.keyedvectors.Vocab at 0xc856080>,
#   'ai[alas!]J': <gensim.models.keyedvectors.Vocab at 0xc8560b8>,
#   'dâlu[move]V': <gensim.models.keyedvectors.Vocab at 0xc8560f0>,
#   'Ur[1]SN': <gensim.models.keyedvectors.Vocab at 0xc856160>,
#   '{m}x': <gensim.models.keyedvectors.Vocab at 0xc8561d0>,
#   'Marduk-zer-ibni[1]PN': <gensim.models.keyedvectors.Vocab at 0xc856208>,
#   'galaturru[junior-lamentation-priest]N': <gensim.models.keyedvectors.Vocab at 0xc856240>,
#   'pāqidu[carer]N': <gensim.models.keyedvectors.Vocab at 0xc856278>,
#   'Borsippa[1]SN': <gensim.models.keyedvectors.Vocab at 0xc8562b0>,
#   'aplu[son]N': <gensim.models.keyedvectors.Vocab at 0xc8562e8>,
#   'upû[cloud]N': <gensim.models.keyedvectors.Vocab at 0xc856320>,
#   'ṣētu[light]N': <gensim.models.keyedvectors.Vocab at 0xc856358>,
#   'māgiru[submissive-one]N': <gensim.models.keyedvectors.Vocab at 0xc856390>,
#   'hiāṭu[supervise]V': <gensim.models.keyedvectors.Vocab at 0xc8563c8>,
#   'šarhu[proud]AJ': <gensim.models.keyedvectors.Vocab at 0xc856400>,
#   'pātu[edge]N': <gensim.models.keyedvectors.Vocab at 0xc856438>,
#   'DINGIR-MEŠ': <gensim.models.keyedvectors.Vocab at 0xc856470>,
#   'ṣaddu[(wooden)-signal]N': <gensim.models.keyedvectors.Vocab at 0xc8564a8>,
#   'šūpû[made-apparent]AJ': <gensim.models.keyedvectors.Vocab at 0xc8564e0>,
#   'kibru[riverbank]N': <gensim.models.keyedvectors.Vocab at 0xc856518>,
#   'arbaʾu[four]NU': <gensim.models.keyedvectors.Vocab at 0xc856550>,
#   'nindabû[(food)-offering]N': <gensim.models.keyedvectors.Vocab at 0xc856588>,
#   'nādinu[giver]N': <gensim.models.keyedvectors.Vocab at 0xc8565c0>,
#   'kalîš[totally]AV': <gensim.models.keyedvectors.Vocab at 0xc8565f8>,
#   'kussû[chair]N': <gensim.models.keyedvectors.Vocab at 0xc856630>,
#   'haṭṭu[stick]N': <gensim.models.keyedvectors.Vocab at 0xc856668>,
#   'qardammu[enemy]N': <gensim.models.keyedvectors.Vocab at 0xc8566a0>,
#   'kāmû[one-who-binds]N': <gensim.models.keyedvectors.Vocab at 0xc8566d8>,
#   'nāsihu[remover]N': <gensim.models.keyedvectors.Vocab at 0xc856710>,
#   ...})

# %% [markdown]
# # Similar words

# %%
model_akk.wv.most_similar("šarru[king]N", topn = 2), model_sux.wv.most_similar("lugal[king]N", topn=2)
# Out:
# ([('bēlu[lord]N', 0.9549878835678101), ('ana[to]PRP', 0.9517405033111572)],
#  [('ki[place]N', 0.9306298494338989), ('kalam[land]N', 0.9235943555831909)])

# %% [markdown]
# # Out of Vocabulary Words
# This is fastext ... You may also use OOV words such as partial matches.

# %%
model_akk.wv.most_similar("palace", topn = 2), model_sux.wv.most_similar("[tiger]N", topn=2)
# Out:
# ([('Ekallu-eššetu[New-Palace-palace-in-Aššur]ON', 0.7083825469017029),
#   ('egalturrû[little-palace]N', 0.6874814033508301)],
#  [('uršub[tiger]N', 0.6488356590270996),
#   ('uršubkuda[wild-animal]N', 0.5293694138526917)])

# %% [markdown]
# # Kings and Queens
# Hmmmm

# %%
model_akk.wv.most_similar(positive=["šarru[king]N", "sinništu[woman]N"], negative = ["zikaru[male]N"])
# Out:
# [('ana[to]PRP', 0.8608435988426208),
#  ('bēlu[lord]N', 0.8355156183242798),
#  ('ša[of]DET', 0.8317270874977112),
#  ('ša[that]REL', 0.82342529296875),
#  ('ardu[slave]N', 0.8218632936477661),
#  ('ina[in]PRP', 0.8146045207977295),
#  ('māru[son]N', 0.80776047706604),
#  ('abu[father]N', 0.8045011758804321),
#  ('ēkallu[palace]N', 0.8006858229637146),
#  ('muhhu[skull]N', 0.7995380163192749)]

# %% [markdown]
# # Oxen and Sheep
# More culturally appropriate, perhaps.

# %%
model_sux.wv.most_similar(positive=["gud[oxen]N", "sila[lamb]N"], negative= ["amar[calf]N"])
# Out:
# [('mašgal[goat]N', 0.9077289700508118),
#  ('ašgar[kid]N', 0.9058449268341064),
#  ('u[ewe]N', 0.8994815349578857),
#  ('udu[sheep]N', 0.8990205526351929),
#  ('maš[goat]N', 0.8890479803085327),
#  ('nua[~animal]N', 0.8813501596450806),
#  ('niga[fattened]V/i', 0.875199556350708),
#  ('gukkal[sheep]N', 0.8608914613723755),
#  ('aslum[sheep]N', 0.8605831861495972),
#  ('mašda[gazelle]N', 0.8534128665924072)]

# %% [markdown]
# # Some Bokeh Fun

# %%
def tsne_bokeh(model, word_d, words, fontsize="12pt"):

    labels = []
    tokens = []
    categories = []
    legend = []
    
    for word in word_d:
        tokens.append(model.wv[word])
        labels.append(word)
        categories.append(word_d[word])
        if word_d[word] == 5: 
            legend.append("mixed")
        else: 
            legend.append(words[word_d[word]])
    
    color_d = {0: "black", 1: "red", 2: "green", 3: "yellow", 4: "brown", 5: "blue"}
    colors = [color_d[category] for category in categories]
    
    tsne = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    tsne_embedding = tsne.fit_transform(tokens)
    tsne_embedding = pd.DataFrame(tsne_embedding, columns=['x','y'])
    tsne_embedding["color"] = colors
    tsne_embedding["labels"] = labels
    tsne_embedding["legend"] = legend

    source = ColumnDataSource(
        data=dict(
        x = tsne_embedding.x,
        y = tsne_embedding.y,
        colors = tsne_embedding.color,
        labels=tsne_embedding.labels,
        legend = tsne_embedding.legend
        )
    )

    l = LabelSet(x='x', y='y', text='labels', level='glyph',
              x_offset=5, y_offset=5, source=source, render_mode='canvas', 
             text_font_size=fontsize, text_font="CuneiformComposite")

    plot_tsne = figure(plot_width=900, plot_height=900) #, tools=tools_tsne, title='Papers')
    plot_tsne.circle('x', 'y', size=7, fill_color='colors', 
                  line_alpha=0, line_width=0.01, source=source, legend="legend")
    plot_tsne.add_layout(l)
    return plot_tsne

# %%
def word_categories(model, words, topn=10):
    """word_categories takes an iterable with one or more words from the vocabulary of model.
    For each word a dictionary of similar words (with the target word) is construed.
    The value of each word is numerical (integer) and indicates the category to which it belongs.
    The function returns a dictionary."""
    word_d = {}
    for idx, word in enumerate(words):
        w = model.wv.most_similar(word, topn=topn)
        w = [m[0] for m in w]
        w.append(word)
        for item in w:
            if item in word_d:
                word_d[item] = 5
            else:
                word_d[item] = idx
    return word_d

# %%
vegetables_perfumes = ["šimgig[tree]N", "hiz[vegetable]N"]
words_d = word_categories(model_sux, vegetables_perfumes, 35)
p2 = tsne_bokeh(model_sux, words_d, vegetables_perfumes, "20pt")
save(p2)
show(p2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-20295789fccf> in <module>()
#       2 words_d = word_categories(model_sux, vegetables_perfumes, 35)
#       3 p2 = tsne_bokeh(model_sux, words_d, vegetables_perfumes, "20pt")
# ----> 4 save(p2)
#       5 show(p2)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\io\saving.py in save(obj, filename, resources, title, template, state, **kwargs)
#      81
#      82     filename, resources, title = _get_save_args(state, filename, resources, title)
# ---> 83     _save_helper(obj, filename, resources, title, template)
#      84     return abspath(filename)
#      85
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\io\saving.py in _save_helper(obj, filename, resources, title, template)
#     145     html = file_html(obj, resources, title=title, template=template)
#     146
# --> 147     with io.open(filename, mode="w", encoding="utf-8") as f:
#     148         f.write(decode_utf8(html))
#     149
#
# FileNotFoundError: [Errno 2] No such file or directory: 'graphs/vegetables_perfumes.html'
